# %%
# %matplotlib inline

# imports
import pandas as pd
import numpy as np

from PIL import Image
from torchvision.io import read_image, ImageReadMode
import os

from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# const

#DIR_PATH = "../dataset/brain-tumor-mri"
DIR_PATH = "/kaggle/input/brain-tumor-mri-dataset"

LABELS = ["notumor", "glioma", "meningioma", "pituitary"]

TRAIN_PERCENT = .7
VAL_PERCENT = .2
TEST_PERCENT = .1

IMAGE_SIZE = 128

RANDOM_STATE = 1

BATCH_SIZE = 64
LEARNING_RATE = 0.001
NUM_EPOCH = 200

# %% [markdown]
# # Data Manipulation

# %%
# creamos un dataset de la forma (path, class)
dataset = pd.DataFrame(columns = ["path", "label"])


for dir in os.listdir(DIR_PATH):
    for label in os.listdir(os.path.join(DIR_PATH, dir)):
        for img in os.listdir(os.path.join(DIR_PATH, dir, label)):
            dataset.loc[len(dataset)] = {"path": os.path.join(DIR_PATH, dir, label, img),
                                   "label": LABELS.index(label) }


print("num elementos:", dataset.count(axis=1).size)
print(dataset.head())
# Out:
# num elementos: 7023
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      3

# %%
min_cat_size = dataset.label.value_counts().min()

print("> Cantidad de imagenes de la categoria que menos tiene:", min_cat_size)
# Out:
# > Cantidad de imagenes de la categoria que menos tiene: 1621

# %%
# Hacemos que todos tengan los mismos elementos
dataset = pd.DataFrame(dataset.groupby("label").apply(lambda label: label.sample(min_cat_size, random_state=RANDOM_STATE)).reset_index(drop=True))

print("> Cantidad de elementos: ", dataset.count(axis=1).size)
print(dataset.label.value_counts())
print(dataset.head())
# Out:
# > Cantidad de elementos:  6484
# label
# 0    1621
# 1    1621
# 2    1621
# 3    1621
# Name: count, dtype: int64
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 1  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      0

# %%
# separamos en los cjtos de entrenamiento
train_dataset, tmp = train_test_split(dataset, train_size=TRAIN_PERCENT, stratify=dataset["label"], shuffle=True, random_state=RANDOM_STATE)
val_dataset, test_dataset = train_test_split(tmp, test_size=TEST_PERCENT/(TEST_PERCENT+VAL_PERCENT), stratify=tmp["label"], shuffle=True, random_state=RANDOM_STATE)

print("> train", train_dataset.count(axis=1).size, train_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(train_dataset.label.value_counts())
print()

print("> val", val_dataset.count(axis=1).size, val_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(val_dataset.label.value_counts())
print()

print("> test", test_dataset.count(axis=1).size, test_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(test_dataset.label.value_counts())
print()
# Out:
# > train 4538 0.6998766193707588
# label
# 2    1135
# 3    1135
# 0    1134
# 1    1134
# Name: count, dtype: int64
#
# > val 1297 0.2000308451573103
# label
# 0    325
# 2    324
# 1    324
# 3    324
# Name: count, dtype: int64
#
# > test 649 0.10009253547193091
# label
# 1    163
# 3    162
# 0    162
# 2    162
# Name: count, dtype: int64

# %%
# Comprobamos que son disjuntos
print((train_dataset[ "path" ].isin(test_dataset["path"] ) == True).value_counts())
print((train_dataset[ "path" ].isin(val_dataset["path"] ) == True).value_counts())
print((val_dataset[ "path" ].isin(test_dataset["path"]) == True).value_counts())
# Out:
# path
# False    4538
# Name: count, dtype: int64
# path
# False    4538
# Name: count, dtype: int64
# path
# False    1297
# Name: count, dtype: int64

# %% [markdown]
# # Preparations

# %% [markdown]
# ## Classes

# %%
class CustomDataset(Dataset):
    
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
    
    def __len__(self):
        return self.dataframe.count(axis=1).size
    
    def __getitem__(self, idx) -> (str, int):
        
        row = self.dataframe.iloc[idx]
        img, label = row.path, row.label

        img = read_image(img, mode=ImageReadMode.GRAY)
        if self.transform: img = self.transform(img)

        return img, label

# %%
class EarlyStopper:
    
    def __init__(self, patience=5, min_delta=0, callback=lambda **_: None):
        self.patience = patience
        self.min_delta = min_delta
        self.callback = callback

        self.counter = 1

        self.best_model = None
        self.best_loss = float("inf")

    def __call__(self, val_loss, model):

        if val_loss < (self.best_loss - self.min_delta):
            self.best_loss = val_loss
            self.counter = 0

            self.best_model = model.state_dict()
            return False


        self.counter += 1
        if self.counter >= self.patience:
            self.callback(counter=self.counter, best_loss=self.best_loss, best_model=self.best_model)
            return True

    def reset(self):
        self.early_stop = False
        self.counter = 1

# %%
class CNN(nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        
        # Capas convolucionales
        self.convin = nn.Conv2d( 1, 64, kernel_size=3, stride=1, padding=1)
        self.conv1 = nn.Conv2d( 64, 64, kernel_size=3, stride=1, padding=1)
        self.convout = nn.Conv2d( 64, 128, kernel_size=3, stride=1, padding=1)

        # Capas Fully connected 
        # ajustado para 128
        self.fcin = nn.Linear(in_features=IMAGE_SIZE * 16 * 16, out_features=128)
        self.fcout = nn.Linear(in_features=128, out_features=len(LABELS))

        # BatchNorm2d
        self.bn1 = nn.BatchNorm2d(64)
        self.bnout = nn.BatchNorm2d(128)
        
        # Max pooling
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        # Capa Dropout 
        self.dropout25 = nn.Dropout(0.25)
        
            

    def forward(self, x):

        # conv in
        x = self.pool(F.relu(self.convin(x)))

        # conv 1
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout25(x)

        # conv out
        x = self.pool(F.relu(self.bnout(self.convout(x)))) 
        x = self.dropout25(x)
    
        # flatten
        x = x.view(-1, 128*16*16)

        # fully in
        x = F.relu(self.fcin(x))
        x = self.dropout25(x)

        # fully out
        x = self.fcout(x)
        
        return x

# %% [markdown]
# ## Functions

# %%
def eval(model, loader, *, device = None, criterion = None):
    """returns pred, real, accuracy, val_loss"""
    if not (device and criterion): raise Exception("Params needed")

    model.eval()

    corrects = 0

    pred = []
    real = []
    loss = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in loader:
            
            imgs, labels = imgs.to(device), labels.to(device)

            outs = model(imgs)
            loss += criterion(outs.data, labels).item()

            _, predicted = torch.max(outs.data, 1)
            
            total += labels.size(0)
            pred.extend(predicted.tolist())
            real.extend(labels.tolist())

            corrects += (predicted == labels).sum().item()
    
    return  pred, real, loss/len(loader), corrects/total

# %%
    #TMP============
    tmp_loss = []
    tmp_acc = []
    #==============

# %%
def train_loop(model, loader, *, optimizer, criterion, num_epoch=100, device=torch.device("cuda" if torch.cuda.is_available() else "cpu"), train_loss_h=[], train_acc_h=[], val_loss_h=[] ,val_acc_h=[], callback=lambda **_: None, early_callback=lambda **_: None, scheduler, val_loader):
    if not (optimizer and criterion and early_stopper and scheduler): raise Exception("Params needed")
    
    val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
    callback(epoch=0, val_acc=val_acc, val_loss=val_loss, train_loss=float("inf"), train_acc=0)
    

    for epoch in range(num_epoch):

        running_loss = 0.0
        corrects = 0
        total = 0

        model.train()

        for i, (imgs, labels) in enumerate(loader, 1):

            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()

            outs = model(imgs)
            loss = criterion(outs, labels)
            
            running_loss += loss.item()
            
            loss.backward()
            optimizer.step()

            # extra for analytics
            _, predicted = torch.max(outs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()
            # ==================

            if not i % 10:
                print(f"\tEpoch {epoch+1}, Batch {i}: Loss: {running_loss*(len(loader)-i+1)/(10*len(loader)):.4f}")
            
        val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
        scheduler.step(val_loss)
        
        # extra for analytics
        train_loss = running_loss/len(loader)
        train_loss_h.append(train_loss)
        train_acc = 100*corrects/total
        train_acc_h.append(train_acc)

        val_loss_h.append(val_loss)
        val_acc_h.append(val_acc*100)
        # ===================
        
        #TMP================
        _, _, tmploss, tmpacc = eval(model, train_loader, device=device, criterion=criterion)
        tmp_loss.append(tmploss)
        tmp_acc.append(tmpacc*100)
        print(f"REAL TRAIN: train_loss: {tmploss:.2f}, train_acc: {tmpacc*100:.4}")
        #==================

        callback(epoch=epoch+1, val_acc=val_acc, val_loss=val_loss, train_loss=train_loss, train_acc=train_acc)

        if(early_stopper(val_loss, model)): break

    return train_acc_h, val_acc_h, train_loss_h, val_loss_h, val_preds, val_labels

# %% [markdown]
# # Utils

# %%
def save_model(model, path, complete=False):
    try:
        torch.save(model if complete else model.state_dict(), path)
    except Exception as e:
        print("Error al guardar el model:", e)

# %%
def show_img(img, label):
    print('Label: ', dataset.label[label], "(" + str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %% [markdown]
# ## Dataset statistics

# %%
unnormalized_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.ToTensor()
])

unnormalized_dataset = CustomDataset(dataset, transform=unnormalized_transforms)
loader = DataLoader(unnormalized_dataset, batch_size=1, shuffle=False)

sum_intensity = 0.0
sum_squared_intensity = 0.0
n_samples = 0

for imgs, _ in loader:
    
    sum_intensity += imgs.sum()
    sum_squared_intensity += (imgs ** 2).sum()
    n_samples += imgs.numel()

mean = sum_intensity / n_samples
std = torch.sqrt(sum_squared_intensity / n_samples - mean ** 2)

print(mean)
print(std)
# Out:
# tensor(0.1842)
# tensor(0.1950)

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.RandomRotation(180),            
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

test_valid_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE),antialias=True),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])


train_dataset = CustomDataset(train_dataset, transform=train_transform)
val_dataset = CustomDataset(val_dataset, transform=test_valid_transforms)
test_dataset = CustomDataset(test_dataset, transform=test_valid_transforms)

# Acceder e imprimir las primeras 5 muestras del dataset
for i in range(5):
    image, label = train_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = val_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = test_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")

# Imprimir los valores de la media y la desviación estándar
print(f"Media: {mean}, Desviación Estándar: {std}")
# Out:
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 1
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 1
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 1
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Media: 0.18419140577316284, Desviación Estándar: 0.19503213465213776

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

# Verificar DataLoader
for images, labels in train_loader:
    print(f"Batch de imágenes: {images.shape}, Batch de etiquetas: {labels.shape}")
    break

# Carga una imagen de prueba
img, label = test_dataset[45]
show_img(img, label)
# Out:
# Batch de imágenes: torch.Size([64, 1, 128, 128]), Batch de etiquetas: torch.Size([64])
# Label:  0 (1)

# %% [markdown]
# ## Comprobaciones previas de la GPU

# %%
print(torch.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo configurado para usar: {device}")

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.0.0
# Dispositivo configurado para usar: cuda
# True
# Tesla P100-PCIE-16GB

# %% [markdown]
# ## Entrenamos

# %%
def early_callback(**kwargs): print("> Early stopping <")

early_stopper = EarlyStopper(patience=10, min_delta=.001, callback=early_callback)

# %%
model = CNN()
if torch.cuda.device_count() > 1: model = nn.DataParallel(model)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss().to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, patience=6, verbose=True)

def callback(**kwargs):
    print(f"Epoch: {kwargs['epoch']}, val_loss: {(kwargs['val_loss']):.2f}, train_loss: {(kwargs['train_loss']):.2f} val_acc: {(kwargs['val_acc']*100):.2f}, train_acc: {(kwargs['train_acc']):.2f}")

train_acc_h, val_acc_h, train_loss_h, val_loss_h, preds, targets = train_loop(model, train_loader,
           val_loader=val_loader,                                                                                  
           optimizer=optimizer,
           criterion=criterion,
           num_epoch=NUM_EPOCH,
           device=device,
           callback=callback,
           scheduler=scheduler
           )
# Out:
# Epoch: 0, val_loss: 1.39, train_loss: inf val_acc: 24.98, train_acc: 0.00
# 	Epoch 1, Batch 10: Loss: 3.7098
# 	Epoch 1, Batch 20: Loss: 4.5383
# 	Epoch 1, Batch 30: Loss: 4.3466
# 	Epoch 1, Batch 40: Loss: 3.7866
# 	Epoch 1, Batch 50: Loss: 2.9023
# 	Epoch 1, Batch 60: Loss: 1.7690
# 	Epoch 1, Batch 70: Loss: 0.3220
# REAL TRAIN: train_loss: 0.87, train_acc: 64.32
# Epoch: 1, val_loss: 0.85, train_loss: 1.62 val_acc: 64.46, train_acc: 55.29
# 	Epoch 2, Batch 10: Loss: 0.8121
# 	Epoch 2, Batch 20: Loss: 1.3150
# 	Epoch 2, Batch 30: Loss: 1.6337
# 	Epoch 2, Batch 40: Loss: 1.6619
# 	Epoch 2, Batch 50: Loss: 1.4130
# 	Epoch 2, Batch 60: Loss: 0.9189
# 	Epoch 2, Batch 70: Loss: 0.1763
# REAL TRAIN: train_loss: 0.77, train_acc: 66.88
# Epoch: 2, val_loss: 0.76, train_loss: 0.89 val_acc: 67.69, train_acc: 63.35
# 	Epoch 3, Batch 10: Loss: 0.7231
# 	Epoch 3, Batch 20: Loss: 1.1771
# 	Epoch 3, Batch 30: Loss: 1.4509
# 	Epoch 3, Batch 40: Loss: 1.4694
# 	Epoch 3, Batch 50: Loss: 1.2580
# 	Epoch 3, Batch 60: Loss: 0.8144
# 	Epoch 3, Batch 70: Loss: 0.1573
# REAL TRAIN: train_loss: 0.71, train_acc: 71.0
# Epoch: 3, val_loss: 0.74, train_loss: 0.79 val_acc: 70.32, train_acc: 67.01
# 	Epoch 4, Batch 10: Loss: 0.6541
# 	Epoch 4, Batch 20: Loss: 1.0948
# 	Epoch 4, Batch 30: Loss: 1.3333
# 	Epoch 4, Batch 40: Loss: 1.3668
# 	Epoch 4, Batch 50: Loss: 1.1678
# 	Epoch 4, Batch 60: Loss: 0.7580
# 	Epoch 4, Batch 70: Loss: 0.1474
# REAL TRAIN: train_loss: 0.64, train_acc: 74.57
# Epoch: 4, val_loss: 0.65, train_loss: 0.75 val_acc: 74.56, train_acc: 69.59
# 	Epoch 5, Batch 10: Loss: 0.6758
# 	Epoch 5, Batch 20: Loss: 1.0710
# 	Epoch 5, Batch 30: Loss: 1.2902
# 	Epoch 5, Batch 40: Loss: 1.3193
# 	Epoch 5, Batch 50: Loss: 1.1128
# 	Epoch 5, Batch 60: Loss: 0.7186
# 	Epoch 5, Batch 70: Loss: 0.1397
# REAL TRAIN: train_loss: 0.65, train_acc: 72.83
# Epoch: 5, val_loss: 0.67, train_loss: 0.71 val_acc: 71.47, train_acc: 69.94
# 	Epoch 6, Batch 10: Loss: 0.5822
# 	Epoch 6, Batch 20: Loss: 1.0073
# 	Epoch 6, Batch 30: Loss: 1.2355
# 	Epoch 6, Batch 40: Loss: 1.2540
# 	Epoch 6, Batch 50: Loss: 1.0938
# 	Epoch 6, Batch 60: Loss: 0.7158
# 	Epoch 6, Batch 70: Loss: 0.1377
# REAL TRAIN: train_loss: 0.70, train_acc: 71.46
# Epoch: 6, val_loss: 0.57, train_loss: 0.70 val_acc: 78.57, train_acc: 70.47
# 	Epoch 7, Batch 10: Loss: 0.6018
# 	Epoch 7, Batch 20: Loss: 1.0160
# 	Epoch 7, Batch 30: Loss: 1.1901
# 	Epoch 7, Batch 40: Loss: 1.2164
# 	Epoch 7, Batch 50: Loss: 1.0268
# 	Epoch 7, Batch 60: Loss: 0.6600
# 	Epoch 7, Batch 70: Loss: 0.1281
# REAL TRAIN: train_loss: 0.62, train_acc: 74.57
# Epoch: 7, val_loss: 0.65, train_loss: 0.65 val_acc: 73.01, train_acc: 72.28
# 	Epoch 8, Batch 10: Loss: 0.5592
# 	Epoch 8, Batch 20: Loss: 0.9024
# 	Epoch 8, Batch 30: Loss: 1.1155
# 	Epoch 8, Batch 40: Loss: 1.1426
# 	Epoch 8, Batch 50: Loss: 0.9786
# 	Epoch 8, Batch 60: Loss: 0.6533
# 	Epoch 8, Batch 70: Loss: 0.1271
# REAL TRAIN: train_loss: 0.56, train_acc: 77.39
# Epoch: 8, val_loss: 0.52, train_loss: 0.64 val_acc: 79.03, train_acc: 73.62
# 	Epoch 9, Batch 10: Loss: 0.5231
# 	Epoch 9, Batch 20: Loss: 0.9170
# 	Epoch 9, Batch 30: Loss: 1.1313
# 	Epoch 9, Batch 40: Loss: 1.1301
# 	Epoch 9, Batch 50: Loss: 0.9604
# 	Epoch 9, Batch 60: Loss: 0.6352
# 	Epoch 9, Batch 70: Loss: 0.1219
# REAL TRAIN: train_loss: 0.56, train_acc: 77.72
# Epoch: 9, val_loss: 0.53, train_loss: 0.62 val_acc: 78.57, train_acc: 74.99
# 	Epoch 10, Batch 10: Loss: 0.5120
# 	Epoch 10, Batch 20: Loss: 0.8599
# 	Epoch 10, Batch 30: Loss: 1.0431
# 	Epoch 10, Batch 40: Loss: 1.0677
# 	Epoch 10, Batch 50: Loss: 0.9192
# 	Epoch 10, Batch 60: Loss: 0.6143
# 	Epoch 10, Batch 70: Loss: 0.1191
# REAL TRAIN: train_loss: 0.60, train_acc: 76.27
# Epoch: 10, val_loss: 0.62, train_loss: 0.60 val_acc: 74.87, train_acc: 75.21
# 	Epoch 11, Batch 10: Loss: 0.5127
# 	Epoch 11, Batch 20: Loss: 0.8212
# 	Epoch 11, Batch 30: Loss: 1.0286
# 	Epoch 11, Batch 40: Loss: 1.0432
# 	Epoch 11, Batch 50: Loss: 0.8993
# 	Epoch 11, Batch 60: Loss: 0.5907
# 	Epoch 11, Batch 70: Loss: 0.1154
# REAL TRAIN: train_loss: 0.52, train_acc: 78.38
# Epoch: 11, val_loss: 0.49, train_loss: 0.58 val_acc: 80.42, train_acc: 75.78
# 	Epoch 12, Batch 10: Loss: 0.4997
# 	Epoch 12, Batch 20: Loss: 0.8889
# 	Epoch 12, Batch 30: Loss: 1.0489
# 	Epoch 12, Batch 40: Loss: 1.0675
# 	Epoch 12, Batch 50: Loss: 0.9147
# 	Epoch 12, Batch 60: Loss: 0.5891
# 	Epoch 12, Batch 70: Loss: 0.1137
# REAL TRAIN: train_loss: 0.63, train_acc: 74.22
# Epoch: 12, val_loss: 0.69, train_loss: 0.58 val_acc: 72.55, train_acc: 75.67
# 	Epoch 13, Batch 10: Loss: 0.5164
# 	Epoch 13, Batch 20: Loss: 0.8432
# 	Epoch 13, Batch 30: Loss: 0.9506
# 	Epoch 13, Batch 40: Loss: 0.9980
# 	Epoch 13, Batch 50: Loss: 0.8429
# 	Epoch 13, Batch 60: Loss: 0.5537
# 	Epoch 13, Batch 70: Loss: 0.1079
# REAL TRAIN: train_loss: 0.53, train_acc: 76.11
# Epoch: 13, val_loss: 0.54, train_loss: 0.55 val_acc: 75.25, train_acc: 78.27
# 	Epoch 14, Batch 10: Loss: 0.4313
# 	Epoch 14, Batch 20: Loss: 0.8112
# 	Epoch 14, Batch 30: Loss: 1.0135
# 	Epoch 14, Batch 40: Loss: 0.9951
# 	Epoch 14, Batch 50: Loss: 0.8482
# 	Epoch 14, Batch 60: Loss: 0.5492
# 	Epoch 14, Batch 70: Loss: 0.1049
# REAL TRAIN: train_loss: 0.45, train_acc: 81.38
# Epoch: 14, val_loss: 0.47, train_loss: 0.53 val_acc: 81.03, train_acc: 78.07
# 	Epoch 15, Batch 10: Loss: 0.4673
# 	Epoch 15, Batch 20: Loss: 0.8088
# 	Epoch 15, Batch 30: Loss: 0.9436
# 	Epoch 15, Batch 40: Loss: 0.9510
# 	Epoch 15, Batch 50: Loss: 0.8110
# 	Epoch 15, Batch 60: Loss: 0.5325
# 	Epoch 15, Batch 70: Loss: 0.1039
# REAL TRAIN: train_loss: 0.49, train_acc: 79.77
# Epoch: 15, val_loss: 0.50, train_loss: 0.53 val_acc: 80.80, train_acc: 78.01
# 	Epoch 16, Batch 10: Loss: 0.4990
# 	Epoch 16, Batch 20: Loss: 0.8122
# 	Epoch 16, Batch 30: Loss: 0.9634
# 	Epoch 16, Batch 40: Loss: 0.9565
# 	Epoch 16, Batch 50: Loss: 0.7980
# 	Epoch 16, Batch 60: Loss: 0.5105
# 	Epoch 16, Batch 70: Loss: 0.0986
# REAL TRAIN: train_loss: 0.41, train_acc: 83.74
# Epoch: 16, val_loss: 0.44, train_loss: 0.50 val_acc: 84.04, train_acc: 79.68
# 	Epoch 17, Batch 10: Loss: 0.4825
# 	Epoch 17, Batch 20: Loss: 0.8186
# 	Epoch 17, Batch 30: Loss: 0.9735
# 	Epoch 17, Batch 40: Loss: 0.9543
# 	Epoch 17, Batch 50: Loss: 0.8045
# 	Epoch 17, Batch 60: Loss: 0.5137
# 	Epoch 17, Batch 70: Loss: 0.0993
# REAL TRAIN: train_loss: 0.37, train_acc: 85.02
# Epoch: 17, val_loss: 0.38, train_loss: 0.50 val_acc: 84.97, train_acc: 78.69
# 	Epoch 18, Batch 10: Loss: 0.4300
# 	Epoch 18, Batch 20: Loss: 0.7299
# 	Epoch 18, Batch 30: Loss: 0.8601
# 	Epoch 18, Batch 40: Loss: 0.8466
# 	Epoch 18, Batch 50: Loss: 0.7347
# 	Epoch 18, Batch 60: Loss: 0.4800
# 	Epoch 18, Batch 70: Loss: 0.0940
# REAL TRAIN: train_loss: 0.38, train_acc: 84.6
# Epoch: 18, val_loss: 0.39, train_loss: 0.48 val_acc: 84.73, train_acc: 80.85
# 	Epoch 19, Batch 10: Loss: 0.3377
# 	Epoch 19, Batch 20: Loss: 0.6688
# 	Epoch 19, Batch 30: Loss: 0.8098
# 	Epoch 19, Batch 40: Loss: 0.8198
# 	Epoch 19, Batch 50: Loss: 0.7183
# 	Epoch 19, Batch 60: Loss: 0.4686
# 	Epoch 19, Batch 70: Loss: 0.0914
# REAL TRAIN: train_loss: 0.39, train_acc: 84.49
# Epoch: 19, val_loss: 0.35, train_loss: 0.46 val_acc: 86.20, train_acc: 81.42
# 	Epoch 20, Batch 10: Loss: 0.3692
# 	Epoch 20, Batch 20: Loss: 0.5814
# 	Epoch 20, Batch 30: Loss: 0.7419
# 	Epoch 20, Batch 40: Loss: 0.7691
# 	Epoch 20, Batch 50: Loss: 0.6802
# 	Epoch 20, Batch 60: Loss: 0.4488
# 	Epoch 20, Batch 70: Loss: 0.0878
# REAL TRAIN: train_loss: 0.49, train_acc: 80.21
# Epoch: 20, val_loss: 0.50, train_loss: 0.45 val_acc: 78.95, train_acc: 81.58
# 	Epoch 21, Batch 10: Loss: 0.3677
# 	Epoch 21, Batch 20: Loss: 0.6076
# 	Epoch 21, Batch 30: Loss: 0.7649
# 	Epoch 21, Batch 40: Loss: 0.7924
# 	Epoch 21, Batch 50: Loss: 0.6689
# 	Epoch 21, Batch 60: Loss: 0.4372
# 	Epoch 21, Batch 70: Loss: 0.0854
# REAL TRAIN: train_loss: 0.42, train_acc: 83.14
# Epoch: 21, val_loss: 0.43, train_loss: 0.43 val_acc: 83.58, train_acc: 82.35
# 	Epoch 22, Batch 10: Loss: 0.3653
# 	Epoch 22, Batch 20: Loss: 0.6220
# 	Epoch 22, Batch 30: Loss: 0.7794
# 	Epoch 22, Batch 40: Loss: 0.7956
# 	Epoch 22, Batch 50: Loss: 0.7049
# 	Epoch 22, Batch 60: Loss: 0.4494
# 	Epoch 22, Batch 70: Loss: 0.0878
# REAL TRAIN: train_loss: 0.35, train_acc: 86.38
# Epoch: 22, val_loss: 0.36, train_loss: 0.45 val_acc: 86.66, train_acc: 82.28
# 	Epoch 23, Batch 10: Loss: 0.4259
# 	Epoch 23, Batch 20: Loss: 0.6573
# 	Epoch 23, Batch 30: Loss: 0.7764
# 	Epoch 23, Batch 40: Loss: 0.7898
# 	Epoch 23, Batch 50: Loss: 0.6663
# 	Epoch 23, Batch 60: Loss: 0.4372
# 	Epoch 23, Batch 70: Loss: 0.0853
# REAL TRAIN: train_loss: 0.46, train_acc: 82.72
# Epoch: 23, val_loss: 0.43, train_loss: 0.43 val_acc: 82.81, train_acc: 82.22
# 	Epoch 24, Batch 10: Loss: 0.3727
# 	Epoch 24, Batch 20: Loss: 0.5987
# 	Epoch 24, Batch 30: Loss: 0.7280
# 	Epoch 24, Batch 40: Loss: 0.7474
# 	Epoch 24, Batch 50: Loss: 0.6399
# 	Epoch 24, Batch 60: Loss: 0.4164
# 	Epoch 24, Batch 70: Loss: 0.0804
# REAL TRAIN: train_loss: 0.33, train_acc: 86.36
# Epoch: 24, val_loss: 0.36, train_loss: 0.41 val_acc: 84.89, train_acc: 83.67
# 	Epoch 25, Batch 10: Loss: 0.3626
# 	Epoch 25, Batch 20: Loss: 0.5853
# 	Epoch 25, Batch 30: Loss: 0.6908
# 	Epoch 25, Batch 40: Loss: 0.7132
# 	Epoch 25, Batch 50: Loss: 0.6147
# 	Epoch 25, Batch 60: Loss: 0.4070
# 	Epoch 25, Batch 70: Loss: 0.0788
# REAL TRAIN: train_loss: 0.29, train_acc: 88.03
# Epoch: 25, val_loss: 0.29, train_loss: 0.40 val_acc: 88.36, train_acc: 84.02
# 	Epoch 26, Batch 10: Loss: 0.3181
# 	Epoch 26, Batch 20: Loss: 0.5469
# 	Epoch 26, Batch 30: Loss: 0.6642
# 	Epoch 26, Batch 40: Loss: 0.6994
# 	Epoch 26, Batch 50: Loss: 0.6007
# 	Epoch 26, Batch 60: Loss: 0.3942
# 	Epoch 26, Batch 70: Loss: 0.0768
# REAL TRAIN: train_loss: 0.38, train_acc: 84.16
# Epoch: 26, val_loss: 0.39, train_loss: 0.39 val_acc: 83.58, train_acc: 84.40
# 	Epoch 27, Batch 10: Loss: 0.3439
# 	Epoch 27, Batch 20: Loss: 0.6217
# 	Epoch 27, Batch 30: Loss: 0.6993
# 	Epoch 27, Batch 40: Loss: 0.7162
# 	Epoch 27, Batch 50: Loss: 0.5909
# 	Epoch 27, Batch 60: Loss: 0.3865
# 	Epoch 27, Batch 70: Loss: 0.0746
# REAL TRAIN: train_loss: 0.31, train_acc: 88.96
# Epoch: 27, val_loss: 0.33, train_loss: 0.38 val_acc: 87.36, train_acc: 85.37
# 	Epoch 28, Batch 10: Loss: 0.3245
# 	Epoch 28, Batch 20: Loss: 0.5543
# 	Epoch 28, Batch 30: Loss: 0.6566
# 	Epoch 28, Batch 40: Loss: 0.6934
# 	Epoch 28, Batch 50: Loss: 0.5966
# 	Epoch 28, Batch 60: Loss: 0.3905
# 	Epoch 28, Batch 70: Loss: 0.0769
# REAL TRAIN: train_loss: 0.33, train_acc: 87.13
# Epoch: 28, val_loss: 0.35, train_loss: 0.39 val_acc: 86.58, train_acc: 84.68
# 	Epoch 29, Batch 10: Loss: 0.3588
# 	Epoch 29, Batch 20: Loss: 0.5724
# 	Epoch 29, Batch 30: Loss: 0.6936
# 	Epoch 29, Batch 40: Loss: 0.7020
# 	Epoch 29, Batch 50: Loss: 0.6006
# 	Epoch 29, Batch 60: Loss: 0.3927
# 	Epoch 29, Batch 70: Loss: 0.0752
# REAL TRAIN: train_loss: 0.91, train_acc: 71.22
# Epoch: 29, val_loss: 0.83, train_loss: 0.38 val_acc: 73.48, train_acc: 84.95
# 	Epoch 30, Batch 10: Loss: 0.3108
# 	Epoch 30, Batch 20: Loss: 0.5513
# 	Epoch 30, Batch 30: Loss: 0.6705
# 	Epoch 30, Batch 40: Loss: 0.7073
# 	Epoch 30, Batch 50: Loss: 0.6080
# 	Epoch 30, Batch 60: Loss: 0.3970
# 	Epoch 30, Batch 70: Loss: 0.0773
# REAL TRAIN: train_loss: 0.28, train_acc: 88.92
# Epoch: 30, val_loss: 0.28, train_loss: 0.39 val_acc: 90.13, train_acc: 84.51
# 	Epoch 31, Batch 10: Loss: 0.3635
# 	Epoch 31, Batch 20: Loss: 0.5734
# 	Epoch 31, Batch 30: Loss: 0.6653
# 	Epoch 31, Batch 40: Loss: 0.6673
# 	Epoch 31, Batch 50: Loss: 0.5703
# 	Epoch 31, Batch 60: Loss: 0.3827
# 	Epoch 31, Batch 70: Loss: 0.0758
# REAL TRAIN: train_loss: 0.34, train_acc: 85.99
# Epoch: 31, val_loss: 0.33, train_loss: 0.38 val_acc: 86.97, train_acc: 84.88
# 	Epoch 32, Batch 10: Loss: 0.3092
# 	Epoch 32, Batch 20: Loss: 0.5167
# 	Epoch 32, Batch 30: Loss: 0.6623
# 	Epoch 32, Batch 40: Loss: 0.6812
# 	Epoch 32, Batch 50: Loss: 0.5720
# 	Epoch 32, Batch 60: Loss: 0.3799
# 	Epoch 32, Batch 70: Loss: 0.0734
# REAL TRAIN: train_loss: 0.52, train_acc: 80.01
# Epoch: 32, val_loss: 0.51, train_loss: 0.37 val_acc: 82.27, train_acc: 85.50
# 	Epoch 33, Batch 10: Loss: 0.3734
# 	Epoch 33, Batch 20: Loss: 0.5743
# 	Epoch 33, Batch 30: Loss: 0.6546
# 	Epoch 33, Batch 40: Loss: 0.6618
# 	Epoch 33, Batch 50: Loss: 0.5715
# 	Epoch 33, Batch 60: Loss: 0.3683
# 	Epoch 33, Batch 70: Loss: 0.0730
# REAL TRAIN: train_loss: 0.31, train_acc: 87.86
# Epoch: 33, val_loss: 0.36, train_loss: 0.37 val_acc: 85.97, train_acc: 85.50
# 	Epoch 34, Batch 10: Loss: 0.3203
# 	Epoch 34, Batch 20: Loss: 0.5350
# 	Epoch 34, Batch 30: Loss: 0.6357
# 	Epoch 34, Batch 40: Loss: 0.6641
# 	Epoch 34, Batch 50: Loss: 0.5739
# 	Epoch 34, Batch 60: Loss: 0.3786
# 	Epoch 34, Batch 70: Loss: 0.0748
# REAL TRAIN: train_loss: 0.33, train_acc: 86.65
# Epoch: 34, val_loss: 0.37, train_loss: 0.38 val_acc: 85.58, train_acc: 85.04
# 	Epoch 35, Batch 10: Loss: 0.3388
# 	Epoch 35, Batch 20: Loss: 0.5355
# 	Epoch 35, Batch 30: Loss: 0.6655
# 	Epoch 35, Batch 40: Loss: 0.6551
# 	Epoch 35, Batch 50: Loss: 0.5566
# 	Epoch 35, Batch 60: Loss: 0.3557
# 	Epoch 35, Batch 70: Loss: 0.0689
# REAL TRAIN: train_loss: 0.29, train_acc: 88.74
# Epoch: 35, val_loss: 0.29, train_loss: 0.35 val_acc: 89.13, train_acc: 85.72
# 	Epoch 36, Batch 10: Loss: 0.2837
# 	Epoch 36, Batch 20: Loss: 0.5013
# 	Epoch 36, Batch 30: Loss: 0.6269
# 	Epoch 36, Batch 40: Loss: 0.6571
# 	Epoch 36, Batch 50: Loss: 0.5835
# 	Epoch 36, Batch 60: Loss: 0.3828
# 	Epoch 36, Batch 70: Loss: 0.0751
# REAL TRAIN: train_loss: 0.29, train_acc: 88.98
# Epoch: 36, val_loss: 0.34, train_loss: 0.38 val_acc: 87.43, train_acc: 85.28
# 	Epoch 37, Batch 10: Loss: 0.3261
# 	Epoch 37, Batch 20: Loss: 0.5217
# 	Epoch 37, Batch 30: Loss: 0.6406
# 	Epoch 37, Batch 40: Loss: 0.6661
# 	Epoch 37, Batch 50: Loss: 0.5704
# 	Epoch 37, Batch 60: Loss: 0.3707
# 	Epoch 37, Batch 70: Loss: 0.0713
# REAL TRAIN: train_loss: 0.25, train_acc: 90.04
# Epoch: 37, val_loss: 0.27, train_loss: 0.36 val_acc: 89.59, train_acc: 86.36
# 	Epoch 38, Batch 10: Loss: 0.2881
# 	Epoch 38, Batch 20: Loss: 0.5022
# 	Epoch 38, Batch 30: Loss: 0.5997
# 	Epoch 38, Batch 40: Loss: 0.6284
# 	Epoch 38, Batch 50: Loss: 0.5425
# 	Epoch 38, Batch 60: Loss: 0.3513
# 	Epoch 38, Batch 70: Loss: 0.0682
# REAL TRAIN: train_loss: 0.26, train_acc: 89.55
# Epoch: 38, val_loss: 0.25, train_loss: 0.35 val_acc: 90.44, train_acc: 86.14
# 	Epoch 39, Batch 10: Loss: 0.2717
# 	Epoch 39, Batch 20: Loss: 0.4605
# 	Epoch 39, Batch 30: Loss: 0.5525
# 	Epoch 39, Batch 40: Loss: 0.5830
# 	Epoch 39, Batch 50: Loss: 0.5063
# 	Epoch 39, Batch 60: Loss: 0.3330
# 	Epoch 39, Batch 70: Loss: 0.0637
# REAL TRAIN: train_loss: 0.33, train_acc: 87.09
# Epoch: 39, val_loss: 0.34, train_loss: 0.33 val_acc: 87.20, train_acc: 87.29
# 	Epoch 40, Batch 10: Loss: 0.3340
# 	Epoch 40, Batch 20: Loss: 0.5306
# 	Epoch 40, Batch 30: Loss: 0.6451
# 	Epoch 40, Batch 40: Loss: 0.6472
# 	Epoch 40, Batch 50: Loss: 0.5484
# 	Epoch 40, Batch 60: Loss: 0.3661
# 	Epoch 40, Batch 70: Loss: 0.0703
# REAL TRAIN: train_loss: 0.28, train_acc: 89.6
# Epoch: 40, val_loss: 0.29, train_loss: 0.36 val_acc: 88.59, train_acc: 86.14
# 	Epoch 41, Batch 10: Loss: 0.2780
# 	Epoch 41, Batch 20: Loss: 0.4911
# 	Epoch 41, Batch 30: Loss: 0.5899
# 	Epoch 41, Batch 40: Loss: 0.6008
# 	Epoch 41, Batch 50: Loss: 0.5162
# 	Epoch 41, Batch 60: Loss: 0.3316
# 	Epoch 41, Batch 70: Loss: 0.0638
# REAL TRAIN: train_loss: 0.50, train_acc: 83.74
# Epoch: 41, val_loss: 0.50, train_loss: 0.32 val_acc: 83.58, train_acc: 87.46
# 	Epoch 42, Batch 10: Loss: 0.3225
# 	Epoch 42, Batch 20: Loss: 0.5477
# 	Epoch 42, Batch 30: Loss: 0.6501
# 	Epoch 42, Batch 40: Loss: 0.6745
# 	Epoch 42, Batch 50: Loss: 0.5695
# 	Epoch 42, Batch 60: Loss: 0.3749
# 	Epoch 42, Batch 70: Loss: 0.0731
# REAL TRAIN: train_loss: 0.28, train_acc: 89.0
# Epoch: 42, val_loss: 0.28, train_loss: 0.37 val_acc: 89.05, train_acc: 85.32
# 	Epoch 43, Batch 10: Loss: 0.2820
# 	Epoch 43, Batch 20: Loss: 0.4954
# 	Epoch 43, Batch 30: Loss: 0.5942
# 	Epoch 43, Batch 40: Loss: 0.6120
# 	Epoch 43, Batch 50: Loss: 0.5235
# 	Epoch 43, Batch 60: Loss: 0.3403
# 	Epoch 43, Batch 70: Loss: 0.0660
# REAL TRAIN: train_loss: 0.32, train_acc: 87.4
# Epoch: 43, val_loss: 0.34, train_loss: 0.34 val_acc: 86.74, train_acc: 86.98
# 	Epoch 44, Batch 10: Loss: 0.2828
# 	Epoch 44, Batch 20: Loss: 0.4319
# 	Epoch 44, Batch 30: Loss: 0.5631
# 	Epoch 44, Batch 40: Loss: 0.5730
# 	Epoch 44, Batch 50: Loss: 0.4995
# 	Epoch 44, Batch 60: Loss: 0.3232
# 	Epoch 44, Batch 70: Loss: 0.0615
# REAL TRAIN: train_loss: 0.22, train_acc: 91.38
# Epoch: 44, val_loss: 0.24, train_loss: 0.31 val_acc: 91.52, train_acc: 88.23
# 	Epoch 45, Batch 10: Loss: 0.2738
# 	Epoch 45, Batch 20: Loss: 0.4648
# 	Epoch 45, Batch 30: Loss: 0.6047
# 	Epoch 45, Batch 40: Loss: 0.5952
# 	Epoch 45, Batch 50: Loss: 0.5137
# 	Epoch 45, Batch 60: Loss: 0.3348
# 	Epoch 45, Batch 70: Loss: 0.0643
# REAL TRAIN: train_loss: 0.30, train_acc: 89.11
# Epoch: 45, val_loss: 0.31, train_loss: 0.33 val_acc: 88.05, train_acc: 87.04
# 	Epoch 46, Batch 10: Loss: 0.2660
# 	Epoch 46, Batch 20: Loss: 0.4383
# 	Epoch 46, Batch 30: Loss: 0.4973
# 	Epoch 46, Batch 40: Loss: 0.5094
# 	Epoch 46, Batch 50: Loss: 0.4381
# 	Epoch 46, Batch 60: Loss: 0.2920
# 	Epoch 46, Batch 70: Loss: 0.0575
# REAL TRAIN: train_loss: 0.37, train_acc: 86.93
# Epoch: 46, val_loss: 0.38, train_loss: 0.29 val_acc: 86.20, train_acc: 88.78
# 	Epoch 47, Batch 10: Loss: 0.2988
# 	Epoch 47, Batch 20: Loss: 0.4640
# 	Epoch 47, Batch 30: Loss: 0.5426
# 	Epoch 47, Batch 40: Loss: 0.5345
# 	Epoch 47, Batch 50: Loss: 0.4727
# 	Epoch 47, Batch 60: Loss: 0.3120
# 	Epoch 47, Batch 70: Loss: 0.0602
# REAL TRAIN: train_loss: 0.23, train_acc: 90.92
# Epoch: 47, val_loss: 0.25, train_loss: 0.31 val_acc: 90.67, train_acc: 88.34
# 	Epoch 48, Batch 10: Loss: 0.2459
# 	Epoch 48, Batch 20: Loss: 0.4320
# 	Epoch 48, Batch 30: Loss: 0.5416
# 	Epoch 48, Batch 40: Loss: 0.5621
# 	Epoch 48, Batch 50: Loss: 0.5069
# 	Epoch 48, Batch 60: Loss: 0.3261
# 	Epoch 48, Batch 70: Loss: 0.0633
# REAL TRAIN: train_loss: 0.23, train_acc: 90.79
# Epoch: 48, val_loss: 0.27, train_loss: 0.32 val_acc: 90.21, train_acc: 87.55
# 	Epoch 49, Batch 10: Loss: 0.2784
# 	Epoch 49, Batch 20: Loss: 0.4757
# 	Epoch 49, Batch 30: Loss: 0.5680
# 	Epoch 49, Batch 40: Loss: 0.5587
# 	Epoch 49, Batch 50: Loss: 0.4903
# 	Epoch 49, Batch 60: Loss: 0.3176
# 	Epoch 49, Batch 70: Loss: 0.0606
# REAL TRAIN: train_loss: 0.22, train_acc: 90.9
# Epoch: 49, val_loss: 0.25, train_loss: 0.30 val_acc: 90.36, train_acc: 88.59
# 	Epoch 50, Batch 10: Loss: 0.2701
# 	Epoch 50, Batch 20: Loss: 0.4209
# 	Epoch 50, Batch 30: Loss: 0.4916
# 	Epoch 50, Batch 40: Loss: 0.5138
# 	Epoch 50, Batch 50: Loss: 0.4515
# 	Epoch 50, Batch 60: Loss: 0.3008
# 	Epoch 50, Batch 70: Loss: 0.0602
# REAL TRAIN: train_loss: 0.25, train_acc: 89.53
# Epoch: 50, val_loss: 0.31, train_loss: 0.31 val_acc: 87.43, train_acc: 88.45
# 	Epoch 51, Batch 10: Loss: 0.2842
# 	Epoch 51, Batch 20: Loss: 0.4807
# 	Epoch 51, Batch 30: Loss: 0.5841
# 	Epoch 51, Batch 40: Loss: 0.5944
# 	Epoch 51, Batch 50: Loss: 0.5101
# 	Epoch 51, Batch 60: Loss: 0.3357
# 	Epoch 51, Batch 70: Loss: 0.0648
# Epoch 00051: reducing learning rate of group 0 to 2.0000e-04.
# REAL TRAIN: train_loss: 0.24, train_acc: 90.77
# Epoch: 51, val_loss: 0.30, train_loss: 0.33 val_acc: 89.82, train_acc: 86.82
# 	Epoch 52, Batch 10: Loss: 0.2595
# 	Epoch 52, Batch 20: Loss: 0.4252
# 	Epoch 52, Batch 30: Loss: 0.4988
# 	Epoch 52, Batch 40: Loss: 0.5013
# 	Epoch 52, Batch 50: Loss: 0.4186
# 	Epoch 52, Batch 60: Loss: 0.2771
# 	Epoch 52, Batch 70: Loss: 0.0535
# REAL TRAIN: train_loss: 0.19, train_acc: 92.18
# Epoch: 52, val_loss: 0.23, train_loss: 0.27 val_acc: 91.98, train_acc: 89.29
# 	Epoch 53, Batch 10: Loss: 0.2267
# 	Epoch 53, Batch 20: Loss: 0.3874
# 	Epoch 53, Batch 30: Loss: 0.4691
# 	Epoch 53, Batch 40: Loss: 0.4719
# 	Epoch 53, Batch 50: Loss: 0.4171
# 	Epoch 53, Batch 60: Loss: 0.2750
# 	Epoch 53, Batch 70: Loss: 0.0522
# REAL TRAIN: train_loss: 0.18, train_acc: 92.9
# Epoch: 53, val_loss: 0.21, train_loss: 0.26 val_acc: 92.37, train_acc: 89.47
# 	Epoch 54, Batch 10: Loss: 0.2136
# 	Epoch 54, Batch 20: Loss: 0.3369
# 	Epoch 54, Batch 30: Loss: 0.4332
# 	Epoch 54, Batch 40: Loss: 0.4500
# 	Epoch 54, Batch 50: Loss: 0.3890
# 	Epoch 54, Batch 60: Loss: 0.2577
# 	Epoch 54, Batch 70: Loss: 0.0499
# REAL TRAIN: train_loss: 0.18, train_acc: 93.32
# Epoch: 54, val_loss: 0.21, train_loss: 0.25 val_acc: 92.91, train_acc: 90.66
# 	Epoch 55, Batch 10: Loss: 0.2036
# 	Epoch 55, Batch 20: Loss: 0.3282
# 	Epoch 55, Batch 30: Loss: 0.4021
# 	Epoch 55, Batch 40: Loss: 0.4167
# 	Epoch 55, Batch 50: Loss: 0.3746
# 	Epoch 55, Batch 60: Loss: 0.2535
# 	Epoch 55, Batch 70: Loss: 0.0492
# REAL TRAIN: train_loss: 0.17, train_acc: 93.87
# Epoch: 55, val_loss: 0.20, train_loss: 0.25 val_acc: 93.14, train_acc: 90.22
# 	Epoch 56, Batch 10: Loss: 0.2183
# 	Epoch 56, Batch 20: Loss: 0.3474
# 	Epoch 56, Batch 30: Loss: 0.4232
# 	Epoch 56, Batch 40: Loss: 0.4333
# 	Epoch 56, Batch 50: Loss: 0.3816
# 	Epoch 56, Batch 60: Loss: 0.2541
# 	Epoch 56, Batch 70: Loss: 0.0486
# REAL TRAIN: train_loss: 0.17, train_acc: 93.87
# Epoch: 56, val_loss: 0.22, train_loss: 0.25 val_acc: 92.21, train_acc: 90.48
# 	Epoch 57, Batch 10: Loss: 0.2259
# 	Epoch 57, Batch 20: Loss: 0.3870
# 	Epoch 57, Batch 30: Loss: 0.4451
# 	Epoch 57, Batch 40: Loss: 0.4653
# 	Epoch 57, Batch 50: Loss: 0.3784
# 	Epoch 57, Batch 60: Loss: 0.2520
# 	Epoch 57, Batch 70: Loss: 0.0491
# REAL TRAIN: train_loss: 0.16, train_acc: 93.68
# Epoch: 57, val_loss: 0.21, train_loss: 0.25 val_acc: 92.52, train_acc: 90.04
# 	Epoch 58, Batch 10: Loss: 0.1986
# 	Epoch 58, Batch 20: Loss: 0.3508
# 	Epoch 58, Batch 30: Loss: 0.4235
# 	Epoch 58, Batch 40: Loss: 0.4346
# 	Epoch 58, Batch 50: Loss: 0.3676
# 	Epoch 58, Batch 60: Loss: 0.2411
# 	Epoch 58, Batch 70: Loss: 0.0471
# REAL TRAIN: train_loss: 0.16, train_acc: 93.85
# Epoch: 58, val_loss: 0.21, train_loss: 0.24 val_acc: 92.37, train_acc: 90.52
# 	Epoch 59, Batch 10: Loss: 0.2098
# 	Epoch 59, Batch 20: Loss: 0.3547
# 	Epoch 59, Batch 30: Loss: 0.4480
# 	Epoch 59, Batch 40: Loss: 0.4510
# 	Epoch 59, Batch 50: Loss: 0.3807
# 	Epoch 59, Batch 60: Loss: 0.2429
# 	Epoch 59, Batch 70: Loss: 0.0470
# REAL TRAIN: train_loss: 0.16, train_acc: 93.54
# Epoch: 59, val_loss: 0.21, train_loss: 0.24 val_acc: 92.60, train_acc: 90.74
# 	Epoch 60, Batch 10: Loss: 0.2204
# 	Epoch 60, Batch 20: Loss: 0.3671
# 	Epoch 60, Batch 30: Loss: 0.4385
# 	Epoch 60, Batch 40: Loss: 0.4566
# 	Epoch 60, Batch 50: Loss: 0.3933
# 	Epoch 60, Batch 60: Loss: 0.2513
# 	Epoch 60, Batch 70: Loss: 0.0491
# REAL TRAIN: train_loss: 0.16, train_acc: 94.09
# Epoch: 60, val_loss: 0.20, train_loss: 0.25 val_acc: 93.45, train_acc: 90.33
# 	Epoch 61, Batch 10: Loss: 0.2298
# 	Epoch 61, Batch 20: Loss: 0.3556
# 	Epoch 61, Batch 30: Loss: 0.4365
# 	Epoch 61, Batch 40: Loss: 0.4429
# 	Epoch 61, Batch 50: Loss: 0.3834
# 	Epoch 61, Batch 60: Loss: 0.2490
# 	Epoch 61, Batch 70: Loss: 0.0474
# REAL TRAIN: train_loss: 0.16, train_acc: 93.74
# Epoch: 61, val_loss: 0.22, train_loss: 0.24 val_acc: 92.29, train_acc: 90.66
# 	Epoch 62, Batch 10: Loss: 0.1954
# 	Epoch 62, Batch 20: Loss: 0.3628
# 	Epoch 62, Batch 30: Loss: 0.4319
# 	Epoch 62, Batch 40: Loss: 0.4381
# 	Epoch 62, Batch 50: Loss: 0.3601
# 	Epoch 62, Batch 60: Loss: 0.2377
# 	Epoch 62, Batch 70: Loss: 0.0456
# REAL TRAIN: train_loss: 0.17, train_acc: 93.85
# Epoch: 62, val_loss: 0.20, train_loss: 0.23 val_acc: 93.06, train_acc: 90.83
# 	Epoch 63, Batch 10: Loss: 0.2263
# 	Epoch 63, Batch 20: Loss: 0.3431
# 	Epoch 63, Batch 30: Loss: 0.4322
# 	Epoch 63, Batch 40: Loss: 0.4519
# 	Epoch 63, Batch 50: Loss: 0.3804
# 	Epoch 63, Batch 60: Loss: 0.2471
# 	Epoch 63, Batch 70: Loss: 0.0472
# REAL TRAIN: train_loss: 0.16, train_acc: 94.6
# Epoch: 63, val_loss: 0.21, train_loss: 0.24 val_acc: 93.29, train_acc: 90.68
# 	Epoch 64, Batch 10: Loss: 0.1638
# 	Epoch 64, Batch 20: Loss: 0.3174
# 	Epoch 64, Batch 30: Loss: 0.3717
# 	Epoch 64, Batch 40: Loss: 0.3859
# 	Epoch 64, Batch 50: Loss: 0.3458
# 	Epoch 64, Batch 60: Loss: 0.2278
# 	Epoch 64, Batch 70: Loss: 0.0449
# REAL TRAIN: train_loss: 0.15, train_acc: 94.51
# Epoch: 64, val_loss: 0.19, train_loss: 0.23 val_acc: 93.29, train_acc: 91.27
# 	Epoch 65, Batch 10: Loss: 0.1810
# 	Epoch 65, Batch 20: Loss: 0.3174
# 	Epoch 65, Batch 30: Loss: 0.3884
# 	Epoch 65, Batch 40: Loss: 0.3846
# 	Epoch 65, Batch 50: Loss: 0.3350
# 	Epoch 65, Batch 60: Loss: 0.2302
# 	Epoch 65, Batch 70: Loss: 0.0451
# REAL TRAIN: train_loss: 0.15, train_acc: 94.54
# Epoch: 65, val_loss: 0.19, train_loss: 0.23 val_acc: 93.60, train_acc: 91.32
# 	Epoch 66, Batch 10: Loss: 0.2033
# 	Epoch 66, Batch 20: Loss: 0.3347
# 	Epoch 66, Batch 30: Loss: 0.4143
# 	Epoch 66, Batch 40: Loss: 0.4157
# 	Epoch 66, Batch 50: Loss: 0.3596
# 	Epoch 66, Batch 60: Loss: 0.2363
# 	Epoch 66, Batch 70: Loss: 0.0441
# REAL TRAIN: train_loss: 0.17, train_acc: 93.9
# Epoch: 66, val_loss: 0.22, train_loss: 0.22 val_acc: 92.75, train_acc: 91.32
# 	Epoch 67, Batch 10: Loss: 0.2419
# 	Epoch 67, Batch 20: Loss: 0.3667
# 	Epoch 67, Batch 30: Loss: 0.4196
# 	Epoch 67, Batch 40: Loss: 0.4148
# 	Epoch 67, Batch 50: Loss: 0.3463
# 	Epoch 67, Batch 60: Loss: 0.2294
# 	Epoch 67, Batch 70: Loss: 0.0451
# REAL TRAIN: train_loss: 0.15, train_acc: 94.23
# Epoch: 67, val_loss: 0.18, train_loss: 0.23 val_acc: 93.75, train_acc: 91.41
# 	Epoch 68, Batch 10: Loss: 0.1832
# 	Epoch 68, Batch 20: Loss: 0.3088
# 	Epoch 68, Batch 30: Loss: 0.4066
# 	Epoch 68, Batch 40: Loss: 0.4285
# 	Epoch 68, Batch 50: Loss: 0.3706
# 	Epoch 68, Batch 60: Loss: 0.2366
# 	Epoch 68, Batch 70: Loss: 0.0457
# REAL TRAIN: train_loss: 0.17, train_acc: 93.87
# Epoch: 68, val_loss: 0.19, train_loss: 0.23 val_acc: 93.68, train_acc: 91.23
# 	Epoch 69, Batch 10: Loss: 0.1948
# 	Epoch 69, Batch 20: Loss: 0.3312
# 	Epoch 69, Batch 30: Loss: 0.4036
# 	Epoch 69, Batch 40: Loss: 0.3959
# 	Epoch 69, Batch 50: Loss: 0.3432
# 	Epoch 69, Batch 60: Loss: 0.2303
# 	Epoch 69, Batch 70: Loss: 0.0461
# REAL TRAIN: train_loss: 0.17, train_acc: 93.37
# Epoch: 69, val_loss: 0.23, train_loss: 0.23 val_acc: 91.36, train_acc: 91.60
# 	Epoch 70, Batch 10: Loss: 0.1904
# 	Epoch 70, Batch 20: Loss: 0.3479
# 	Epoch 70, Batch 30: Loss: 0.4468
# 	Epoch 70, Batch 40: Loss: 0.4428
# 	Epoch 70, Batch 50: Loss: 0.3851
# 	Epoch 70, Batch 60: Loss: 0.2477
# 	Epoch 70, Batch 70: Loss: 0.0478
# REAL TRAIN: train_loss: 0.15, train_acc: 94.73
# Epoch: 70, val_loss: 0.19, train_loss: 0.24 val_acc: 93.91, train_acc: 90.52
# 	Epoch 71, Batch 10: Loss: 0.2169
# 	Epoch 71, Batch 20: Loss: 0.3356
# 	Epoch 71, Batch 30: Loss: 0.4047
# 	Epoch 71, Batch 40: Loss: 0.4094
# 	Epoch 71, Batch 50: Loss: 0.3391
# 	Epoch 71, Batch 60: Loss: 0.2196
# 	Epoch 71, Batch 70: Loss: 0.0429
# REAL TRAIN: train_loss: 0.17, train_acc: 94.09
# Epoch: 71, val_loss: 0.19, train_loss: 0.22 val_acc: 93.91, train_acc: 91.58
# 	Epoch 72, Batch 10: Loss: 0.2015
# 	Epoch 72, Batch 20: Loss: 0.3213
# 	Epoch 72, Batch 30: Loss: 0.3955
# 	Epoch 72, Batch 40: Loss: 0.3894
# 	Epoch 72, Batch 50: Loss: 0.3407
# 	Epoch 72, Batch 60: Loss: 0.2212
# 	Epoch 72, Batch 70: Loss: 0.0438
# REAL TRAIN: train_loss: 0.17, train_acc: 93.85
# Epoch: 72, val_loss: 0.21, train_loss: 0.22 val_acc: 93.45, train_acc: 91.36
# 	Epoch 73, Batch 10: Loss: 0.2192
# 	Epoch 73, Batch 20: Loss: 0.3373
# 	Epoch 73, Batch 30: Loss: 0.4176
# 	Epoch 73, Batch 40: Loss: 0.4036
# 	Epoch 73, Batch 50: Loss: 0.3481
# 	Epoch 73, Batch 60: Loss: 0.2255
# 	Epoch 73, Batch 70: Loss: 0.0441
# REAL TRAIN: train_loss: 0.14, train_acc: 95.09
# Epoch: 73, val_loss: 0.19, train_loss: 0.23 val_acc: 93.45, train_acc: 91.43
# 	Epoch 74, Batch 10: Loss: 0.1912
# 	Epoch 74, Batch 20: Loss: 0.3024
# 	Epoch 74, Batch 30: Loss: 0.3657
# 	Epoch 74, Batch 40: Loss: 0.3823
# 	Epoch 74, Batch 50: Loss: 0.3309
# 	Epoch 74, Batch 60: Loss: 0.2263
# 	Epoch 74, Batch 70: Loss: 0.0439
# Epoch 00074: reducing learning rate of group 0 to 4.0000e-05.
# REAL TRAIN: train_loss: 0.15, train_acc: 94.56
# Epoch: 74, val_loss: 0.19, train_loss: 0.22 val_acc: 94.06, train_acc: 91.36
# 	Epoch 75, Batch 10: Loss: 0.2162
# 	Epoch 75, Batch 20: Loss: 0.3498
# 	Epoch 75, Batch 30: Loss: 0.3922
# 	Epoch 75, Batch 40: Loss: 0.4084
# 	Epoch 75, Batch 50: Loss: 0.3500
# 	Epoch 75, Batch 60: Loss: 0.2270
# 	Epoch 75, Batch 70: Loss: 0.0436
# REAL TRAIN: train_loss: 0.14, train_acc: 94.89
# Epoch: 75, val_loss: 0.19, train_loss: 0.22 val_acc: 93.91, train_acc: 91.30
# 	Epoch 76, Batch 10: Loss: 0.2075
# 	Epoch 76, Batch 20: Loss: 0.3442
# 	Epoch 76, Batch 30: Loss: 0.4096
# 	Epoch 76, Batch 40: Loss: 0.3993
# 	Epoch 76, Batch 50: Loss: 0.3404
# 	Epoch 76, Batch 60: Loss: 0.2221
# 	Epoch 76, Batch 70: Loss: 0.0427
# REAL TRAIN: train_loss: 0.13, train_acc: 95.06
# Epoch: 76, val_loss: 0.18, train_loss: 0.22 val_acc: 94.14, train_acc: 91.71
# 	Epoch 77, Batch 10: Loss: 0.1850
# 	Epoch 77, Batch 20: Loss: 0.2858
# 	Epoch 77, Batch 30: Loss: 0.3717
# 	Epoch 77, Batch 40: Loss: 0.3856
# 	Epoch 77, Batch 50: Loss: 0.3366
# 	Epoch 77, Batch 60: Loss: 0.2289
# 	Epoch 77, Batch 70: Loss: 0.0447
# REAL TRAIN: train_loss: 0.14, train_acc: 94.76
# Epoch: 77, val_loss: 0.18, train_loss: 0.23 val_acc: 94.06, train_acc: 91.25
# > Early stopping <

# %% [markdown]
# # Analizamos los datos

# %%
model.load_state_dict(early_stopper.best_model)
model.eval()

cm = metrics.confusion_matrix(targets, preds)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Gráfico de la precisión de entrenamiento y validación
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_acc_h, label='Train Accuracy')
plt.plot(val_acc_h, label='Validation Accuracy')
#TMP==========
plt.plot(tmp_acc, label='REAL TRAIN ACC')
#=============
plt.title('Train vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Gráfico de la pérdida de entrenamiento y validación
plt.subplot(1, 2, 2)
plt.plot(train_loss_h, label='Train Loss')
plt.plot(val_loss_h, label='Validation Loss')
#TMP==========
plt.plot(tmp_loss, label='REAL TRAIN LOSS')
#=============
plt.title('Train vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# cjto train
train_preds, train_reals, train_loss, train_acc = eval(model, train_loader, device=device, criterion=criterion)
print("Train Dataset ----------------------------------------------------------------")
print(f"train_loss: {train_loss} - train_acc: {train_acc}")
print(metrics.classification_report(train_reals, train_preds, zero_division=0))


# cjto val
val_preds, val_reals, val_loss, val_acc = eval(model, val_loader, device=device, criterion=criterion)
print("Val Dataset ----------------------------------------------------------------")
print(f"val_loss: {val_loss} - val_acc: {val_acc}")
print(metrics.classification_report(val_reals, val_preds, zero_division=0))

# cjto tests
test_preds, test_reals, test_loss, test_acc = eval(model, test_loader, device=device, criterion=criterion)
cm = metrics.confusion_matrix(test_reals, test_preds)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Tests Dataset")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print("Tests Dataset ----------------------------------------------------------------")
print(f"test_loss: {test_loss} - test_acc: {test_acc}")
print(metrics.classification_report(test_reals, test_preds, zero_division=0))
# Out:
# Train Dataset ----------------------------------------------------------------
# train_loss: 0.1341746026571368 - train_acc: 0.9490965182899956
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1134
#            1       0.97      0.91      0.94      1134
#            2       0.89      0.92      0.90      1135
#            3       0.97      0.98      0.98      1135
#
#     accuracy                           0.95      4538
#    macro avg       0.95      0.95      0.95      4538
# weighted avg       0.95      0.95      0.95      4538
#
# Val Dataset ----------------------------------------------------------------
# val_loss: 0.18236070516563596 - val_acc: 0.9406322282189669
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       325
#            1       0.98      0.89      0.93       324
#            2       0.85      0.94      0.90       324
#            3       0.97      0.96      0.97       324
#
#     accuracy                           0.94      1297
#    macro avg       0.94      0.94      0.94      1297
# weighted avg       0.94      0.94      0.94      1297
# Tests Dataset ----------------------------------------------------------------
# test_loss: 0.2812839421358975 - test_acc: 0.9198767334360555
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       162
#            1       0.93      0.83      0.88       163
#            2       0.83      0.93      0.87       162
#            3       0.97      0.96      0.97       162
#
#     accuracy                           0.92       649
#    macro avg       0.92      0.92      0.92       649
# weighted avg       0.92      0.92      0.92       649

# %%
save_model(model, "/kaggle/working/model.pth", complete=True)
