# %%
# %matplotlib inline

# imports
import pandas as pd
import numpy as np

from PIL import Image
from torchvision.io import read_image, ImageReadMode
import os

from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# const

#DIR_PATH = "../dataset/brain-tumor-mri"
DIR_PATH = "/kaggle/input/brain-tumor-mri-dataset"

LABELS = ["notumor", "glioma", "meningioma", "pituitary"]

TRAIN_PERCENT = .7
VAL_PERCENT = .2
TEST_PERCENT = .1

IMAGE_SIZE = 128

RANDOM_STATE = None

BATCH_SIZE = 64
LEARNING_RATE = 0.001
NUM_EPOCH = 200
EARLY_PATIENCE=10

# %% [markdown]
# # Data Manipulation

# %%
# creamos un dataset de la forma (path, class)
dataset = pd.DataFrame(columns = ["path", "label"])


for dir in os.listdir(DIR_PATH):
    for label in os.listdir(os.path.join(DIR_PATH, dir)):
        for img in os.listdir(os.path.join(DIR_PATH, dir, label)):
            dataset.loc[len(dataset)] = {"path": os.path.join(DIR_PATH, dir, label, img),
                                   "label": LABELS.index(label) }


print("num elementos:", dataset.count(axis=1).size)
print(dataset.head())
# Out:
# num elementos: 7023
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      3

# %%
min_cat_size = dataset.label.value_counts().min()

print("> Cantidad de imagenes de la categoria que menos tiene:", min_cat_size)
# Out:
# > Cantidad de imagenes de la categoria que menos tiene: 1621

# %%
# Hacemos que todos tengan los mismos elementos
dataset = pd.DataFrame(dataset.groupby("label").apply(lambda label: label.sample(min_cat_size, random_state=RANDOM_STATE)).reset_index(drop=True))

print("> Cantidad de elementos: ", dataset.count(axis=1).size)
print(dataset.label.value_counts())
print(dataset.head())
# Out:
# > Cantidad de elementos:  6484
# label
# 0    1621
# 1    1621
# 2    1621
# 3    1621
# Name: count, dtype: int64
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 2  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      0

# %%
# separamos en los cjtos de entrenamiento
train_dataset, tmp = train_test_split(dataset, train_size=TRAIN_PERCENT, stratify=dataset["label"], shuffle=True, random_state=RANDOM_STATE)
val_dataset, test_dataset = train_test_split(tmp, test_size=TEST_PERCENT/(TEST_PERCENT+VAL_PERCENT), stratify=tmp["label"], shuffle=True, random_state=RANDOM_STATE)

print("> train", train_dataset.count(axis=1).size, train_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(train_dataset.label.value_counts())
print()

print("> val", val_dataset.count(axis=1).size, val_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(val_dataset.label.value_counts())
print()

print("> test", test_dataset.count(axis=1).size, test_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(test_dataset.label.value_counts())
print()
# Out:
# > train 4538 0.6998766193707588
# label
# 0    1135
# 1    1135
# 2    1134
# 3    1134
# Name: count, dtype: int64
#
# > val 1297 0.2000308451573103
# label
# 2    325
# 3    324
# 0    324
# 1    324
# Name: count, dtype: int64
#
# > test 649 0.10009253547193091
# label
# 3    163
# 0    162
# 1    162
# 2    162
# Name: count, dtype: int64

# %%
# Comprobamos que son disjuntos
print((train_dataset[ "path" ].isin(test_dataset["path"] ) == True).value_counts())
print((train_dataset[ "path" ].isin(val_dataset["path"] ) == True).value_counts())
print((val_dataset[ "path" ].isin(test_dataset["path"]) == True).value_counts())
# Out:
# path
# False    4538
# Name: count, dtype: int64
# path
# False    4538
# Name: count, dtype: int64
# path
# False    1297
# Name: count, dtype: int64

# %% [markdown]
# # Preparations

# %% [markdown]
# ## Classes

# %%
class CustomDataset(Dataset):
    
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
    
    def __len__(self):
        return self.dataframe.count(axis=1).size
    
    def __getitem__(self, idx) -> (str, int):
        
        row = self.dataframe.iloc[idx]
        img, label = row.path, row.label

        img = read_image(img, mode=ImageReadMode.GRAY)
        if self.transform: img = self.transform(img)

        return img, label

# %%
class EarlyStopper:
    
    def __init__(self, patience=5, min_delta=0, callback=lambda **_: None):
        self.patience = patience
        self.min_delta = min_delta
        self.callback = callback

        self.counter = 1

        self.best_model = None
        self.best_loss = float("inf")

    def __call__(self, val_loss, model):

        if val_loss < (self.best_loss - self.min_delta):
            self.best_loss = val_loss
            self.counter = 0

            self.best_model = model.state_dict()
            return False


        self.counter += 1
        if self.counter >= self.patience:
            self.callback(counter=self.counter, best_loss=self.best_loss, best_model=self.best_model)
            return True

    def reset(self):
        self.early_stop = False
        self.counter = 1

# %%
class CNN(nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        
        # Capas convolucionales
        self.convin = nn.Conv2d( 1, 64, kernel_size=3, stride=1, padding=1)
        self.conv1 = nn.Conv2d( 64, 64, kernel_size=3, stride=1, padding=1)
        self.convout = nn.Conv2d( 64, 128, kernel_size=3, stride=1, padding=1)

        # Capas Fully connected 
        # ajustado para 128
        self.fcin = nn.Linear(in_features=IMAGE_SIZE * 16 * 16, out_features=128)
        self.fcout = nn.Linear(in_features=128, out_features=len(LABELS))

        # BatchNorm2d
        self.bn1 = nn.BatchNorm2d(64)
        self.bnout = nn.BatchNorm2d(128)
        
        # Max pooling
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        # Capa Dropout 
        self.dropout25 = nn.Dropout(0.25)
        
            

    def forward(self, x):

        # conv in
        x = self.pool(F.relu(self.convin(x)))

        # conv 1
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout25(x)

        # conv out
        x = self.pool(F.relu(self.bnout(self.convout(x)))) 
        x = self.dropout25(x)
    
        # flatten
        x = x.view(-1, 128*16*16)

        # fully in
        x = F.relu(self.fcin(x))
        x = self.dropout25(x)

        # fully out
        x = self.fcout(x)
        
        return x

# %% [markdown]
# ## Functions

# %%
def eval(model, loader, *, device = None, criterion = None):
    """returns pred, real, accuracy, val_loss"""
    if not (device and criterion): raise Exception("Params needed")

    model.eval()

    corrects = 0

    pred = []
    real = []
    loss = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in loader:
            
            imgs, labels = imgs.to(device), labels.to(device)

            outs = model(imgs)
            loss += criterion(outs.data, labels).item()

            _, predicted = torch.max(outs.data, 1)
            
            total += labels.size(0)
            pred.extend(predicted.tolist())
            real.extend(labels.tolist())

            corrects += (predicted == labels).sum().item()
    
    return  pred, real, loss/len(loader), corrects/total

# %%
    #TMP============
    tmp_loss = []
    tmp_acc = []
    #==============

# %%
def train_loop(model, loader, *, optimizer, criterion, num_epoch=100, device=torch.device("cuda" if torch.cuda.is_available() else "cpu"), train_loss_h=[], train_acc_h=[], val_loss_h=[] ,val_acc_h=[], callback=lambda **_: None, early_callback=lambda **_: None, scheduler, val_loader):
    if not (optimizer and criterion and early_stopper and scheduler): raise Exception("Params needed")
    
    val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
    callback(epoch=0, val_acc=val_acc, val_loss=val_loss, train_loss=float("inf"), train_acc=0)
    

    for epoch in range(num_epoch):

        running_loss = 0.0
        corrects = 0
        total = 0

        model.train()

        for i, (imgs, labels) in enumerate(loader, 1):

            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()

            outs = model(imgs)
            loss = criterion(outs, labels)
            
            running_loss += loss.item()
            
            loss.backward()
            optimizer.step()

            # extra for analytics
            _, predicted = torch.max(outs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()
            # ==================

            if not i % 10:
                print(f"\tEpoch {epoch+1}, Batch {i}: Loss: {running_loss*(len(loader)-i+1)/(10*len(loader)):.4f}")
            
        val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
        scheduler.step(val_loss)
        
        # extra for analytics
        train_loss = running_loss/len(loader)
        train_loss_h.append(train_loss)
        train_acc = 100*corrects/total
        train_acc_h.append(train_acc)

        val_loss_h.append(val_loss)
        val_acc_h.append(val_acc*100)
        # ===================
        
        #TMP================
        _, _, tmploss, tmpacc = eval(model, train_loader, device=device, criterion=criterion)
        tmp_loss.append(tmploss)
        tmp_acc.append(tmpacc*100)
        print(f"REAL TRAIN: train_loss: {tmploss:.2f}, train_acc: {tmpacc*100:.4}")
        #==================

        callback(epoch=epoch+1, val_acc=val_acc, val_loss=val_loss, train_loss=train_loss, train_acc=train_acc)

        if(early_stopper(val_loss, model)): break

    return train_acc_h, val_acc_h, train_loss_h, val_loss_h, val_preds, val_labels

# %% [markdown]
# # Utils

# %%
def save_model(model, path, complete=False):
    try:
        torch.save(model if complete else model.state_dict(), path)
    except Exception as e:
        print("Error al guardar el model:", e)

# %%
def show_img(img, label):
    print('Label: ', dataset.label[label], "(" + str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %% [markdown]
# ## Dataset statistics

# %%
unnormalized_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.ToTensor()
])

unnormalized_dataset = CustomDataset(dataset, transform=unnormalized_transforms)
loader = DataLoader(unnormalized_dataset, batch_size=1, shuffle=False)

sum_intensity = 0.0
sum_squared_intensity = 0.0
n_samples = 0

for imgs, _ in loader:
    
    sum_intensity += imgs.sum()
    sum_squared_intensity += (imgs ** 2).sum()
    n_samples += imgs.numel()

mean = sum_intensity / n_samples
std = torch.sqrt(sum_squared_intensity / n_samples - mean ** 2)

print(mean)
print(std)
# Out:
# tensor(0.1836)
# tensor(0.1944)

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.RandomRotation(180),            
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

test_valid_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE),antialias=True),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])


train_dataset = CustomDataset(train_dataset, transform=train_transform)
val_dataset = CustomDataset(val_dataset, transform=test_valid_transforms)
test_dataset = CustomDataset(test_dataset, transform=test_valid_transforms)

# Acceder e imprimir las primeras 5 muestras del dataset
for i in range(5):
    image, label = train_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = val_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = test_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")

# Imprimir los valores de la media y la desviación estándar
print(f"Media: {mean}, Desviación Estándar: {std}")
# Out:
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 1
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 1
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 0
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 128, 128]), Etiqueta - 2
# Media: 0.1836220771074295, Desviación Estándar: 0.19443011283874512

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

# Verificar DataLoader
for images, labels in train_loader:
    print(f"Batch de imágenes: {images.shape}, Batch de etiquetas: {labels.shape}")
    break

# Carga una imagen de prueba
img, label = test_dataset[45]
show_img(img, label)
# Out:
# Batch de imágenes: torch.Size([64, 1, 128, 128]), Batch de etiquetas: torch.Size([64])
# Label:  0 (3)

# %% [markdown]
# ## Comprobaciones previas de la GPU

# %%
print(torch.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo configurado para usar: {device}")

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.0.0
# Dispositivo configurado para usar: cuda
# True
# Tesla P100-PCIE-16GB

# %% [markdown]
# ## Entrenamos

# %%
def early_callback(**kwargs): print("> Early stopping <")

early_stopper = EarlyStopper(patience=EARLY_PATIENCE, min_delta=.001, callback=early_callback)

# %%
model = CNN()
if torch.cuda.device_count() > 1: model = nn.DataParallel(model)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss().to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, patience=10, verbose=True)

def callback(**kwargs):
    print(f"Epoch: {kwargs['epoch']}, val_loss: {(kwargs['val_loss']):.2f}, train_loss: {(kwargs['train_loss']):.2f} val_acc: {(kwargs['val_acc']*100):.2f}, train_acc: {(kwargs['train_acc']):.2f}")

train_acc_h, val_acc_h, train_loss_h, val_loss_h, preds, targets = train_loop(model, train_loader,
           val_loader=val_loader,                                                                                  
           optimizer=optimizer,
           criterion=criterion,
           num_epoch=NUM_EPOCH,
           device=device,
           callback=callback,
           scheduler=scheduler
           )
# Out:
# Epoch: 0, val_loss: 1.39, train_loss: inf val_acc: 26.29, train_acc: 0.00
# 	Epoch 1, Batch 10: Loss: 5.7813
# 	Epoch 1, Batch 20: Loss: 6.8061
# 	Epoch 1, Batch 30: Loss: 6.3154
# 	Epoch 1, Batch 40: Loss: 5.3227
# 	Epoch 1, Batch 50: Loss: 3.9848
# 	Epoch 1, Batch 60: Loss: 2.3430
# 	Epoch 1, Batch 70: Loss: 0.4193
# REAL TRAIN: train_loss: 0.92, train_acc: 62.25
# Epoch: 1, val_loss: 0.97, train_loss: 2.11 val_acc: 60.52, train_acc: 49.87
# 	Epoch 2, Batch 10: Loss: 0.8630
# 	Epoch 2, Batch 20: Loss: 1.4595
# 	Epoch 2, Batch 30: Loss: 1.7275
# 	Epoch 2, Batch 40: Loss: 1.7790
# 	Epoch 2, Batch 50: Loss: 1.5133
# 	Epoch 2, Batch 60: Loss: 0.9875
# 	Epoch 2, Batch 70: Loss: 0.1903
# REAL TRAIN: train_loss: 0.84, train_acc: 65.65
# Epoch: 2, val_loss: 0.85, train_loss: 0.96 val_acc: 63.84, train_acc: 59.50
# 	Epoch 3, Batch 10: Loss: 0.7740
# 	Epoch 3, Batch 20: Loss: 1.2945
# 	Epoch 3, Batch 30: Loss: 1.5781
# 	Epoch 3, Batch 40: Loss: 1.5982
# 	Epoch 3, Batch 50: Loss: 1.3586
# 	Epoch 3, Batch 60: Loss: 0.8908
# 	Epoch 3, Batch 70: Loss: 0.1708
# REAL TRAIN: train_loss: 0.76, train_acc: 66.68
# Epoch: 3, val_loss: 0.81, train_loss: 0.87 val_acc: 64.23, train_acc: 64.17
# 	Epoch 4, Batch 10: Loss: 0.7078
# 	Epoch 4, Batch 20: Loss: 1.2005
# 	Epoch 4, Batch 30: Loss: 1.4442
# 	Epoch 4, Batch 40: Loss: 1.4722
# 	Epoch 4, Batch 50: Loss: 1.2456
# 	Epoch 4, Batch 60: Loss: 0.8043
# 	Epoch 4, Batch 70: Loss: 0.1567
# REAL TRAIN: train_loss: 0.70, train_acc: 71.57
# Epoch: 4, val_loss: 0.65, train_loss: 0.79 val_acc: 72.94, train_acc: 67.36
# 	Epoch 5, Batch 10: Loss: 0.6428
# 	Epoch 5, Batch 20: Loss: 1.0757
# 	Epoch 5, Batch 30: Loss: 1.3153
# 	Epoch 5, Batch 40: Loss: 1.3204
# 	Epoch 5, Batch 50: Loss: 1.1436
# 	Epoch 5, Batch 60: Loss: 0.7557
# 	Epoch 5, Batch 70: Loss: 0.1456
# REAL TRAIN: train_loss: 0.65, train_acc: 72.79
# Epoch: 5, val_loss: 0.66, train_loss: 0.74 val_acc: 70.32, train_acc: 69.00
# 	Epoch 6, Batch 10: Loss: 0.6392
# 	Epoch 6, Batch 20: Loss: 1.0847
# 	Epoch 6, Batch 30: Loss: 1.3021
# 	Epoch 6, Batch 40: Loss: 1.3495
# 	Epoch 6, Batch 50: Loss: 1.1717
# 	Epoch 6, Batch 60: Loss: 0.7649
# 	Epoch 6, Batch 70: Loss: 0.1499
# REAL TRAIN: train_loss: 0.69, train_acc: 72.15
# Epoch: 6, val_loss: 0.74, train_loss: 0.76 val_acc: 71.32, train_acc: 68.71
# 	Epoch 7, Batch 10: Loss: 0.6054
# 	Epoch 7, Batch 20: Loss: 1.0321
# 	Epoch 7, Batch 30: Loss: 1.2660
# 	Epoch 7, Batch 40: Loss: 1.2677
# 	Epoch 7, Batch 50: Loss: 1.0933
# 	Epoch 7, Batch 60: Loss: 0.7163
# 	Epoch 7, Batch 70: Loss: 0.1381
# REAL TRAIN: train_loss: 0.62, train_acc: 73.8
# Epoch: 7, val_loss: 0.58, train_loss: 0.70 val_acc: 76.56, train_acc: 70.91
# 	Epoch 8, Batch 10: Loss: 0.6370
# 	Epoch 8, Batch 20: Loss: 1.0324
# 	Epoch 8, Batch 30: Loss: 1.2459
# 	Epoch 8, Batch 40: Loss: 1.2509
# 	Epoch 8, Batch 50: Loss: 1.0612
# 	Epoch 8, Batch 60: Loss: 0.6967
# 	Epoch 8, Batch 70: Loss: 0.1362
# REAL TRAIN: train_loss: 0.59, train_acc: 74.88
# Epoch: 8, val_loss: 0.61, train_loss: 0.69 val_acc: 75.40, train_acc: 71.02
# 	Epoch 9, Batch 10: Loss: 0.5727
# 	Epoch 9, Batch 20: Loss: 0.9575
# 	Epoch 9, Batch 30: Loss: 1.1791
# 	Epoch 9, Batch 40: Loss: 1.1756
# 	Epoch 9, Batch 50: Loss: 1.0165
# 	Epoch 9, Batch 60: Loss: 0.6708
# 	Epoch 9, Batch 70: Loss: 0.1309
# REAL TRAIN: train_loss: 0.65, train_acc: 73.56
# Epoch: 9, val_loss: 0.67, train_loss: 0.66 val_acc: 72.55, train_acc: 71.73
# 	Epoch 10, Batch 10: Loss: 0.5257
# 	Epoch 10, Batch 20: Loss: 0.8927
# 	Epoch 10, Batch 30: Loss: 1.0964
# 	Epoch 10, Batch 40: Loss: 1.1139
# 	Epoch 10, Batch 50: Loss: 0.9758
# 	Epoch 10, Batch 60: Loss: 0.6497
# 	Epoch 10, Batch 70: Loss: 0.1264
# REAL TRAIN: train_loss: 0.68, train_acc: 72.65
# Epoch: 10, val_loss: 0.67, train_loss: 0.64 val_acc: 74.09, train_acc: 72.59
# 	Epoch 11, Batch 10: Loss: 0.5927
# 	Epoch 11, Batch 20: Loss: 0.9626
# 	Epoch 11, Batch 30: Loss: 1.1340
# 	Epoch 11, Batch 40: Loss: 1.1313
# 	Epoch 11, Batch 50: Loss: 0.9723
# 	Epoch 11, Batch 60: Loss: 0.6411
# 	Epoch 11, Batch 70: Loss: 0.1240
# REAL TRAIN: train_loss: 0.54, train_acc: 77.74
# Epoch: 11, val_loss: 0.55, train_loss: 0.63 val_acc: 78.64, train_acc: 72.81
# 	Epoch 12, Batch 10: Loss: 0.4880
# 	Epoch 12, Batch 20: Loss: 0.8400
# 	Epoch 12, Batch 30: Loss: 1.0286
# 	Epoch 12, Batch 40: Loss: 1.0600
# 	Epoch 12, Batch 50: Loss: 0.9140
# 	Epoch 12, Batch 60: Loss: 0.6026
# 	Epoch 12, Batch 70: Loss: 0.1172
# REAL TRAIN: train_loss: 0.53, train_acc: 77.63
# Epoch: 12, val_loss: 0.54, train_loss: 0.59 val_acc: 76.10, train_acc: 73.80
# 	Epoch 13, Batch 10: Loss: 0.5016
# 	Epoch 13, Batch 20: Loss: 0.8670
# 	Epoch 13, Batch 30: Loss: 1.0518
# 	Epoch 13, Batch 40: Loss: 1.0591
# 	Epoch 13, Batch 50: Loss: 0.9158
# 	Epoch 13, Batch 60: Loss: 0.5990
# 	Epoch 13, Batch 70: Loss: 0.1177
# REAL TRAIN: train_loss: 0.54, train_acc: 78.65
# Epoch: 13, val_loss: 0.59, train_loss: 0.60 val_acc: 78.49, train_acc: 75.17
# 	Epoch 14, Batch 10: Loss: 0.5683
# 	Epoch 14, Batch 20: Loss: 0.9579
# 	Epoch 14, Batch 30: Loss: 1.0776
# 	Epoch 14, Batch 40: Loss: 1.0826
# 	Epoch 14, Batch 50: Loss: 0.9197
# 	Epoch 14, Batch 60: Loss: 0.6022
# 	Epoch 14, Batch 70: Loss: 0.1148
# REAL TRAIN: train_loss: 0.51, train_acc: 78.65
# Epoch: 14, val_loss: 0.49, train_loss: 0.58 val_acc: 80.49, train_acc: 76.16
# 	Epoch 15, Batch 10: Loss: 0.4775
# 	Epoch 15, Batch 20: Loss: 0.7922
# 	Epoch 15, Batch 30: Loss: 0.9853
# 	Epoch 15, Batch 40: Loss: 0.9968
# 	Epoch 15, Batch 50: Loss: 0.8583
# 	Epoch 15, Batch 60: Loss: 0.5556
# 	Epoch 15, Batch 70: Loss: 0.1074
# REAL TRAIN: train_loss: 0.59, train_acc: 75.87
# Epoch: 15, val_loss: 0.62, train_loss: 0.55 val_acc: 73.25, train_acc: 76.42
# 	Epoch 16, Batch 10: Loss: 0.5411
# 	Epoch 16, Batch 20: Loss: 0.8505
# 	Epoch 16, Batch 30: Loss: 1.0210
# 	Epoch 16, Batch 40: Loss: 1.0185
# 	Epoch 16, Batch 50: Loss: 0.8787
# 	Epoch 16, Batch 60: Loss: 0.5691
# 	Epoch 16, Batch 70: Loss: 0.1100
# REAL TRAIN: train_loss: 0.71, train_acc: 70.78
# Epoch: 16, val_loss: 0.75, train_loss: 0.56 val_acc: 68.39, train_acc: 77.30
# 	Epoch 17, Batch 10: Loss: 0.4709
# 	Epoch 17, Batch 20: Loss: 0.7345
# 	Epoch 17, Batch 30: Loss: 0.9290
# 	Epoch 17, Batch 40: Loss: 0.9416
# 	Epoch 17, Batch 50: Loss: 0.8114
# 	Epoch 17, Batch 60: Loss: 0.5355
# 	Epoch 17, Batch 70: Loss: 0.1024
# REAL TRAIN: train_loss: 0.43, train_acc: 84.0
# Epoch: 17, val_loss: 0.47, train_loss: 0.52 val_acc: 84.43, train_acc: 78.05
# 	Epoch 18, Batch 10: Loss: 0.4042
# 	Epoch 18, Batch 20: Loss: 0.7076
# 	Epoch 18, Batch 30: Loss: 0.8629
# 	Epoch 18, Batch 40: Loss: 0.8859
# 	Epoch 18, Batch 50: Loss: 0.7797
# 	Epoch 18, Batch 60: Loss: 0.5148
# 	Epoch 18, Batch 70: Loss: 0.1023
# REAL TRAIN: train_loss: 0.43, train_acc: 82.99
# Epoch: 18, val_loss: 0.46, train_loss: 0.52 val_acc: 84.66, train_acc: 78.93
# 	Epoch 19, Batch 10: Loss: 0.4285
# 	Epoch 19, Batch 20: Loss: 0.7120
# 	Epoch 19, Batch 30: Loss: 0.8578
# 	Epoch 19, Batch 40: Loss: 0.8791
# 	Epoch 19, Batch 50: Loss: 0.7690
# 	Epoch 19, Batch 60: Loss: 0.5006
# 	Epoch 19, Batch 70: Loss: 0.0965
# REAL TRAIN: train_loss: 0.46, train_acc: 81.64
# Epoch: 19, val_loss: 0.51, train_loss: 0.49 val_acc: 80.19, train_acc: 79.93
# 	Epoch 20, Batch 10: Loss: 0.4195
# 	Epoch 20, Batch 20: Loss: 0.7284
# 	Epoch 20, Batch 30: Loss: 0.8680
# 	Epoch 20, Batch 40: Loss: 0.8863
# 	Epoch 20, Batch 50: Loss: 0.7633
# 	Epoch 20, Batch 60: Loss: 0.4939
# 	Epoch 20, Batch 70: Loss: 0.0969
# REAL TRAIN: train_loss: 0.44, train_acc: 82.7
# Epoch: 20, val_loss: 0.43, train_loss: 0.49 val_acc: 84.27, train_acc: 79.86
# 	Epoch 21, Batch 10: Loss: 0.3817
# 	Epoch 21, Batch 20: Loss: 0.6632
# 	Epoch 21, Batch 30: Loss: 0.8225
# 	Epoch 21, Batch 40: Loss: 0.8561
# 	Epoch 21, Batch 50: Loss: 0.7310
# 	Epoch 21, Batch 60: Loss: 0.4822
# 	Epoch 21, Batch 70: Loss: 0.0940
# REAL TRAIN: train_loss: 0.40, train_acc: 84.55
# Epoch: 21, val_loss: 0.42, train_loss: 0.48 val_acc: 84.81, train_acc: 80.41
# 	Epoch 22, Batch 10: Loss: 0.4517
# 	Epoch 22, Batch 20: Loss: 0.7743
# 	Epoch 22, Batch 30: Loss: 0.8825
# 	Epoch 22, Batch 40: Loss: 0.8951
# 	Epoch 22, Batch 50: Loss: 0.7652
# 	Epoch 22, Batch 60: Loss: 0.5024
# 	Epoch 22, Batch 70: Loss: 0.0967
# REAL TRAIN: train_loss: 0.38, train_acc: 84.84
# Epoch: 22, val_loss: 0.39, train_loss: 0.49 val_acc: 84.58, train_acc: 80.37
# 	Epoch 23, Batch 10: Loss: 0.4379
# 	Epoch 23, Batch 20: Loss: 0.7444
# 	Epoch 23, Batch 30: Loss: 0.8734
# 	Epoch 23, Batch 40: Loss: 0.8622
# 	Epoch 23, Batch 50: Loss: 0.7367
# 	Epoch 23, Batch 60: Loss: 0.4868
# 	Epoch 23, Batch 70: Loss: 0.0935
# REAL TRAIN: train_loss: 0.48, train_acc: 81.03
# Epoch: 23, val_loss: 0.45, train_loss: 0.47 val_acc: 83.27, train_acc: 80.26
# 	Epoch 24, Batch 10: Loss: 0.3993
# 	Epoch 24, Batch 20: Loss: 0.6494
# 	Epoch 24, Batch 30: Loss: 0.8206
# 	Epoch 24, Batch 40: Loss: 0.8129
# 	Epoch 24, Batch 50: Loss: 0.7108
# 	Epoch 24, Batch 60: Loss: 0.4648
# 	Epoch 24, Batch 70: Loss: 0.0906
# REAL TRAIN: train_loss: 0.39, train_acc: 85.57
# Epoch: 24, val_loss: 0.43, train_loss: 0.46 val_acc: 83.04, train_acc: 81.51
# 	Epoch 25, Batch 10: Loss: 0.3977
# 	Epoch 25, Batch 20: Loss: 0.6824
# 	Epoch 25, Batch 30: Loss: 0.8260
# 	Epoch 25, Batch 40: Loss: 0.8276
# 	Epoch 25, Batch 50: Loss: 0.6929
# 	Epoch 25, Batch 60: Loss: 0.4583
# 	Epoch 25, Batch 70: Loss: 0.0891
# REAL TRAIN: train_loss: 0.41, train_acc: 83.41
# Epoch: 25, val_loss: 0.45, train_loss: 0.45 val_acc: 82.19, train_acc: 82.02
# 	Epoch 26, Batch 10: Loss: 0.3671
# 	Epoch 26, Batch 20: Loss: 0.6222
# 	Epoch 26, Batch 30: Loss: 0.7592
# 	Epoch 26, Batch 40: Loss: 0.7805
# 	Epoch 26, Batch 50: Loss: 0.6834
# 	Epoch 26, Batch 60: Loss: 0.4528
# 	Epoch 26, Batch 70: Loss: 0.0885
# REAL TRAIN: train_loss: 0.46, train_acc: 82.99
# Epoch: 26, val_loss: 0.47, train_loss: 0.45 val_acc: 83.11, train_acc: 82.04
# 	Epoch 27, Batch 10: Loss: 0.3785
# 	Epoch 27, Batch 20: Loss: 0.6215
# 	Epoch 27, Batch 30: Loss: 0.7360
# 	Epoch 27, Batch 40: Loss: 0.7654
# 	Epoch 27, Batch 50: Loss: 0.6623
# 	Epoch 27, Batch 60: Loss: 0.4283
# 	Epoch 27, Batch 70: Loss: 0.0850
# REAL TRAIN: train_loss: 0.92, train_acc: 68.38
# Epoch: 27, val_loss: 0.88, train_loss: 0.43 val_acc: 70.39, train_acc: 82.44
# 	Epoch 28, Batch 10: Loss: 0.3995
# 	Epoch 28, Batch 20: Loss: 0.6568
# 	Epoch 28, Batch 30: Loss: 0.7839
# 	Epoch 28, Batch 40: Loss: 0.7943
# 	Epoch 28, Batch 50: Loss: 0.6919
# 	Epoch 28, Batch 60: Loss: 0.4540
# 	Epoch 28, Batch 70: Loss: 0.0893
# REAL TRAIN: train_loss: 0.40, train_acc: 83.87
# Epoch: 28, val_loss: 0.44, train_loss: 0.45 val_acc: 81.88, train_acc: 81.09
# 	Epoch 29, Batch 10: Loss: 0.4026
# 	Epoch 29, Batch 20: Loss: 0.6800
# 	Epoch 29, Batch 30: Loss: 0.7929
# 	Epoch 29, Batch 40: Loss: 0.8061
# 	Epoch 29, Batch 50: Loss: 0.6790
# 	Epoch 29, Batch 60: Loss: 0.4391
# 	Epoch 29, Batch 70: Loss: 0.0842
# REAL TRAIN: train_loss: 0.36, train_acc: 85.61
# Epoch: 29, val_loss: 0.38, train_loss: 0.43 val_acc: 85.89, train_acc: 83.21
# 	Epoch 30, Batch 10: Loss: 0.3182
# 	Epoch 30, Batch 20: Loss: 0.5625
# 	Epoch 30, Batch 30: Loss: 0.7278
# 	Epoch 30, Batch 40: Loss: 0.7453
# 	Epoch 30, Batch 50: Loss: 0.6383
# 	Epoch 30, Batch 60: Loss: 0.4117
# 	Epoch 30, Batch 70: Loss: 0.0795
# REAL TRAIN: train_loss: 0.34, train_acc: 87.13
# Epoch: 30, val_loss: 0.39, train_loss: 0.40 val_acc: 85.66, train_acc: 84.64
# 	Epoch 31, Batch 10: Loss: 0.3777
# 	Epoch 31, Batch 20: Loss: 0.6330
# 	Epoch 31, Batch 30: Loss: 0.7548
# 	Epoch 31, Batch 40: Loss: 0.7495
# 	Epoch 31, Batch 50: Loss: 0.6428
# 	Epoch 31, Batch 60: Loss: 0.4206
# 	Epoch 31, Batch 70: Loss: 0.0831
# REAL TRAIN: train_loss: 0.45, train_acc: 82.11
# Epoch: 31, val_loss: 0.50, train_loss: 0.42 val_acc: 81.96, train_acc: 83.63
# 	Epoch 32, Batch 10: Loss: 0.3720
# 	Epoch 32, Batch 20: Loss: 0.6279
# 	Epoch 32, Batch 30: Loss: 0.7325
# 	Epoch 32, Batch 40: Loss: 0.7499
# 	Epoch 32, Batch 50: Loss: 0.6512
# 	Epoch 32, Batch 60: Loss: 0.4237
# 	Epoch 32, Batch 70: Loss: 0.0827
# REAL TRAIN: train_loss: 0.46, train_acc: 82.24
# Epoch: 32, val_loss: 0.52, train_loss: 0.42 val_acc: 80.65, train_acc: 82.79
# 	Epoch 33, Batch 10: Loss: 0.3369
# 	Epoch 33, Batch 20: Loss: 0.6170
# 	Epoch 33, Batch 30: Loss: 0.7367
# 	Epoch 33, Batch 40: Loss: 0.7404
# 	Epoch 33, Batch 50: Loss: 0.6385
# 	Epoch 33, Batch 60: Loss: 0.4198
# 	Epoch 33, Batch 70: Loss: 0.0813
# REAL TRAIN: train_loss: 0.33, train_acc: 87.86
# Epoch: 33, val_loss: 0.35, train_loss: 0.41 val_acc: 87.90, train_acc: 83.25
# 	Epoch 34, Batch 10: Loss: 0.3586
# 	Epoch 34, Batch 20: Loss: 0.6315
# 	Epoch 34, Batch 30: Loss: 0.7870
# 	Epoch 34, Batch 40: Loss: 0.8092
# 	Epoch 34, Batch 50: Loss: 0.6973
# 	Epoch 34, Batch 60: Loss: 0.4476
# 	Epoch 34, Batch 70: Loss: 0.0862
# REAL TRAIN: train_loss: 0.32, train_acc: 87.11
# Epoch: 34, val_loss: 0.33, train_loss: 0.44 val_acc: 86.43, train_acc: 82.57
# 	Epoch 35, Batch 10: Loss: 0.3517
# 	Epoch 35, Batch 20: Loss: 0.6065
# 	Epoch 35, Batch 30: Loss: 0.7361
# 	Epoch 35, Batch 40: Loss: 0.7419
# 	Epoch 35, Batch 50: Loss: 0.6221
# 	Epoch 35, Batch 60: Loss: 0.4035
# 	Epoch 35, Batch 70: Loss: 0.0773
# REAL TRAIN: train_loss: 0.30, train_acc: 89.53
# Epoch: 35, val_loss: 0.32, train_loss: 0.40 val_acc: 88.82, train_acc: 83.85
# 	Epoch 36, Batch 10: Loss: 0.3319
# 	Epoch 36, Batch 20: Loss: 0.5562
# 	Epoch 36, Batch 30: Loss: 0.6819
# 	Epoch 36, Batch 40: Loss: 0.6972
# 	Epoch 36, Batch 50: Loss: 0.5987
# 	Epoch 36, Batch 60: Loss: 0.3894
# 	Epoch 36, Batch 70: Loss: 0.0772
# REAL TRAIN: train_loss: 0.30, train_acc: 87.51
# Epoch: 36, val_loss: 0.32, train_loss: 0.39 val_acc: 87.12, train_acc: 85.15
# 	Epoch 37, Batch 10: Loss: 0.3087
# 	Epoch 37, Batch 20: Loss: 0.5654
# 	Epoch 37, Batch 30: Loss: 0.7104
# 	Epoch 37, Batch 40: Loss: 0.7155
# 	Epoch 37, Batch 50: Loss: 0.6152
# 	Epoch 37, Batch 60: Loss: 0.3971
# 	Epoch 37, Batch 70: Loss: 0.0772
# REAL TRAIN: train_loss: 0.29, train_acc: 87.92
# Epoch: 37, val_loss: 0.31, train_loss: 0.39 val_acc: 88.43, train_acc: 84.40
# 	Epoch 38, Batch 10: Loss: 0.3542
# 	Epoch 38, Batch 20: Loss: 0.6387
# 	Epoch 38, Batch 30: Loss: 0.7856
# 	Epoch 38, Batch 40: Loss: 0.8132
# 	Epoch 38, Batch 50: Loss: 0.6813
# 	Epoch 38, Batch 60: Loss: 0.4411
# 	Epoch 38, Batch 70: Loss: 0.0845
# REAL TRAIN: train_loss: 0.30, train_acc: 88.96
# Epoch: 38, val_loss: 0.31, train_loss: 0.43 val_acc: 88.43, train_acc: 83.08
# 	Epoch 39, Batch 10: Loss: 0.2975
# 	Epoch 39, Batch 20: Loss: 0.5426
# 	Epoch 39, Batch 30: Loss: 0.6833
# 	Epoch 39, Batch 40: Loss: 0.6844
# 	Epoch 39, Batch 50: Loss: 0.5988
# 	Epoch 39, Batch 60: Loss: 0.3903
# 	Epoch 39, Batch 70: Loss: 0.0753
# REAL TRAIN: train_loss: 0.30, train_acc: 88.01
# Epoch: 39, val_loss: 0.33, train_loss: 0.38 val_acc: 88.05, train_acc: 84.11
# 	Epoch 40, Batch 10: Loss: 0.2788
# 	Epoch 40, Batch 20: Loss: 0.4910
# 	Epoch 40, Batch 30: Loss: 0.6415
# 	Epoch 40, Batch 40: Loss: 0.6767
# 	Epoch 40, Batch 50: Loss: 0.5940
# 	Epoch 40, Batch 60: Loss: 0.3917
# 	Epoch 40, Batch 70: Loss: 0.0778
# REAL TRAIN: train_loss: 0.30, train_acc: 87.73
# Epoch: 40, val_loss: 0.34, train_loss: 0.40 val_acc: 87.12, train_acc: 84.46
# 	Epoch 41, Batch 10: Loss: 0.3411
# 	Epoch 41, Batch 20: Loss: 0.5534
# 	Epoch 41, Batch 30: Loss: 0.6739
# 	Epoch 41, Batch 40: Loss: 0.6827
# 	Epoch 41, Batch 50: Loss: 0.5795
# 	Epoch 41, Batch 60: Loss: 0.3763
# 	Epoch 41, Batch 70: Loss: 0.0725
# REAL TRAIN: train_loss: 0.27, train_acc: 90.19
# Epoch: 41, val_loss: 0.30, train_loss: 0.37 val_acc: 88.90, train_acc: 85.15
# 	Epoch 42, Batch 10: Loss: 0.3409
# 	Epoch 42, Batch 20: Loss: 0.5324
# 	Epoch 42, Batch 30: Loss: 0.6432
# 	Epoch 42, Batch 40: Loss: 0.6451
# 	Epoch 42, Batch 50: Loss: 0.5501
# 	Epoch 42, Batch 60: Loss: 0.3646
# 	Epoch 42, Batch 70: Loss: 0.0724
# REAL TRAIN: train_loss: 0.50, train_acc: 79.42
# Epoch: 42, val_loss: 0.47, train_loss: 0.37 val_acc: 80.49, train_acc: 85.21
# 	Epoch 43, Batch 10: Loss: 0.3505
# 	Epoch 43, Batch 20: Loss: 0.5191
# 	Epoch 43, Batch 30: Loss: 0.6643
# 	Epoch 43, Batch 40: Loss: 0.6877
# 	Epoch 43, Batch 50: Loss: 0.6107
# 	Epoch 43, Batch 60: Loss: 0.3910
# 	Epoch 43, Batch 70: Loss: 0.0757
# REAL TRAIN: train_loss: 0.25, train_acc: 90.28
# Epoch: 43, val_loss: 0.28, train_loss: 0.38 val_acc: 90.21, train_acc: 84.91
# 	Epoch 44, Batch 10: Loss: 0.3331
# 	Epoch 44, Batch 20: Loss: 0.5066
# 	Epoch 44, Batch 30: Loss: 0.6327
# 	Epoch 44, Batch 40: Loss: 0.6599
# 	Epoch 44, Batch 50: Loss: 0.5611
# 	Epoch 44, Batch 60: Loss: 0.3693
# 	Epoch 44, Batch 70: Loss: 0.0724
# REAL TRAIN: train_loss: 0.28, train_acc: 89.42
# Epoch: 44, val_loss: 0.31, train_loss: 0.37 val_acc: 87.74, train_acc: 85.52
# 	Epoch 45, Batch 10: Loss: 0.3037
# 	Epoch 45, Batch 20: Loss: 0.5707
# 	Epoch 45, Batch 30: Loss: 0.6727
# 	Epoch 45, Batch 40: Loss: 0.6525
# 	Epoch 45, Batch 50: Loss: 0.5686
# 	Epoch 45, Batch 60: Loss: 0.3665
# 	Epoch 45, Batch 70: Loss: 0.0723
# REAL TRAIN: train_loss: 0.33, train_acc: 88.56
# Epoch: 45, val_loss: 0.32, train_loss: 0.37 val_acc: 88.20, train_acc: 85.81
# 	Epoch 46, Batch 10: Loss: 0.2603
# 	Epoch 46, Batch 20: Loss: 0.5074
# 	Epoch 46, Batch 30: Loss: 0.6314
# 	Epoch 46, Batch 40: Loss: 0.6352
# 	Epoch 46, Batch 50: Loss: 0.5389
# 	Epoch 46, Batch 60: Loss: 0.3564
# 	Epoch 46, Batch 70: Loss: 0.0716
# REAL TRAIN: train_loss: 0.33, train_acc: 87.22
# Epoch: 46, val_loss: 0.33, train_loss: 0.37 val_acc: 86.89, train_acc: 85.26
# 	Epoch 47, Batch 10: Loss: 0.2983
# 	Epoch 47, Batch 20: Loss: 0.5173
# 	Epoch 47, Batch 30: Loss: 0.6157
# 	Epoch 47, Batch 40: Loss: 0.6477
# 	Epoch 47, Batch 50: Loss: 0.5553
# 	Epoch 47, Batch 60: Loss: 0.3654
# 	Epoch 47, Batch 70: Loss: 0.0710
# REAL TRAIN: train_loss: 0.26, train_acc: 89.71
# Epoch: 47, val_loss: 0.29, train_loss: 0.36 val_acc: 89.51, train_acc: 86.18
# 	Epoch 48, Batch 10: Loss: 0.2670
# 	Epoch 48, Batch 20: Loss: 0.4770
# 	Epoch 48, Batch 30: Loss: 0.5888
# 	Epoch 48, Batch 40: Loss: 0.6140
# 	Epoch 48, Batch 50: Loss: 0.5438
# 	Epoch 48, Batch 60: Loss: 0.3598
# 	Epoch 48, Batch 70: Loss: 0.0709
# REAL TRAIN: train_loss: 0.33, train_acc: 87.06
# Epoch: 48, val_loss: 0.37, train_loss: 0.36 val_acc: 86.66, train_acc: 85.92
# 	Epoch 49, Batch 10: Loss: 0.2969
# 	Epoch 49, Batch 20: Loss: 0.4968
# 	Epoch 49, Batch 30: Loss: 0.6067
# 	Epoch 49, Batch 40: Loss: 0.6105
# 	Epoch 49, Batch 50: Loss: 0.5399
# 	Epoch 49, Batch 60: Loss: 0.3611
# 	Epoch 49, Batch 70: Loss: 0.0709
# REAL TRAIN: train_loss: 0.28, train_acc: 88.7
# Epoch: 49, val_loss: 0.32, train_loss: 0.36 val_acc: 88.59, train_acc: 85.76
# 	Epoch 50, Batch 10: Loss: 0.3044
# 	Epoch 50, Batch 20: Loss: 0.5207
# 	Epoch 50, Batch 30: Loss: 0.6183
# 	Epoch 50, Batch 40: Loss: 0.6076
# 	Epoch 50, Batch 50: Loss: 0.5306
# 	Epoch 50, Batch 60: Loss: 0.3409
# 	Epoch 50, Batch 70: Loss: 0.0669
# REAL TRAIN: train_loss: 0.28, train_acc: 87.97
# Epoch: 50, val_loss: 0.33, train_loss: 0.34 val_acc: 86.66, train_acc: 86.98
# 	Epoch 51, Batch 10: Loss: 0.3211
# 	Epoch 51, Batch 20: Loss: 0.5055
# 	Epoch 51, Batch 30: Loss: 0.6330
# 	Epoch 51, Batch 40: Loss: 0.6429
# 	Epoch 51, Batch 50: Loss: 0.5509
# 	Epoch 51, Batch 60: Loss: 0.3556
# 	Epoch 51, Batch 70: Loss: 0.0693
# REAL TRAIN: train_loss: 0.23, train_acc: 91.34
# Epoch: 51, val_loss: 0.25, train_loss: 0.35 val_acc: 90.44, train_acc: 86.12
# 	Epoch 52, Batch 10: Loss: 0.3158
# 	Epoch 52, Batch 20: Loss: 0.5294
# 	Epoch 52, Batch 30: Loss: 0.6269
# 	Epoch 52, Batch 40: Loss: 0.6232
# 	Epoch 52, Batch 50: Loss: 0.5193
# 	Epoch 52, Batch 60: Loss: 0.3389
# 	Epoch 52, Batch 70: Loss: 0.0671
# REAL TRAIN: train_loss: 0.38, train_acc: 85.02
# Epoch: 52, val_loss: 0.41, train_loss: 0.34 val_acc: 85.58, train_acc: 86.38
# 	Epoch 53, Batch 10: Loss: 0.3255
# 	Epoch 53, Batch 20: Loss: 0.4978
# 	Epoch 53, Batch 30: Loss: 0.5786
# 	Epoch 53, Batch 40: Loss: 0.5806
# 	Epoch 53, Batch 50: Loss: 0.5093
# 	Epoch 53, Batch 60: Loss: 0.3422
# 	Epoch 53, Batch 70: Loss: 0.0665
# REAL TRAIN: train_loss: 0.25, train_acc: 91.05
# Epoch: 53, val_loss: 0.31, train_loss: 0.34 val_acc: 88.97, train_acc: 86.87
# 	Epoch 54, Batch 10: Loss: 0.3148
# 	Epoch 54, Batch 20: Loss: 0.5197
# 	Epoch 54, Batch 30: Loss: 0.6199
# 	Epoch 54, Batch 40: Loss: 0.6373
# 	Epoch 54, Batch 50: Loss: 0.5307
# 	Epoch 54, Batch 60: Loss: 0.3434
# 	Epoch 54, Batch 70: Loss: 0.0665
# REAL TRAIN: train_loss: 0.28, train_acc: 89.38
# Epoch: 54, val_loss: 0.31, train_loss: 0.34 val_acc: 88.90, train_acc: 86.62
# 	Epoch 55, Batch 10: Loss: 0.2777
# 	Epoch 55, Batch 20: Loss: 0.4978
# 	Epoch 55, Batch 30: Loss: 0.5698
# 	Epoch 55, Batch 40: Loss: 0.5709
# 	Epoch 55, Batch 50: Loss: 0.4801
# 	Epoch 55, Batch 60: Loss: 0.3184
# 	Epoch 55, Batch 70: Loss: 0.0621
# REAL TRAIN: train_loss: 0.37, train_acc: 86.84
# Epoch: 55, val_loss: 0.39, train_loss: 0.31 val_acc: 85.12, train_acc: 87.51
# 	Epoch 56, Batch 10: Loss: 0.2920
# 	Epoch 56, Batch 20: Loss: 0.5283
# 	Epoch 56, Batch 30: Loss: 0.6883
# 	Epoch 56, Batch 40: Loss: 0.6625
# 	Epoch 56, Batch 50: Loss: 0.5602
# 	Epoch 56, Batch 60: Loss: 0.3630
# 	Epoch 56, Batch 70: Loss: 0.0700
# REAL TRAIN: train_loss: 0.24, train_acc: 91.12
# Epoch: 56, val_loss: 0.29, train_loss: 0.36 val_acc: 88.97, train_acc: 86.67
# 	Epoch 57, Batch 10: Loss: 0.2756
# 	Epoch 57, Batch 20: Loss: 0.4351
# 	Epoch 57, Batch 30: Loss: 0.5089
# 	Epoch 57, Batch 40: Loss: 0.5484
# 	Epoch 57, Batch 50: Loss: 0.4692
# 	Epoch 57, Batch 60: Loss: 0.3084
# 	Epoch 57, Batch 70: Loss: 0.0612
# REAL TRAIN: train_loss: 0.22, train_acc: 92.04
# Epoch: 57, val_loss: 0.26, train_loss: 0.31 val_acc: 90.36, train_acc: 88.23
# 	Epoch 58, Batch 10: Loss: 0.2869
# 	Epoch 58, Batch 20: Loss: 0.4960
# 	Epoch 58, Batch 30: Loss: 0.6061
# 	Epoch 58, Batch 40: Loss: 0.6078
# 	Epoch 58, Batch 50: Loss: 0.5189
# 	Epoch 58, Batch 60: Loss: 0.3391
# 	Epoch 58, Batch 70: Loss: 0.0648
# REAL TRAIN: train_loss: 0.22, train_acc: 92.16
# Epoch: 58, val_loss: 0.28, train_loss: 0.33 val_acc: 89.13, train_acc: 86.87
# 	Epoch 59, Batch 10: Loss: 0.3042
# 	Epoch 59, Batch 20: Loss: 0.4949
# 	Epoch 59, Batch 30: Loss: 0.5956
# 	Epoch 59, Batch 40: Loss: 0.6191
# 	Epoch 59, Batch 50: Loss: 0.5190
# 	Epoch 59, Batch 60: Loss: 0.3319
# 	Epoch 59, Batch 70: Loss: 0.0643
# REAL TRAIN: train_loss: 0.22, train_acc: 91.23
# Epoch: 59, val_loss: 0.27, train_loss: 0.33 val_acc: 90.05, train_acc: 87.20
# 	Epoch 60, Batch 10: Loss: 0.2539
# 	Epoch 60, Batch 20: Loss: 0.4554
# 	Epoch 60, Batch 30: Loss: 0.5744
# 	Epoch 60, Batch 40: Loss: 0.5833
# 	Epoch 60, Batch 50: Loss: 0.4916
# 	Epoch 60, Batch 60: Loss: 0.3236
# 	Epoch 60, Batch 70: Loss: 0.0625
# REAL TRAIN: train_loss: 0.40, train_acc: 84.73
# Epoch: 60, val_loss: 0.37, train_loss: 0.32 val_acc: 86.97, train_acc: 87.22
# 	Epoch 61, Batch 10: Loss: 0.2830
# 	Epoch 61, Batch 20: Loss: 0.4647
# 	Epoch 61, Batch 30: Loss: 0.5907
# 	Epoch 61, Batch 40: Loss: 0.6000
# 	Epoch 61, Batch 50: Loss: 0.4955
# 	Epoch 61, Batch 60: Loss: 0.3295
# 	Epoch 61, Batch 70: Loss: 0.0640
# REAL TRAIN: train_loss: 0.21, train_acc: 92.44
# Epoch: 61, val_loss: 0.25, train_loss: 0.32 val_acc: 90.82, train_acc: 87.31
# > Early stopping <

# %% [markdown]
# # Analizamos los datos

# %%
model.load_state_dict(early_stopper.best_model)
model.eval()

cm = metrics.confusion_matrix(targets, preds)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Gráfico de la precisión de entrenamiento y validación
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_acc_h, label='Train Accuracy')
plt.plot(val_acc_h, label='Validation Accuracy')
#TMP==========
plt.plot(tmp_acc, label='REAL TRAIN ACC')
#=============
plt.title('Train vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Gráfico de la pérdida de entrenamiento y validación
plt.subplot(1, 2, 2)
plt.plot(train_loss_h, label='Train Loss')
plt.plot(val_loss_h, label='Validation Loss')
#TMP==========
plt.plot(tmp_loss, label='REAL TRAIN LOSS')
#=============
plt.title('Train vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# cjto train
train_preds, train_reals, train_loss, train_acc = eval(model, train_loader, device=device, criterion=criterion)
print("Train Dataset ----------------------------------------------------------------")
print(f"train_loss: {train_loss} - train_acc: {train_acc}")
print(metrics.classification_report(train_reals, train_preds, zero_division=0))


# cjto val
val_preds, val_reals, val_loss, val_acc = eval(model, val_loader, device=device, criterion=criterion)
print("Val Dataset ----------------------------------------------------------------")
print(f"val_loss: {val_loss} - val_acc: {val_acc}")
print(metrics.classification_report(val_reals, val_preds, zero_division=0))

# cjto tests
test_preds, test_reals, test_loss, test_acc = eval(model, test_loader, device=device, criterion=criterion)
cm = metrics.confusion_matrix(test_reals, test_preds)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Tests Dataset")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print("Tests Dataset ----------------------------------------------------------------")
print(f"test_loss: {test_loss} - test_acc: {test_acc}")
print(metrics.classification_report(test_reals, test_preds, zero_division=0))
# Out:
# Train Dataset ----------------------------------------------------------------
# train_loss: 0.2115619752398679 - train_acc: 0.9222124283825474
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      1135
#            1       0.94      0.89      0.92      1135
#            2       0.86      0.85      0.86      1134
#            3       0.92      0.98      0.95      1134
#
#     accuracy                           0.92      4538
#    macro avg       0.92      0.92      0.92      4538
# weighted avg       0.92      0.92      0.92      4538
#
# Val Dataset ----------------------------------------------------------------
# val_loss: 0.25382975382464273 - val_acc: 0.9082498072474943
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       324
#            1       0.93      0.86      0.90       324
#            2       0.83      0.83      0.83       325
#            3       0.91      0.97      0.94       324
#
#     accuracy                           0.91      1297
#    macro avg       0.91      0.91      0.91      1297
# weighted avg       0.91      0.91      0.91      1297
# Tests Dataset ----------------------------------------------------------------
# test_loss: 0.22337071733041244 - test_acc: 0.926040061633282
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       162
#            1       0.95      0.89      0.92       162
#            2       0.87      0.86      0.87       162
#            3       0.90      0.98      0.94       163
#
#     accuracy                           0.93       649
#    macro avg       0.93      0.93      0.93       649
# weighted avg       0.93      0.93      0.93       649

# %%
save_model(model, "/kaggle/working/model.pth", complete=True)
