# %% [markdown]
# # CLASIFICADOR DE IMAGENES MRI

# %% [markdown]
# # Indice
# * [Constantes e hiperparametros](#constantes)
# * [Creación  dataset](#dataset)
#     * [Balanceamiento del dataset](#balanceamiento)
#     * [Separación y comprobación de conjuntos](#separacion)
# * [Dataset de pytorch](#pytorch)
#     * [Calculo media y desviación](#media)
#     * [Data Augmentation y Datasets de Conjuntos](#data)
#     * [DataLoaders](#dataloaders)
# * [Entrenamiento](#entrenamiento)
#     * [Early Stopping](#earlyStopping)
#     * [Modelo CNN](#modelo)
#     * [Funcion de evaluacion](#evaluacion)
#     * [Funcion de entrenamiento](#entrenamiento)
#     * [ Configuración y Entrenamiento del Modelo CNN](#configuracion)
# * [Guardado del modelo ](#guardado)

# %%
# %matplotlib inline

# imports
import pandas as pd
from torchvision.io import read_image, ImageReadMode
import os
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns
from torch import optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
print(torch.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo configurado para usar: {device}")

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.0.0
# Dispositivo configurado para usar: cuda
# True
# Tesla P100-PCIE-16GB

# %% [markdown]
# # Constantes e hiperparametros <a name="constantes"></a>

# %%
# const

DIR_PATH = "/kaggle/input/brain-tumor-mri-dataset"

LABELS = ["notumor", "glioma", "meningioma", "pituitary"]

TRAIN_PERCENT = .7
VAL_PERCENT = .2
TEST_PERCENT = .1

IMAGE_SIZE = 220

RANDOM_STATE = None

BATCH_SIZE = 32
LEARNING_RATE = 0.001
MOMENTUM = 0.9
NUM_EPOCH = 100
EARLY_PATIENCE = 10
SCHEDULER_PATIENCE = 6
DROPOUT_1=0.5
DROPOUT_2=0.75

# %% [markdown]
# # Creación dataset <a name="dataset"></a>
#
#
# Se crea un conjunto de datos a partir de imágenes almacenadas en el directorio. Cada imagen se registra junto con su categoria(label).

# %%
dataset = pd.DataFrame(columns = ["path", "label"])

for dir in os.listdir(DIR_PATH):
    for label in os.listdir(os.path.join(DIR_PATH, dir)):
        for img in os.listdir(os.path.join(DIR_PATH, dir, label)):
            dataset.loc[len(dataset)] = {"path": os.path.join(DIR_PATH, dir, label, img),
                                   "label": LABELS.index(label) }

print("num elementos:", dataset.count(axis=1).size)
print(dataset.head())
# Out:
# num elementos: 7023
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      3

# %% [markdown]
# ## Balanceamiento del dataset  <a name="balanceamiento"></a>
#
#
# Para evitar el desbalanceo se calcula el numero de imagenes de la categoria con menos imagenes

# %%
min_cat_size = dataset.label.value_counts().min()

print("> Cantidad de imagenes de la categoria que menos tiene:", min_cat_size)
# Out:
# > Cantidad de imagenes de la categoria que menos tiene: 1621

# %% [markdown]
# Se equilibra el conjunto de datos para que todos tengan 1621 imagenes, dependiendo del valor de RANDOM_STATE, la elección será aleatoria o no.

# %%
# Hacemos que todos tengan los mismos elementos
dataset = pd.DataFrame(dataset.groupby("label").apply(lambda label: label.sample(min_cat_size, random_state=RANDOM_STATE)).reset_index(drop=True))

print("> Cantidad de elementos: ", dataset.count(axis=1).size)
print(dataset.label.value_counts())
print(dataset.head())
# Out:
# > Cantidad de elementos:  6484
# label
# 0    1621
# 1    1621
# 2    1621
# 3    1621
# Name: count, dtype: int64
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      0

# %% [markdown]
# ## Separación y comprobación de conjuntos <a name="separacion" ></a>
#
# Se separan las imagenes del dataset balanceado en 3 conjuntos: entrenamiento,validación y test

# %%
train_dataset, tmp = train_test_split(dataset, train_size=TRAIN_PERCENT, stratify=dataset["label"], shuffle=True, random_state=RANDOM_STATE)
val_dataset, test_dataset = train_test_split(tmp, test_size=TEST_PERCENT/(TEST_PERCENT+VAL_PERCENT), stratify=tmp["label"], shuffle=True, random_state=RANDOM_STATE)

print("> train", train_dataset.count(axis=1).size, train_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(train_dataset.label.value_counts())
print()

print("> val", val_dataset.count(axis=1).size, val_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(val_dataset.label.value_counts())
print()

print("> test", test_dataset.count(axis=1).size, test_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(test_dataset.label.value_counts())
print()
# Out:
# > train 4538 0.6998766193707588
# label
# 0    1135
# 3    1135
# 1    1134
# 2    1134
# Name: count, dtype: int64
#
# > val 1297 0.2000308451573103
# label
# 2    325
# 1    324
# 3    324
# 0    324
# Name: count, dtype: int64
#
# > test 649 0.10009253547193091
# label
# 1    163
# 0    162
# 2    162
# 3    162
# Name: count, dtype: int64

# %% [markdown]
# Se comprueba que son disjuntos para garantizar la integridad y la evaluación imparcial del modelo

# %%
print((train_dataset[ "path" ].isin(test_dataset["path"] ) == True).value_counts())
print((train_dataset[ "path" ].isin(val_dataset["path"] ) == True).value_counts())
print((val_dataset[ "path" ].isin(test_dataset["path"]) == True).value_counts())
# Out:
# path
# False    4538
# Name: count, dtype: int64
# path
# False    4538
# Name: count, dtype: int64
# path
# False    1297
# Name: count, dtype: int64

# %% [markdown]
# # Dataset de pytorch <a name="pytorch"></a>
#
# La clase CustomDataset esta diseñada para cargar y preparar datos para su uso en el aprendizaje automático utilizando la biblioteca PyTorch.

# %%
class CustomDataset(Dataset):
    
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
    
    def __len__(self):
        return self.dataframe.count(axis=1).size
    
    def __getitem__(self, idx) -> (str, int):
        
        row = self.dataframe.iloc[idx]
        img, label = row.path, row.label

        img = read_image(img, mode=ImageReadMode.GRAY)
        if self.transform: img = self.transform(img)

        return img, label

# %% [markdown]
# ## Calculo media y desviación <a name="media"></a>
#
# Se calcula la media y desviación  de un dataset sin Data Augmentation para poder normalizar las imagenes antes de usarlas en el modelo.

# %%
unnormalized_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.ToTensor()
])

unnormalized_dataset = CustomDataset(dataset, transform=unnormalized_transforms)
loader = DataLoader(unnormalized_dataset, batch_size=1, shuffle=False)

sum_intensity = 0.0
sum_squared_intensity = 0.0
n_samples = 0

for imgs, _ in loader:
    
    sum_intensity += imgs.sum()
    sum_squared_intensity += (imgs ** 2).sum()
    n_samples += imgs.numel()

mean = sum_intensity / n_samples
std = torch.sqrt(sum_squared_intensity / n_samples - mean ** 2)

print(mean)
print(std)
# Out:
# tensor(0.1837)
# tensor(0.1990)

# %% [markdown]
# ## Data Augmentation y Datasets de Conjuntos <a name="data" ></a>

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.RandomRotation(180),            
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

test_valid_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE),antialias=True),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])


train_dataset = CustomDataset(train_dataset, transform=train_transform)
val_dataset = CustomDataset(val_dataset, transform=test_valid_transforms)
test_dataset = CustomDataset(test_dataset, transform=test_valid_transforms)

# Acceder e imprimir las primeras 5 muestras del dataset
for i in range(5):
    image, label = train_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = val_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = test_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")

# Imprimir los valores de la media y la desviación estándar
print(f"Media: {mean}, Desviación Estándar: {std}")
# Out:
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 1
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 1
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 2
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 1
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Media: 0.1836961954832077, Desviación Estándar: 0.19904878735542297

# %% [markdown]
# ## Dataloaders <a name="dataloaders"></a>
#
# Se crean los dataLoaders ya que se encargan de cargar y organizar los datos de un conjunto de datos para que puedan ser procesados por un modelo de manera eficiente durante el entrenamiento y la evaluación.

# %%
def show_img(img, label):
    print('Label: ', dataset.label[label], "(" + str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

# Verificar DataLoader
for images, labels in train_loader:
    print(f"Batch de imágenes: {images.shape}, Batch de etiquetas: {labels.shape}")
    break

# Carga una imagen de prueba
img, label = test_dataset[45]
show_img(img, label)
# Out:
# Batch de imágenes: torch.Size([32, 1, 220, 220]), Batch de etiquetas: torch.Size([32])
# Label:  0 (1)

# %% [markdown]
# # Entrenamiento <a name="entrenamiento"></a>

# %% [markdown]
# ## Early Stopping <a name="earlyStopping"></a>
#
# Se establece el mecanismo de parada temprana (Early Stopping) para el entrenamiento del modelo. Esta técnica ayuda a evitar el sobreajuste y ahorrar tiempo de entrenamiento.
#
# Si la pérdida de validación no mejora durante un número específico de épocas (determinado por la paciencia), el entrenamiento se detiene.

# %%
class EarlyStopper:
    
    def __init__(self, patience=5, min_delta=0, callback=lambda **_: None):
        self.patience = patience
        self.min_delta = min_delta
        self.callback = callback

        self.counter = 1

        self.best_model = None
        self.best_loss = float("inf")

    def __call__(self, val_loss, model):

        if val_loss < (self.best_loss - self.min_delta):
            self.best_loss = val_loss
            self.counter = 0

            self.best_model = model.state_dict()
            return False


        self.counter += 1
        if self.counter >= self.patience:
            self.callback(counter=self.counter, best_loss=self.best_loss, best_model=self.best_model)
            return True

    def reset(self):
        self.early_stop = False
        self.counter = 1

# %% [markdown]
# ## Modelo CNN <a name="modelo"></a>
#
# Este modelo tiene:
#
# **6 Capas Convolucionales (Conv2d)**:
#
# Su objetivo es extraer características de las imágene mediante la Aplicación de un conjunto de filtros (kernels) a la imagen para crear mapas de características. Cada filtro detecta características específicas (bordes, texturas, etc.).
#
# La primera capa toma una imagen con un solo canal, ya que se trabaja con imagenes en escala de grises.
#
# **6 Normalización por Lotes (BatchNorm2d)**
#
# Su objetivo es estabilizar y acelerar el aprendizaje mediante la Normalización de la salida de la capa anterior, reduciendo el cambio de distribución interna (Internal Covariate Shift).
#
# **Función de Activación ReLU**
#
# Su objetivo es introducir no linealidades en el model Convirtiendo todos los valores negativos a cero y mantiene los positivos tal cual están, lo que ayuda a activar solo ciertas neuronas, aumentando la eficiencia y efectividad del aprendizaje.
#
# **Pooling (Max Pooling)**
#
# Su objetivo es reducir la dimensionalidad espacial, conservando las características más importantes. Esto se consigue seleccionando el valor máximo de una ventana de tamaño especificado y lo usa para representar la región.
#
# **3 Capas Completamente Conectadas (Linear)**
#
# Su objetivo es realizar la clasificación en base a las características extraídas.
# Cada neurona en estas capas está conectada a todas las activaciones de la capa anterior, y se utilizan para derivar la salida final.
#
# **Dropout**
#
# Su objetivo es prevenir el sobreajuste. Durante el entrenamiento, se "desactivan" aleatoriamente algunas neuronas, lo que hace que el modelo sea menos sensible a las características específicas de los datos de entrenamiento.

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        padding_size = 3
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 64, kernel_size=7, padding=padding_size)
        self.bn1 = nn.BatchNorm2d(64)

        self.conv2 = nn.Conv2d(64, 128, kernel_size=7, padding=padding_size)
        self.bn2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128, 128, kernel_size=7, padding=padding_size)
        self.bn3 = nn.BatchNorm2d(128)

        self.conv4 = nn.Conv2d(128, 256, kernel_size=7, padding=padding_size)
        self.bn4 = nn.BatchNorm2d(256)

        self.conv5 = nn.Conv2d(256, 256, kernel_size=7, padding=padding_size)
        self.bn5 = nn.BatchNorm2d(256)

        self.conv6 = nn.Conv2d(256, 512, kernel_size=7, padding=padding_size)
        self.bn6 = nn.BatchNorm2d(512)

        # Fully connected layers
        self.fc1 = nn.Linear(512*3*3, 1024) 
        self.dropout1 = nn.Dropout(DROPOUT_1)
        self.fc2 = nn.Linear(1024, 512)
        self.dropout2 = nn.Dropout(DROPOUT_2)
        self.fc3 = nn.Linear(512, 4)

    def forward(self, x):
        # Convolutional layers with ReLU activations and batch normalization
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn3(self.conv3(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn4(self.conv4(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn5(self.conv5(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn6(self.conv6(x)))
        x = F.max_pool2d(x, kernel_size=2)

        # Flatten the output for the fully connected layers
        x = x.view(x.size(0), -1)

        # Fully connected layers with ReLU activations and dropout
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)  

        return x

# %% [markdown]
# ## Función de evaluación <a name="evaluacion"></a>

# %%
def eval(model, loader, *, device = None, criterion = None):
    """returns pred, real, accuracy, val_loss"""
    if not (device and criterion): raise Exception("Params needed")

    model.eval()

    corrects = 0

    pred = []
    real = []
    loss = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in loader:
            
            imgs, labels = imgs.to(device), labels.to(device)

            outs = model(imgs)
            loss += criterion(outs.data, labels).item()

            _, predicted = torch.max(outs.data, 1)
            
            total += labels.size(0)
            pred.extend(predicted.tolist())
            real.extend(labels.tolist())

            corrects += (predicted == labels).sum().item()
    
    return  pred, real, loss/len(loader), corrects/total

# %% [markdown]
# ## Función de entrenamiento <a name="entrenamiento"></a>

# %%
def train_loop(model, loader, *, optimizer, criterion, num_epoch=100, device=torch.device("cuda" if torch.cuda.is_available() else "cpu"), train_loss_h=[], train_acc_h=[], val_loss_h=[] ,val_acc_h=[], callback=lambda **_: None, early_callback=lambda **_: None, scheduler, val_loader):
    if not (optimizer and criterion and early_stopper and scheduler): raise Exception("Params needed")
    
    val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
    callback(epoch=0, val_acc=val_acc, val_loss=val_loss, train_loss=float("inf"), train_acc=0)

    for epoch in range(num_epoch):

        running_loss = 0.0
        corrects = 0
        total = 0

        model.train()

        for i, (imgs, labels) in enumerate(loader, 1):

            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()

            outs = model(imgs)
            loss = criterion(outs, labels)
            
            running_loss += loss.item()
            
            loss.backward()
            optimizer.step()

            # extra for analytics
            _, predicted = torch.max(outs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()
            # ==================

            if not i % 10:
                print(f"\tEpoch {epoch+1}, Batch {i}: Loss: {running_loss*(len(loader)-i+1)/(10*len(loader)):.4f}")
            
        val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
        scheduler.step(val_loss)
        
        # extra for analytics
        train_loss = running_loss/len(loader)
        train_loss_h.append(train_loss)
        train_acc = 100*corrects/total
        train_acc_h.append(train_acc)

        val_loss_h.append(val_loss)
        val_acc_h.append(val_acc*100)
        # ===================

        callback(epoch=epoch+1, val_acc=val_acc, val_loss=val_loss, train_loss=train_loss, train_acc=train_acc)

        if(early_stopper(val_loss, model)): break

    return train_acc_h, val_acc_h, train_loss_h, val_loss_h, val_preds, val_labels

# %% [markdown]
# ## Configuración y Entrenamiento del Modelo CNN <a name="configuracion"></a>
#
# **Optimizador**: descenso de gradiente estocástico (SGD. El gradiente se calcula de manera aproximada a partir de un subconjunto de datos en lugar de utilizar todo el conjunto de datos. Esto hace que el proceso de entrenamiento sea más eficiente y escalable.
#
# **Función de pérdida:** CrossEntropyLoss. Ampliamente utilizada para problemas de clasificación multiclase en aprendizaje profundo. Ayuda a medir la discrepancia entre las predicciones del modelo y las etiquetas reales.
#
# **Scheduler:** ReduceLROnPlateau. Reduce la tasa de aprendizaje cuando el modelo deja de mejorar en la perdida de validación. Esto puede ayudar a que el modelo converja de manera más efectiva hacia una solución óptima y evite oscilaciones en el entrenamiento

# %%
def early_callback(**kwargs): print("> Early stopping <")

early_stopper = EarlyStopper(patience=EARLY_PATIENCE, min_delta=.001, callback=early_callback)

# %%
model = CNN()
if torch.cuda.device_count() > 1: model = nn.DataParallel(model)
model.to(device)

optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
criterion = nn.CrossEntropyLoss().to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, patience=SCHEDULER_PATIENCE, verbose=True)

def callback(**kwargs):
    print(f"Epoch: {kwargs['epoch']}, val_loss: {(kwargs['val_loss']):.2f}, train_loss: {(kwargs['train_loss']):.2f} val_acc: {(kwargs['val_acc']*100):.2f}, train_acc: {(kwargs['train_acc']):.2f}")

train_acc_h, val_acc_h, train_loss_h, val_loss_h, preds, targets = train_loop(model, train_loader,
           val_loader=val_loader,                                                             
           optimizer=optimizer,
           criterion=criterion,
           num_epoch=NUM_EPOCH,
           device=device,
           callback=callback,
           scheduler=scheduler
           )
# Out:
# Epoch: 0, val_loss: 1.39, train_loss: inf val_acc: 24.98, train_acc: 0.00
# 	Epoch 1, Batch 10: Loss: 1.2890
# 	Epoch 1, Batch 20: Loss: 2.2407
# 	Epoch 1, Batch 30: Loss: 2.9816
# 	Epoch 1, Batch 40: Loss: 3.5622
# 	Epoch 1, Batch 50: Loss: 3.9648
# 	Epoch 1, Batch 60: Loss: 4.1994
# 	Epoch 1, Batch 70: Loss: 4.2388
# 	Epoch 1, Batch 80: Loss: 4.0854
# 	Epoch 1, Batch 90: Loss: 3.7605
# 	Epoch 1, Batch 100: Loss: 3.3449
# 	Epoch 1, Batch 110: Loss: 2.7854
# 	Epoch 1, Batch 120: Loss: 2.0852
# 	Epoch 1, Batch 130: Loss: 1.2557
# 	Epoch 1, Batch 140: Loss: 0.3068
# Epoch: 1, val_loss: 1.05, train_loss: 1.03 val_acc: 57.52, train_acc: 55.49
# 	Epoch 2, Batch 10: Loss: 0.7235
# 	Epoch 2, Batch 20: Loss: 1.3986
# 	Epoch 2, Batch 30: Loss: 1.8930
# 	Epoch 2, Batch 40: Loss: 2.2593
# 	Epoch 2, Batch 50: Loss: 2.5315
# 	Epoch 2, Batch 60: Loss: 2.7128
# 	Epoch 2, Batch 70: Loss: 2.7355
# 	Epoch 2, Batch 80: Loss: 2.6811
# 	Epoch 2, Batch 90: Loss: 2.5276
# 	Epoch 2, Batch 100: Loss: 2.2913
# 	Epoch 2, Batch 110: Loss: 1.9422
# 	Epoch 2, Batch 120: Loss: 1.4803
# 	Epoch 2, Batch 130: Loss: 0.9036
# 	Epoch 2, Batch 140: Loss: 0.2217
# Epoch: 2, val_loss: 0.65, train_loss: 0.75 val_acc: 72.40, train_acc: 70.82
# 	Epoch 3, Batch 10: Loss: 0.5507
# 	Epoch 3, Batch 20: Loss: 1.1704
# 	Epoch 3, Batch 30: Loss: 1.5941
# 	Epoch 3, Batch 40: Loss: 2.0138
# 	Epoch 3, Batch 50: Loss: 2.2266
# 	Epoch 3, Batch 60: Loss: 2.3854
# 	Epoch 3, Batch 70: Loss: 2.4419
# 	Epoch 3, Batch 80: Loss: 2.3861
# 	Epoch 3, Batch 90: Loss: 2.2534
# 	Epoch 3, Batch 100: Loss: 2.0314
# 	Epoch 3, Batch 110: Loss: 1.7072
# 	Epoch 3, Batch 120: Loss: 1.2916
# 	Epoch 3, Batch 130: Loss: 0.7848
# 	Epoch 3, Batch 140: Loss: 0.1926
# Epoch: 3, val_loss: 0.61, train_loss: 0.65 val_acc: 77.18, train_acc: 73.78
# 	Epoch 4, Batch 10: Loss: 0.5288
# 	Epoch 4, Batch 20: Loss: 1.0707
# 	Epoch 4, Batch 30: Loss: 1.4731
# 	Epoch 4, Batch 40: Loss: 1.7942
# 	Epoch 4, Batch 50: Loss: 2.0271
# 	Epoch 4, Batch 60: Loss: 2.1462
# 	Epoch 4, Batch 70: Loss: 2.2230
# 	Epoch 4, Batch 80: Loss: 2.2034
# 	Epoch 4, Batch 90: Loss: 2.0843
# 	Epoch 4, Batch 100: Loss: 1.8897
# 	Epoch 4, Batch 110: Loss: 1.5771
# 	Epoch 4, Batch 120: Loss: 1.1929
# 	Epoch 4, Batch 130: Loss: 0.7293
# 	Epoch 4, Batch 140: Loss: 0.1808
# Epoch: 4, val_loss: 0.54, train_loss: 0.61 val_acc: 77.33, train_acc: 76.13
# 	Epoch 5, Batch 10: Loss: 0.4563
# 	Epoch 5, Batch 20: Loss: 0.8970
# 	Epoch 5, Batch 30: Loss: 1.2144
# 	Epoch 5, Batch 40: Loss: 1.4791
# 	Epoch 5, Batch 50: Loss: 1.6847
# 	Epoch 5, Batch 60: Loss: 1.8481
# 	Epoch 5, Batch 70: Loss: 1.9436
# 	Epoch 5, Batch 80: Loss: 1.8964
# 	Epoch 5, Batch 90: Loss: 1.8134
# 	Epoch 5, Batch 100: Loss: 1.6329
# 	Epoch 5, Batch 110: Loss: 1.3709
# 	Epoch 5, Batch 120: Loss: 1.0499
# 	Epoch 5, Batch 130: Loss: 0.6440
# 	Epoch 5, Batch 140: Loss: 0.1594
# Epoch: 5, val_loss: 0.44, train_loss: 0.54 val_acc: 81.42, train_acc: 79.53
# 	Epoch 6, Batch 10: Loss: 0.4410
# 	Epoch 6, Batch 20: Loss: 0.8378
# 	Epoch 6, Batch 30: Loss: 1.1105
# 	Epoch 6, Batch 40: Loss: 1.3385
# 	Epoch 6, Batch 50: Loss: 1.5675
# 	Epoch 6, Batch 60: Loss: 1.6594
# 	Epoch 6, Batch 70: Loss: 1.6852
# 	Epoch 6, Batch 80: Loss: 1.6684
# 	Epoch 6, Batch 90: Loss: 1.5766
# 	Epoch 6, Batch 100: Loss: 1.4322
# 	Epoch 6, Batch 110: Loss: 1.2194
# 	Epoch 6, Batch 120: Loss: 0.9211
# 	Epoch 6, Batch 130: Loss: 0.5678
# 	Epoch 6, Batch 140: Loss: 0.1401
# Epoch: 6, val_loss: 0.34, train_loss: 0.47 val_acc: 86.28, train_acc: 82.46
# 	Epoch 7, Batch 10: Loss: 0.3948
# 	Epoch 7, Batch 20: Loss: 0.8306
# 	Epoch 7, Batch 30: Loss: 1.0747
# 	Epoch 7, Batch 40: Loss: 1.3117
# 	Epoch 7, Batch 50: Loss: 1.4487
# 	Epoch 7, Batch 60: Loss: 1.5353
# 	Epoch 7, Batch 70: Loss: 1.6047
# 	Epoch 7, Batch 80: Loss: 1.5612
# 	Epoch 7, Batch 90: Loss: 1.4913
# 	Epoch 7, Batch 100: Loss: 1.3507
# 	Epoch 7, Batch 110: Loss: 1.1224
# 	Epoch 7, Batch 120: Loss: 0.8586
# 	Epoch 7, Batch 130: Loss: 0.5175
# 	Epoch 7, Batch 140: Loss: 0.1309
# Epoch: 7, val_loss: 0.40, train_loss: 0.44 val_acc: 84.58, train_acc: 83.74
# 	Epoch 8, Batch 10: Loss: 0.3860
# 	Epoch 8, Batch 20: Loss: 0.7024
# 	Epoch 8, Batch 30: Loss: 0.9526
# 	Epoch 8, Batch 40: Loss: 1.1165
# 	Epoch 8, Batch 50: Loss: 1.2815
# 	Epoch 8, Batch 60: Loss: 1.4358
# 	Epoch 8, Batch 70: Loss: 1.4661
# 	Epoch 8, Batch 80: Loss: 1.4431
# 	Epoch 8, Batch 90: Loss: 1.3905
# 	Epoch 8, Batch 100: Loss: 1.2538
# 	Epoch 8, Batch 110: Loss: 1.0686
# 	Epoch 8, Batch 120: Loss: 0.7977
# 	Epoch 8, Batch 130: Loss: 0.4883
# 	Epoch 8, Batch 140: Loss: 0.1213
# Epoch: 8, val_loss: 0.52, train_loss: 0.41 val_acc: 77.02, train_acc: 84.93
# 	Epoch 9, Batch 10: Loss: 0.4019
# 	Epoch 9, Batch 20: Loss: 0.7105
# 	Epoch 9, Batch 30: Loss: 0.9504
# 	Epoch 9, Batch 40: Loss: 1.1129
# 	Epoch 9, Batch 50: Loss: 1.2941
# 	Epoch 9, Batch 60: Loss: 1.4222
# 	Epoch 9, Batch 70: Loss: 1.4300
# 	Epoch 9, Batch 80: Loss: 1.3877
# 	Epoch 9, Batch 90: Loss: 1.2984
# 	Epoch 9, Batch 100: Loss: 1.1579
# 	Epoch 9, Batch 110: Loss: 0.9584
# 	Epoch 9, Batch 120: Loss: 0.7296
# 	Epoch 9, Batch 130: Loss: 0.4576
# 	Epoch 9, Batch 140: Loss: 0.1118
# Epoch: 9, val_loss: 0.39, train_loss: 0.38 val_acc: 83.89, train_acc: 85.83
# 	Epoch 10, Batch 10: Loss: 0.3693
# 	Epoch 10, Batch 20: Loss: 0.6560
# 	Epoch 10, Batch 30: Loss: 0.9446
# 	Epoch 10, Batch 40: Loss: 1.1433
# 	Epoch 10, Batch 50: Loss: 1.3408
# 	Epoch 10, Batch 60: Loss: 1.3912
# 	Epoch 10, Batch 70: Loss: 1.3887
# 	Epoch 10, Batch 80: Loss: 1.3607
# 	Epoch 10, Batch 90: Loss: 1.3090
# 	Epoch 10, Batch 100: Loss: 1.1768
# 	Epoch 10, Batch 110: Loss: 0.9695
# 	Epoch 10, Batch 120: Loss: 0.7268
# 	Epoch 10, Batch 130: Loss: 0.4422
# 	Epoch 10, Batch 140: Loss: 0.1090
# Epoch: 10, val_loss: 0.25, train_loss: 0.37 val_acc: 90.52, train_acc: 86.93
# 	Epoch 11, Batch 10: Loss: 0.2359
# 	Epoch 11, Batch 20: Loss: 0.4278
# 	Epoch 11, Batch 30: Loss: 0.7508
# 	Epoch 11, Batch 40: Loss: 0.9062
# 	Epoch 11, Batch 50: Loss: 1.0982
# 	Epoch 11, Batch 60: Loss: 1.2111
# 	Epoch 11, Batch 70: Loss: 1.2626
# 	Epoch 11, Batch 80: Loss: 1.2362
# 	Epoch 11, Batch 90: Loss: 1.1520
# 	Epoch 11, Batch 100: Loss: 1.0126
# 	Epoch 11, Batch 110: Loss: 0.8623
# 	Epoch 11, Batch 120: Loss: 0.6500
# 	Epoch 11, Batch 130: Loss: 0.3934
# 	Epoch 11, Batch 140: Loss: 0.0981
# Epoch: 11, val_loss: 0.23, train_loss: 0.33 val_acc: 92.75, train_acc: 87.70
# 	Epoch 12, Batch 10: Loss: 0.3654
# 	Epoch 12, Batch 20: Loss: 0.5968
# 	Epoch 12, Batch 30: Loss: 0.8146
# 	Epoch 12, Batch 40: Loss: 0.9631
# 	Epoch 12, Batch 50: Loss: 1.0838
# 	Epoch 12, Batch 60: Loss: 1.1400
# 	Epoch 12, Batch 70: Loss: 1.1915
# 	Epoch 12, Batch 80: Loss: 1.1545
# 	Epoch 12, Batch 90: Loss: 1.0778
# 	Epoch 12, Batch 100: Loss: 0.9544
# 	Epoch 12, Batch 110: Loss: 0.8072
# 	Epoch 12, Batch 120: Loss: 0.6103
# 	Epoch 12, Batch 130: Loss: 0.3781
# 	Epoch 12, Batch 140: Loss: 0.0928
# Epoch: 12, val_loss: 0.25, train_loss: 0.31 val_acc: 91.13, train_acc: 88.48
# 	Epoch 13, Batch 10: Loss: 0.2722
# 	Epoch 13, Batch 20: Loss: 0.4824
# 	Epoch 13, Batch 30: Loss: 0.6844
# 	Epoch 13, Batch 40: Loss: 0.8309
# 	Epoch 13, Batch 50: Loss: 0.9633
# 	Epoch 13, Batch 60: Loss: 1.0426
# 	Epoch 13, Batch 70: Loss: 1.0467
# 	Epoch 13, Batch 80: Loss: 1.0327
# 	Epoch 13, Batch 90: Loss: 0.9800
# 	Epoch 13, Batch 100: Loss: 0.9110
# 	Epoch 13, Batch 110: Loss: 0.7825
# 	Epoch 13, Batch 120: Loss: 0.5823
# 	Epoch 13, Batch 130: Loss: 0.3534
# 	Epoch 13, Batch 140: Loss: 0.0865
# Epoch: 13, val_loss: 0.21, train_loss: 0.29 val_acc: 92.52, train_acc: 89.27
# 	Epoch 14, Batch 10: Loss: 0.2145
# 	Epoch 14, Batch 20: Loss: 0.4308
# 	Epoch 14, Batch 30: Loss: 0.6455
# 	Epoch 14, Batch 40: Loss: 0.7945
# 	Epoch 14, Batch 50: Loss: 0.9286
# 	Epoch 14, Batch 60: Loss: 0.9537
# 	Epoch 14, Batch 70: Loss: 0.9652
# 	Epoch 14, Batch 80: Loss: 0.9758
# 	Epoch 14, Batch 90: Loss: 0.9106
# 	Epoch 14, Batch 100: Loss: 0.8132
# 	Epoch 14, Batch 110: Loss: 0.6923
# 	Epoch 14, Batch 120: Loss: 0.5331
# 	Epoch 14, Batch 130: Loss: 0.3269
# 	Epoch 14, Batch 140: Loss: 0.0803
# Epoch: 14, val_loss: 0.19, train_loss: 0.27 val_acc: 92.91, train_acc: 90.17
# 	Epoch 15, Batch 10: Loss: 0.2631
# 	Epoch 15, Batch 20: Loss: 0.4546
# 	Epoch 15, Batch 30: Loss: 0.6243
# 	Epoch 15, Batch 40: Loss: 0.7611
# 	Epoch 15, Batch 50: Loss: 0.8932
# 	Epoch 15, Batch 60: Loss: 0.9375
# 	Epoch 15, Batch 70: Loss: 0.9547
# 	Epoch 15, Batch 80: Loss: 0.9276
# 	Epoch 15, Batch 90: Loss: 0.8606
# 	Epoch 15, Batch 100: Loss: 0.7676
# 	Epoch 15, Batch 110: Loss: 0.6371
# 	Epoch 15, Batch 120: Loss: 0.4815
# 	Epoch 15, Batch 130: Loss: 0.2897
# 	Epoch 15, Batch 140: Loss: 0.0721
# Epoch: 15, val_loss: 0.18, train_loss: 0.25 val_acc: 93.45, train_acc: 90.83
# 	Epoch 16, Batch 10: Loss: 0.1761
# 	Epoch 16, Batch 20: Loss: 0.3273
# 	Epoch 16, Batch 30: Loss: 0.5066
# 	Epoch 16, Batch 40: Loss: 0.6373
# 	Epoch 16, Batch 50: Loss: 0.7346
# 	Epoch 16, Batch 60: Loss: 0.7975
# 	Epoch 16, Batch 70: Loss: 0.7982
# 	Epoch 16, Batch 80: Loss: 0.7990
# 	Epoch 16, Batch 90: Loss: 0.7714
# 	Epoch 16, Batch 100: Loss: 0.6962
# 	Epoch 16, Batch 110: Loss: 0.5852
# 	Epoch 16, Batch 120: Loss: 0.4509
# 	Epoch 16, Batch 130: Loss: 0.2734
# 	Epoch 16, Batch 140: Loss: 0.0701
# Epoch: 16, val_loss: 0.39, train_loss: 0.24 val_acc: 85.35, train_acc: 91.36
# 	Epoch 17, Batch 10: Loss: 0.2797
# 	Epoch 17, Batch 20: Loss: 0.4632
# 	Epoch 17, Batch 30: Loss: 0.5885
# 	Epoch 17, Batch 40: Loss: 0.6690
# 	Epoch 17, Batch 50: Loss: 0.7947
# 	Epoch 17, Batch 60: Loss: 0.8143
# 	Epoch 17, Batch 70: Loss: 0.8477
# 	Epoch 17, Batch 80: Loss: 0.8326
# 	Epoch 17, Batch 90: Loss: 0.7839
# 	Epoch 17, Batch 100: Loss: 0.6858
# 	Epoch 17, Batch 110: Loss: 0.5650
# 	Epoch 17, Batch 120: Loss: 0.4352
# 	Epoch 17, Batch 130: Loss: 0.2626
# 	Epoch 17, Batch 140: Loss: 0.0665
# Epoch: 17, val_loss: 0.20, train_loss: 0.23 val_acc: 92.60, train_acc: 92.31
# 	Epoch 18, Batch 10: Loss: 0.3002
# 	Epoch 18, Batch 20: Loss: 0.5260
# 	Epoch 18, Batch 30: Loss: 0.6809
# 	Epoch 18, Batch 40: Loss: 0.7678
# 	Epoch 18, Batch 50: Loss: 0.8698
# 	Epoch 18, Batch 60: Loss: 0.9201
# 	Epoch 18, Batch 70: Loss: 0.9634
# 	Epoch 18, Batch 80: Loss: 0.9232
# 	Epoch 18, Batch 90: Loss: 0.8478
# 	Epoch 18, Batch 100: Loss: 0.7634
# 	Epoch 18, Batch 110: Loss: 0.6282
# 	Epoch 18, Batch 120: Loss: 0.4795
# 	Epoch 18, Batch 130: Loss: 0.2906
# 	Epoch 18, Batch 140: Loss: 0.0736
# Epoch: 18, val_loss: 0.28, train_loss: 0.25 val_acc: 89.36, train_acc: 91.30
# 	Epoch 19, Batch 10: Loss: 0.1595
# 	Epoch 19, Batch 20: Loss: 0.3390
# 	Epoch 19, Batch 30: Loss: 0.5387
# 	Epoch 19, Batch 40: Loss: 0.6800
# 	Epoch 19, Batch 50: Loss: 0.7434
# 	Epoch 19, Batch 60: Loss: 0.7681
# 	Epoch 19, Batch 70: Loss: 0.7843
# 	Epoch 19, Batch 80: Loss: 0.7593
# 	Epoch 19, Batch 90: Loss: 0.7003
# 	Epoch 19, Batch 100: Loss: 0.6617
# 	Epoch 19, Batch 110: Loss: 0.5549
# 	Epoch 19, Batch 120: Loss: 0.4220
# 	Epoch 19, Batch 130: Loss: 0.2533
# 	Epoch 19, Batch 140: Loss: 0.0627
# Epoch: 19, val_loss: 0.33, train_loss: 0.21 val_acc: 86.74, train_acc: 92.73
# 	Epoch 20, Batch 10: Loss: 0.1900
# 	Epoch 20, Batch 20: Loss: 0.3160
# 	Epoch 20, Batch 30: Loss: 0.4309
# 	Epoch 20, Batch 40: Loss: 0.5248
# 	Epoch 20, Batch 50: Loss: 0.5696
# 	Epoch 20, Batch 60: Loss: 0.6128
# 	Epoch 20, Batch 70: Loss: 0.6567
# 	Epoch 20, Batch 80: Loss: 0.6490
# 	Epoch 20, Batch 90: Loss: 0.6082
# 	Epoch 20, Batch 100: Loss: 0.5819
# 	Epoch 20, Batch 110: Loss: 0.5079
# 	Epoch 20, Batch 120: Loss: 0.3852
# 	Epoch 20, Batch 130: Loss: 0.2367
# 	Epoch 20, Batch 140: Loss: 0.0583
# Epoch: 20, val_loss: 0.16, train_loss: 0.20 val_acc: 94.14, train_acc: 92.88
# 	Epoch 21, Batch 10: Loss: 0.1572
# 	Epoch 21, Batch 20: Loss: 0.3292
# 	Epoch 21, Batch 30: Loss: 0.4670
# 	Epoch 21, Batch 40: Loss: 0.5756
# 	Epoch 21, Batch 50: Loss: 0.6761
# 	Epoch 21, Batch 60: Loss: 0.7315
# 	Epoch 21, Batch 70: Loss: 0.7589
# 	Epoch 21, Batch 80: Loss: 0.7200
# 	Epoch 21, Batch 90: Loss: 0.6959
# 	Epoch 21, Batch 100: Loss: 0.6239
# 	Epoch 21, Batch 110: Loss: 0.5310
# 	Epoch 21, Batch 120: Loss: 0.3976
# 	Epoch 21, Batch 130: Loss: 0.2450
# 	Epoch 21, Batch 140: Loss: 0.0604
# Epoch: 21, val_loss: 0.17, train_loss: 0.20 val_acc: 93.22, train_acc: 92.51
# 	Epoch 22, Batch 10: Loss: 0.1733
# 	Epoch 22, Batch 20: Loss: 0.3241
# 	Epoch 22, Batch 30: Loss: 0.4103
# 	Epoch 22, Batch 40: Loss: 0.5209
# 	Epoch 22, Batch 50: Loss: 0.5821
# 	Epoch 22, Batch 60: Loss: 0.6064
# 	Epoch 22, Batch 70: Loss: 0.5970
# 	Epoch 22, Batch 80: Loss: 0.5921
# 	Epoch 22, Batch 90: Loss: 0.5692
# 	Epoch 22, Batch 100: Loss: 0.5163
# 	Epoch 22, Batch 110: Loss: 0.4396
# 	Epoch 22, Batch 120: Loss: 0.3564
# 	Epoch 22, Batch 130: Loss: 0.2168
# 	Epoch 22, Batch 140: Loss: 0.0546
# Epoch: 22, val_loss: 0.21, train_loss: 0.18 val_acc: 92.98, train_acc: 93.04
# 	Epoch 23, Batch 10: Loss: 0.1912
# 	Epoch 23, Batch 20: Loss: 0.3480
# 	Epoch 23, Batch 30: Loss: 0.4750
# 	Epoch 23, Batch 40: Loss: 0.5561
# 	Epoch 23, Batch 50: Loss: 0.6388
# 	Epoch 23, Batch 60: Loss: 0.6960
# 	Epoch 23, Batch 70: Loss: 0.7022
# 	Epoch 23, Batch 80: Loss: 0.6639
# 	Epoch 23, Batch 90: Loss: 0.6335
# 	Epoch 23, Batch 100: Loss: 0.5774
# 	Epoch 23, Batch 110: Loss: 0.4868
# 	Epoch 23, Batch 120: Loss: 0.3674
# 	Epoch 23, Batch 130: Loss: 0.2204
# 	Epoch 23, Batch 140: Loss: 0.0539
# Epoch: 23, val_loss: 0.14, train_loss: 0.18 val_acc: 95.76, train_acc: 93.57
# 	Epoch 24, Batch 10: Loss: 0.1386
# 	Epoch 24, Batch 20: Loss: 0.2972
# 	Epoch 24, Batch 30: Loss: 0.3968
# 	Epoch 24, Batch 40: Loss: 0.4641
# 	Epoch 24, Batch 50: Loss: 0.5160
# 	Epoch 24, Batch 60: Loss: 0.5395
# 	Epoch 24, Batch 70: Loss: 0.5706
# 	Epoch 24, Batch 80: Loss: 0.5669
# 	Epoch 24, Batch 90: Loss: 0.5325
# 	Epoch 24, Batch 100: Loss: 0.4810
# 	Epoch 24, Batch 110: Loss: 0.4086
# 	Epoch 24, Batch 120: Loss: 0.3138
# 	Epoch 24, Batch 130: Loss: 0.1945
# 	Epoch 24, Batch 140: Loss: 0.0492
# Epoch: 24, val_loss: 0.34, train_loss: 0.17 val_acc: 86.97, train_acc: 94.34
# 	Epoch 25, Batch 10: Loss: 0.1816
# 	Epoch 25, Batch 20: Loss: 0.3227
# 	Epoch 25, Batch 30: Loss: 0.4177
# 	Epoch 25, Batch 40: Loss: 0.4775
# 	Epoch 25, Batch 50: Loss: 0.5164
# 	Epoch 25, Batch 60: Loss: 0.5272
# 	Epoch 25, Batch 70: Loss: 0.5407
# 	Epoch 25, Batch 80: Loss: 0.5341
# 	Epoch 25, Batch 90: Loss: 0.4990
# 	Epoch 25, Batch 100: Loss: 0.4527
# 	Epoch 25, Batch 110: Loss: 0.3862
# 	Epoch 25, Batch 120: Loss: 0.2924
# 	Epoch 25, Batch 130: Loss: 0.1809
# 	Epoch 25, Batch 140: Loss: 0.0443
# Epoch: 25, val_loss: 0.15, train_loss: 0.15 val_acc: 94.60, train_acc: 94.65
# 	Epoch 26, Batch 10: Loss: 0.1215
# 	Epoch 26, Batch 20: Loss: 0.2278
# 	Epoch 26, Batch 30: Loss: 0.3314
# 	Epoch 26, Batch 40: Loss: 0.4243
# 	Epoch 26, Batch 50: Loss: 0.4638
# 	Epoch 26, Batch 60: Loss: 0.4936
# 	Epoch 26, Batch 70: Loss: 0.5377
# 	Epoch 26, Batch 80: Loss: 0.5198
# 	Epoch 26, Batch 90: Loss: 0.5275
# 	Epoch 26, Batch 100: Loss: 0.4815
# 	Epoch 26, Batch 110: Loss: 0.4116
# 	Epoch 26, Batch 120: Loss: 0.3187
# 	Epoch 26, Batch 130: Loss: 0.1930
# 	Epoch 26, Batch 140: Loss: 0.0479
# Epoch: 26, val_loss: 0.16, train_loss: 0.16 val_acc: 93.60, train_acc: 94.49
# 	Epoch 27, Batch 10: Loss: 0.1954
# 	Epoch 27, Batch 20: Loss: 0.2846
# 	Epoch 27, Batch 30: Loss: 0.3581
# 	Epoch 27, Batch 40: Loss: 0.4092
# 	Epoch 27, Batch 50: Loss: 0.4822
# 	Epoch 27, Batch 60: Loss: 0.5081
# 	Epoch 27, Batch 70: Loss: 0.5401
# 	Epoch 27, Batch 80: Loss: 0.5303
# 	Epoch 27, Batch 90: Loss: 0.5102
# 	Epoch 27, Batch 100: Loss: 0.4617
# 	Epoch 27, Batch 110: Loss: 0.3838
# 	Epoch 27, Batch 120: Loss: 0.2987
# 	Epoch 27, Batch 130: Loss: 0.1784
# 	Epoch 27, Batch 140: Loss: 0.0441
# Epoch: 27, val_loss: 0.12, train_loss: 0.15 val_acc: 95.68, train_acc: 94.95
# 	Epoch 28, Batch 10: Loss: 0.1072
# 	Epoch 28, Batch 20: Loss: 0.1688
# 	Epoch 28, Batch 30: Loss: 0.2793
# 	Epoch 28, Batch 40: Loss: 0.3991
# 	Epoch 28, Batch 50: Loss: 0.4566
# 	Epoch 28, Batch 60: Loss: 0.4971
# 	Epoch 28, Batch 70: Loss: 0.5268
# 	Epoch 28, Batch 80: Loss: 0.5180
# 	Epoch 28, Batch 90: Loss: 0.5024
# 	Epoch 28, Batch 100: Loss: 0.4464
# 	Epoch 28, Batch 110: Loss: 0.3807
# 	Epoch 28, Batch 120: Loss: 0.2988
# 	Epoch 28, Batch 130: Loss: 0.1835
# 	Epoch 28, Batch 140: Loss: 0.0458
# Epoch: 28, val_loss: 0.23, train_loss: 0.15 val_acc: 91.36, train_acc: 94.65
# 	Epoch 29, Batch 10: Loss: 0.1560
# 	Epoch 29, Batch 20: Loss: 0.3249
# 	Epoch 29, Batch 30: Loss: 0.4091
# 	Epoch 29, Batch 40: Loss: 0.4651
# 	Epoch 29, Batch 50: Loss: 0.5014
# 	Epoch 29, Batch 60: Loss: 0.4987
# 	Epoch 29, Batch 70: Loss: 0.5017
# 	Epoch 29, Batch 80: Loss: 0.4900
# 	Epoch 29, Batch 90: Loss: 0.4857
# 	Epoch 29, Batch 100: Loss: 0.4313
# 	Epoch 29, Batch 110: Loss: 0.3701
# 	Epoch 29, Batch 120: Loss: 0.2746
# 	Epoch 29, Batch 130: Loss: 0.1716
# 	Epoch 29, Batch 140: Loss: 0.0431
# Epoch: 29, val_loss: 0.13, train_loss: 0.15 val_acc: 94.06, train_acc: 94.80
# 	Epoch 30, Batch 10: Loss: 0.1066
# 	Epoch 30, Batch 20: Loss: 0.1941
# 	Epoch 30, Batch 30: Loss: 0.2515
# 	Epoch 30, Batch 40: Loss: 0.2925
# 	Epoch 30, Batch 50: Loss: 0.3549
# 	Epoch 30, Batch 60: Loss: 0.3623
# 	Epoch 30, Batch 70: Loss: 0.4426
# 	Epoch 30, Batch 80: Loss: 0.4674
# 	Epoch 30, Batch 90: Loss: 0.4436
# 	Epoch 30, Batch 100: Loss: 0.4050
# 	Epoch 30, Batch 110: Loss: 0.3521
# 	Epoch 30, Batch 120: Loss: 0.2591
# 	Epoch 30, Batch 130: Loss: 0.1650
# 	Epoch 30, Batch 140: Loss: 0.0411
# Epoch: 30, val_loss: 0.18, train_loss: 0.14 val_acc: 93.75, train_acc: 95.46
# 	Epoch 31, Batch 10: Loss: 0.1017
# 	Epoch 31, Batch 20: Loss: 0.2090
# 	Epoch 31, Batch 30: Loss: 0.2738
# 	Epoch 31, Batch 40: Loss: 0.3313
# 	Epoch 31, Batch 50: Loss: 0.3727
# 	Epoch 31, Batch 60: Loss: 0.4371
# 	Epoch 31, Batch 70: Loss: 0.4360
# 	Epoch 31, Batch 80: Loss: 0.4480
# 	Epoch 31, Batch 90: Loss: 0.4376
# 	Epoch 31, Batch 100: Loss: 0.4048
# 	Epoch 31, Batch 110: Loss: 0.3490
# 	Epoch 31, Batch 120: Loss: 0.2595
# 	Epoch 31, Batch 130: Loss: 0.1602
# 	Epoch 31, Batch 140: Loss: 0.0388
# Epoch: 31, val_loss: 0.11, train_loss: 0.13 val_acc: 95.68, train_acc: 95.55
# 	Epoch 32, Batch 10: Loss: 0.0939
# 	Epoch 32, Batch 20: Loss: 0.1970
# 	Epoch 32, Batch 30: Loss: 0.2717
# 	Epoch 32, Batch 40: Loss: 0.3419
# 	Epoch 32, Batch 50: Loss: 0.3648
# 	Epoch 32, Batch 60: Loss: 0.4356
# 	Epoch 32, Batch 70: Loss: 0.4757
# 	Epoch 32, Batch 80: Loss: 0.4881
# 	Epoch 32, Batch 90: Loss: 0.4651
# 	Epoch 32, Batch 100: Loss: 0.4165
# 	Epoch 32, Batch 110: Loss: 0.3544
# 	Epoch 32, Batch 120: Loss: 0.2666
# 	Epoch 32, Batch 130: Loss: 0.1623
# 	Epoch 32, Batch 140: Loss: 0.0393
# Epoch: 32, val_loss: 0.14, train_loss: 0.13 val_acc: 94.99, train_acc: 95.42
# 	Epoch 33, Batch 10: Loss: 0.1576
# 	Epoch 33, Batch 20: Loss: 0.2772
# 	Epoch 33, Batch 30: Loss: 0.3350
# 	Epoch 33, Batch 40: Loss: 0.3958
# 	Epoch 33, Batch 50: Loss: 0.4403
# 	Epoch 33, Batch 60: Loss: 0.4889
# 	Epoch 33, Batch 70: Loss: 0.5084
# 	Epoch 33, Batch 80: Loss: 0.5266
# 	Epoch 33, Batch 90: Loss: 0.4932
# 	Epoch 33, Batch 100: Loss: 0.4360
# 	Epoch 33, Batch 110: Loss: 0.3600
# 	Epoch 33, Batch 120: Loss: 0.2667
# 	Epoch 33, Batch 130: Loss: 0.1590
# 	Epoch 33, Batch 140: Loss: 0.0391
# Epoch: 33, val_loss: 0.10, train_loss: 0.13 val_acc: 96.68, train_acc: 95.68
# 	Epoch 34, Batch 10: Loss: 0.1362
# 	Epoch 34, Batch 20: Loss: 0.2934
# 	Epoch 34, Batch 30: Loss: 0.3799
# 	Epoch 34, Batch 40: Loss: 0.4257
# 	Epoch 34, Batch 50: Loss: 0.4437
# 	Epoch 34, Batch 60: Loss: 0.4492
# 	Epoch 34, Batch 70: Loss: 0.4666
# 	Epoch 34, Batch 80: Loss: 0.4893
# 	Epoch 34, Batch 90: Loss: 0.4503
# 	Epoch 34, Batch 100: Loss: 0.4008
# 	Epoch 34, Batch 110: Loss: 0.3317
# 	Epoch 34, Batch 120: Loss: 0.2577
# 	Epoch 34, Batch 130: Loss: 0.1577
# 	Epoch 34, Batch 140: Loss: 0.0383
# Epoch: 34, val_loss: 0.11, train_loss: 0.13 val_acc: 96.22, train_acc: 95.53
# 	Epoch 35, Batch 10: Loss: 0.1065
# 	Epoch 35, Batch 20: Loss: 0.2138
# 	Epoch 35, Batch 30: Loss: 0.2589
# 	Epoch 35, Batch 40: Loss: 0.3014
# 	Epoch 35, Batch 50: Loss: 0.3599
# 	Epoch 35, Batch 60: Loss: 0.3936
# 	Epoch 35, Batch 70: Loss: 0.4220
# 	Epoch 35, Batch 80: Loss: 0.4250
# 	Epoch 35, Batch 90: Loss: 0.3967
# 	Epoch 35, Batch 100: Loss: 0.3757
# 	Epoch 35, Batch 110: Loss: 0.3221
# 	Epoch 35, Batch 120: Loss: 0.2417
# 	Epoch 35, Batch 130: Loss: 0.1486
# 	Epoch 35, Batch 140: Loss: 0.0366
# Epoch: 35, val_loss: 0.14, train_loss: 0.13 val_acc: 95.53, train_acc: 95.68
# 	Epoch 36, Batch 10: Loss: 0.1264
# 	Epoch 36, Batch 20: Loss: 0.2541
# 	Epoch 36, Batch 30: Loss: 0.2930
# 	Epoch 36, Batch 40: Loss: 0.3469
# 	Epoch 36, Batch 50: Loss: 0.3929
# 	Epoch 36, Batch 60: Loss: 0.4418
# 	Epoch 36, Batch 70: Loss: 0.4213
# 	Epoch 36, Batch 80: Loss: 0.4211
# 	Epoch 36, Batch 90: Loss: 0.4091
# 	Epoch 36, Batch 100: Loss: 0.3689
# 	Epoch 36, Batch 110: Loss: 0.3153
# 	Epoch 36, Batch 120: Loss: 0.2344
# 	Epoch 36, Batch 130: Loss: 0.1461
# 	Epoch 36, Batch 140: Loss: 0.0359
# Epoch: 36, val_loss: 0.09, train_loss: 0.12 val_acc: 96.61, train_acc: 95.99
# 	Epoch 37, Batch 10: Loss: 0.1077
# 	Epoch 37, Batch 20: Loss: 0.1499
# 	Epoch 37, Batch 30: Loss: 0.1807
# 	Epoch 37, Batch 40: Loss: 0.2230
# 	Epoch 37, Batch 50: Loss: 0.2726
# 	Epoch 37, Batch 60: Loss: 0.3165
# 	Epoch 37, Batch 70: Loss: 0.3503
# 	Epoch 37, Batch 80: Loss: 0.3907
# 	Epoch 37, Batch 90: Loss: 0.3525
# 	Epoch 37, Batch 100: Loss: 0.3207
# 	Epoch 37, Batch 110: Loss: 0.2658
# 	Epoch 37, Batch 120: Loss: 0.2077
# 	Epoch 37, Batch 130: Loss: 0.1259
# 	Epoch 37, Batch 140: Loss: 0.0313
# Epoch: 37, val_loss: 0.10, train_loss: 0.10 val_acc: 96.68, train_acc: 96.72
# 	Epoch 38, Batch 10: Loss: 0.1095
# 	Epoch 38, Batch 20: Loss: 0.2006
# 	Epoch 38, Batch 30: Loss: 0.2609
# 	Epoch 38, Batch 40: Loss: 0.3180
# 	Epoch 38, Batch 50: Loss: 0.3581
# 	Epoch 38, Batch 60: Loss: 0.3741
# 	Epoch 38, Batch 70: Loss: 0.4298
# 	Epoch 38, Batch 80: Loss: 0.4157
# 	Epoch 38, Batch 90: Loss: 0.3908
# 	Epoch 38, Batch 100: Loss: 0.3502
# 	Epoch 38, Batch 110: Loss: 0.2906
# 	Epoch 38, Batch 120: Loss: 0.2271
# 	Epoch 38, Batch 130: Loss: 0.1402
# 	Epoch 38, Batch 140: Loss: 0.0349
# Epoch: 38, val_loss: 0.09, train_loss: 0.12 val_acc: 96.30, train_acc: 95.72
# 	Epoch 39, Batch 10: Loss: 0.0634
# 	Epoch 39, Batch 20: Loss: 0.1855
# 	Epoch 39, Batch 30: Loss: 0.2635
# 	Epoch 39, Batch 40: Loss: 0.2956
# 	Epoch 39, Batch 50: Loss: 0.3476
# 	Epoch 39, Batch 60: Loss: 0.4060
# 	Epoch 39, Batch 70: Loss: 0.3972
# 	Epoch 39, Batch 80: Loss: 0.3765
# 	Epoch 39, Batch 90: Loss: 0.3614
# 	Epoch 39, Batch 100: Loss: 0.3230
# 	Epoch 39, Batch 110: Loss: 0.2714
# 	Epoch 39, Batch 120: Loss: 0.2060
# 	Epoch 39, Batch 130: Loss: 0.1267
# 	Epoch 39, Batch 140: Loss: 0.0310
# Epoch: 39, val_loss: 0.11, train_loss: 0.10 val_acc: 96.38, train_acc: 96.08
# 	Epoch 40, Batch 10: Loss: 0.0969
# 	Epoch 40, Batch 20: Loss: 0.1760
# 	Epoch 40, Batch 30: Loss: 0.1981
# 	Epoch 40, Batch 40: Loss: 0.2606
# 	Epoch 40, Batch 50: Loss: 0.2983
# 	Epoch 40, Batch 60: Loss: 0.3448
# 	Epoch 40, Batch 70: Loss: 0.3595
# 	Epoch 40, Batch 80: Loss: 0.3617
# 	Epoch 40, Batch 90: Loss: 0.3542
# 	Epoch 40, Batch 100: Loss: 0.3104
# 	Epoch 40, Batch 110: Loss: 0.2656
# 	Epoch 40, Batch 120: Loss: 0.2049
# 	Epoch 40, Batch 130: Loss: 0.1264
# 	Epoch 40, Batch 140: Loss: 0.0310
# Epoch: 40, val_loss: 0.25, train_loss: 0.10 val_acc: 90.75, train_acc: 96.41
# 	Epoch 41, Batch 10: Loss: 0.0897
# 	Epoch 41, Batch 20: Loss: 0.2149
# 	Epoch 41, Batch 30: Loss: 0.2825
# 	Epoch 41, Batch 40: Loss: 0.3173
# 	Epoch 41, Batch 50: Loss: 0.3599
# 	Epoch 41, Batch 60: Loss: 0.3732
# 	Epoch 41, Batch 70: Loss: 0.3850
# 	Epoch 41, Batch 80: Loss: 0.3840
# 	Epoch 41, Batch 90: Loss: 0.3683
# 	Epoch 41, Batch 100: Loss: 0.3262
# 	Epoch 41, Batch 110: Loss: 0.2728
# 	Epoch 41, Batch 120: Loss: 0.2037
# 	Epoch 41, Batch 130: Loss: 0.1234
# 	Epoch 41, Batch 140: Loss: 0.0301
# Epoch: 41, val_loss: 0.15, train_loss: 0.10 val_acc: 95.61, train_acc: 96.52
# 	Epoch 42, Batch 10: Loss: 0.0885
# 	Epoch 42, Batch 20: Loss: 0.1736
# 	Epoch 42, Batch 30: Loss: 0.2693
# 	Epoch 42, Batch 40: Loss: 0.3291
# 	Epoch 42, Batch 50: Loss: 0.3554
# 	Epoch 42, Batch 60: Loss: 0.3607
# 	Epoch 42, Batch 70: Loss: 0.3606
# 	Epoch 42, Batch 80: Loss: 0.3514
# 	Epoch 42, Batch 90: Loss: 0.3442
# 	Epoch 42, Batch 100: Loss: 0.3111
# 	Epoch 42, Batch 110: Loss: 0.2690
# 	Epoch 42, Batch 120: Loss: 0.2043
# 	Epoch 42, Batch 130: Loss: 0.1320
# 	Epoch 42, Batch 140: Loss: 0.0332
# Epoch: 42, val_loss: 0.10, train_loss: 0.11 val_acc: 96.30, train_acc: 96.10
# 	Epoch 43, Batch 10: Loss: 0.1513
# 	Epoch 43, Batch 20: Loss: 0.1885
# 	Epoch 43, Batch 30: Loss: 0.2462
# 	Epoch 43, Batch 40: Loss: 0.3055
# 	Epoch 43, Batch 50: Loss: 0.3263
# 	Epoch 43, Batch 60: Loss: 0.3354
# 	Epoch 43, Batch 70: Loss: 0.3489
# 	Epoch 43, Batch 80: Loss: 0.3377
# 	Epoch 43, Batch 90: Loss: 0.3200
# 	Epoch 43, Batch 100: Loss: 0.2988
# 	Epoch 43, Batch 110: Loss: 0.2503
# 	Epoch 43, Batch 120: Loss: 0.1911
# 	Epoch 43, Batch 130: Loss: 0.1187
# 	Epoch 43, Batch 140: Loss: 0.0307
# Epoch 00043: reducing learning rate of group 0 to 2.0000e-04.
# Epoch: 43, val_loss: 0.12, train_loss: 0.10 val_acc: 96.22, train_acc: 96.50
# 	Epoch 44, Batch 10: Loss: 0.0800
# 	Epoch 44, Batch 20: Loss: 0.1228
# 	Epoch 44, Batch 30: Loss: 0.1942
# 	Epoch 44, Batch 40: Loss: 0.2262
# 	Epoch 44, Batch 50: Loss: 0.2563
# 	Epoch 44, Batch 60: Loss: 0.2619
# 	Epoch 44, Batch 70: Loss: 0.2613
# 	Epoch 44, Batch 80: Loss: 0.2570
# 	Epoch 44, Batch 90: Loss: 0.2356
# 	Epoch 44, Batch 100: Loss: 0.2126
# 	Epoch 44, Batch 110: Loss: 0.1789
# 	Epoch 44, Batch 120: Loss: 0.1367
# 	Epoch 44, Batch 130: Loss: 0.0847
# 	Epoch 44, Batch 140: Loss: 0.0209
# Epoch: 44, val_loss: 0.06, train_loss: 0.07 val_acc: 98.15, train_acc: 97.64
# 	Epoch 45, Batch 10: Loss: 0.0555
# 	Epoch 45, Batch 20: Loss: 0.0913
# 	Epoch 45, Batch 30: Loss: 0.1472
# 	Epoch 45, Batch 40: Loss: 0.1985
# 	Epoch 45, Batch 50: Loss: 0.2389
# 	Epoch 45, Batch 60: Loss: 0.2635
# 	Epoch 45, Batch 70: Loss: 0.2472
# 	Epoch 45, Batch 80: Loss: 0.2470
# 	Epoch 45, Batch 90: Loss: 0.2302
# 	Epoch 45, Batch 100: Loss: 0.1988
# 	Epoch 45, Batch 110: Loss: 0.1615
# 	Epoch 45, Batch 120: Loss: 0.1198
# 	Epoch 45, Batch 130: Loss: 0.0713
# 	Epoch 45, Batch 140: Loss: 0.0174
# Epoch: 45, val_loss: 0.06, train_loss: 0.06 val_acc: 97.92, train_acc: 98.06
# 	Epoch 46, Batch 10: Loss: 0.0685
# 	Epoch 46, Batch 20: Loss: 0.1081
# 	Epoch 46, Batch 30: Loss: 0.1670
# 	Epoch 46, Batch 40: Loss: 0.1663
# 	Epoch 46, Batch 50: Loss: 0.1959
# 	Epoch 46, Batch 60: Loss: 0.2185
# 	Epoch 46, Batch 70: Loss: 0.2113
# 	Epoch 46, Batch 80: Loss: 0.2242
# 	Epoch 46, Batch 90: Loss: 0.2082
# 	Epoch 46, Batch 100: Loss: 0.1854
# 	Epoch 46, Batch 110: Loss: 0.1611
# 	Epoch 46, Batch 120: Loss: 0.1186
# 	Epoch 46, Batch 130: Loss: 0.0706
# 	Epoch 46, Batch 140: Loss: 0.0180
# Epoch: 46, val_loss: 0.05, train_loss: 0.06 val_acc: 98.07, train_acc: 98.06
# 	Epoch 47, Batch 10: Loss: 0.0725
# 	Epoch 47, Batch 20: Loss: 0.1124
# 	Epoch 47, Batch 30: Loss: 0.1481
# 	Epoch 47, Batch 40: Loss: 0.1696
# 	Epoch 47, Batch 50: Loss: 0.1878
# 	Epoch 47, Batch 60: Loss: 0.1927
# 	Epoch 47, Batch 70: Loss: 0.1968
# 	Epoch 47, Batch 80: Loss: 0.1859
# 	Epoch 47, Batch 90: Loss: 0.1639
# 	Epoch 47, Batch 100: Loss: 0.1492
# 	Epoch 47, Batch 110: Loss: 0.1302
# 	Epoch 47, Batch 120: Loss: 0.1037
# 	Epoch 47, Batch 130: Loss: 0.0628
# 	Epoch 47, Batch 140: Loss: 0.0156
# Epoch: 47, val_loss: 0.05, train_loss: 0.05 val_acc: 98.15, train_acc: 98.19
# 	Epoch 48, Batch 10: Loss: 0.0350
# 	Epoch 48, Batch 20: Loss: 0.0927
# 	Epoch 48, Batch 30: Loss: 0.1149
# 	Epoch 48, Batch 40: Loss: 0.1419
# 	Epoch 48, Batch 50: Loss: 0.1626
# 	Epoch 48, Batch 60: Loss: 0.1675
# 	Epoch 48, Batch 70: Loss: 0.1823
# 	Epoch 48, Batch 80: Loss: 0.1862
# 	Epoch 48, Batch 90: Loss: 0.1775
# 	Epoch 48, Batch 100: Loss: 0.1650
# 	Epoch 48, Batch 110: Loss: 0.1415
# 	Epoch 48, Batch 120: Loss: 0.1063
# 	Epoch 48, Batch 130: Loss: 0.0638
# 	Epoch 48, Batch 140: Loss: 0.0157
# Epoch: 48, val_loss: 0.05, train_loss: 0.05 val_acc: 98.30, train_acc: 98.30
# 	Epoch 49, Batch 10: Loss: 0.0735
# 	Epoch 49, Batch 20: Loss: 0.1277
# 	Epoch 49, Batch 30: Loss: 0.1652
# 	Epoch 49, Batch 40: Loss: 0.1941
# 	Epoch 49, Batch 50: Loss: 0.2012
# 	Epoch 49, Batch 60: Loss: 0.2057
# 	Epoch 49, Batch 70: Loss: 0.2012
# 	Epoch 49, Batch 80: Loss: 0.2103
# 	Epoch 49, Batch 90: Loss: 0.1953
# 	Epoch 49, Batch 100: Loss: 0.1707
# 	Epoch 49, Batch 110: Loss: 0.1389
# 	Epoch 49, Batch 120: Loss: 0.1006
# 	Epoch 49, Batch 130: Loss: 0.0592
# 	Epoch 49, Batch 140: Loss: 0.0153
# Epoch: 49, val_loss: 0.05, train_loss: 0.05 val_acc: 98.30, train_acc: 98.22
# 	Epoch 50, Batch 10: Loss: 0.0194
# 	Epoch 50, Batch 20: Loss: 0.0551
# 	Epoch 50, Batch 30: Loss: 0.0686
# 	Epoch 50, Batch 40: Loss: 0.0894
# 	Epoch 50, Batch 50: Loss: 0.1084
# 	Epoch 50, Batch 60: Loss: 0.1179
# 	Epoch 50, Batch 70: Loss: 0.1533
# 	Epoch 50, Batch 80: Loss: 0.1471
# 	Epoch 50, Batch 90: Loss: 0.1483
# 	Epoch 50, Batch 100: Loss: 0.1403
# 	Epoch 50, Batch 110: Loss: 0.1191
# 	Epoch 50, Batch 120: Loss: 0.0912
# 	Epoch 50, Batch 130: Loss: 0.0554
# 	Epoch 50, Batch 140: Loss: 0.0136
# Epoch: 50, val_loss: 0.05, train_loss: 0.05 val_acc: 98.69, train_acc: 98.48
# 	Epoch 51, Batch 10: Loss: 0.0397
# 	Epoch 51, Batch 20: Loss: 0.0782
# 	Epoch 51, Batch 30: Loss: 0.1104
# 	Epoch 51, Batch 40: Loss: 0.1424
# 	Epoch 51, Batch 50: Loss: 0.1590
# 	Epoch 51, Batch 60: Loss: 0.1706
# 	Epoch 51, Batch 70: Loss: 0.1859
# 	Epoch 51, Batch 80: Loss: 0.1796
# 	Epoch 51, Batch 90: Loss: 0.1567
# 	Epoch 51, Batch 100: Loss: 0.1346
# 	Epoch 51, Batch 110: Loss: 0.1163
# 	Epoch 51, Batch 120: Loss: 0.0859
# 	Epoch 51, Batch 130: Loss: 0.0522
# 	Epoch 51, Batch 140: Loss: 0.0128
# Epoch: 51, val_loss: 0.05, train_loss: 0.04 val_acc: 98.46, train_acc: 98.63
# 	Epoch 52, Batch 10: Loss: 0.0373
# 	Epoch 52, Batch 20: Loss: 0.0861
# 	Epoch 52, Batch 30: Loss: 0.0949
# 	Epoch 52, Batch 40: Loss: 0.1117
# 	Epoch 52, Batch 50: Loss: 0.1299
# 	Epoch 52, Batch 60: Loss: 0.1251
# 	Epoch 52, Batch 70: Loss: 0.1478
# 	Epoch 52, Batch 80: Loss: 0.1489
# 	Epoch 52, Batch 90: Loss: 0.1390
# 	Epoch 52, Batch 100: Loss: 0.1362
# 	Epoch 52, Batch 110: Loss: 0.1182
# 	Epoch 52, Batch 120: Loss: 0.0910
# 	Epoch 52, Batch 130: Loss: 0.0558
# 	Epoch 52, Batch 140: Loss: 0.0143
# Epoch: 52, val_loss: 0.05, train_loss: 0.05 val_acc: 98.38, train_acc: 98.33
# 	Epoch 53, Batch 10: Loss: 0.0551
# 	Epoch 53, Batch 20: Loss: 0.0922
# 	Epoch 53, Batch 30: Loss: 0.1216
# 	Epoch 53, Batch 40: Loss: 0.1351
# 	Epoch 53, Batch 50: Loss: 0.1578
# 	Epoch 53, Batch 60: Loss: 0.1679
# 	Epoch 53, Batch 70: Loss: 0.1643
# 	Epoch 53, Batch 80: Loss: 0.1563
# 	Epoch 53, Batch 90: Loss: 0.1460
# 	Epoch 53, Batch 100: Loss: 0.1308
# 	Epoch 53, Batch 110: Loss: 0.1058
# 	Epoch 53, Batch 120: Loss: 0.0854
# 	Epoch 53, Batch 130: Loss: 0.0508
# 	Epoch 53, Batch 140: Loss: 0.0126
# Epoch: 53, val_loss: 0.04, train_loss: 0.04 val_acc: 98.61, train_acc: 98.57
# 	Epoch 54, Batch 10: Loss: 0.0191
# 	Epoch 54, Batch 20: Loss: 0.0759
# 	Epoch 54, Batch 30: Loss: 0.0912
# 	Epoch 54, Batch 40: Loss: 0.1115
# 	Epoch 54, Batch 50: Loss: 0.1241
# 	Epoch 54, Batch 60: Loss: 0.1294
# 	Epoch 54, Batch 70: Loss: 0.1358
# 	Epoch 54, Batch 80: Loss: 0.1527
# 	Epoch 54, Batch 90: Loss: 0.1445
# 	Epoch 54, Batch 100: Loss: 0.1300
# 	Epoch 54, Batch 110: Loss: 0.1082
# 	Epoch 54, Batch 120: Loss: 0.0799
# 	Epoch 54, Batch 130: Loss: 0.0481
# 	Epoch 54, Batch 140: Loss: 0.0123
# Epoch: 54, val_loss: 0.04, train_loss: 0.04 val_acc: 98.61, train_acc: 98.50
# 	Epoch 55, Batch 10: Loss: 0.0268
# 	Epoch 55, Batch 20: Loss: 0.0565
# 	Epoch 55, Batch 30: Loss: 0.0702
# 	Epoch 55, Batch 40: Loss: 0.0965
# 	Epoch 55, Batch 50: Loss: 0.1209
# 	Epoch 55, Batch 60: Loss: 0.1223
# 	Epoch 55, Batch 70: Loss: 0.1287
# 	Epoch 55, Batch 80: Loss: 0.1422
# 	Epoch 55, Batch 90: Loss: 0.1401
# 	Epoch 55, Batch 100: Loss: 0.1227
# 	Epoch 55, Batch 110: Loss: 0.1006
# 	Epoch 55, Batch 120: Loss: 0.0798
# 	Epoch 55, Batch 130: Loss: 0.0484
# 	Epoch 55, Batch 140: Loss: 0.0119
# Epoch: 55, val_loss: 0.04, train_loss: 0.04 val_acc: 98.54, train_acc: 98.50
# 	Epoch 56, Batch 10: Loss: 0.0163
# 	Epoch 56, Batch 20: Loss: 0.0506
# 	Epoch 56, Batch 30: Loss: 0.0992
# 	Epoch 56, Batch 40: Loss: 0.1106
# 	Epoch 56, Batch 50: Loss: 0.1294
# 	Epoch 56, Batch 60: Loss: 0.1339
# 	Epoch 56, Batch 70: Loss: 0.1401
# 	Epoch 56, Batch 80: Loss: 0.1454
# 	Epoch 56, Batch 90: Loss: 0.1480
# 	Epoch 56, Batch 100: Loss: 0.1363
# 	Epoch 56, Batch 110: Loss: 0.1135
# 	Epoch 56, Batch 120: Loss: 0.0860
# 	Epoch 56, Batch 130: Loss: 0.0513
# 	Epoch 56, Batch 140: Loss: 0.0126
# Epoch: 56, val_loss: 0.05, train_loss: 0.04 val_acc: 98.15, train_acc: 98.55
# 	Epoch 57, Batch 10: Loss: 0.0336
# 	Epoch 57, Batch 20: Loss: 0.1055
# 	Epoch 57, Batch 30: Loss: 0.1180
# 	Epoch 57, Batch 40: Loss: 0.1229
# 	Epoch 57, Batch 50: Loss: 0.1420
# 	Epoch 57, Batch 60: Loss: 0.1527
# 	Epoch 57, Batch 70: Loss: 0.1452
# 	Epoch 57, Batch 80: Loss: 0.1421
# 	Epoch 57, Batch 90: Loss: 0.1342
# 	Epoch 57, Batch 100: Loss: 0.1219
# 	Epoch 57, Batch 110: Loss: 0.1011
# 	Epoch 57, Batch 120: Loss: 0.0775
# 	Epoch 57, Batch 130: Loss: 0.0492
# 	Epoch 57, Batch 140: Loss: 0.0121
# Epoch: 57, val_loss: 0.05, train_loss: 0.04 val_acc: 98.61, train_acc: 98.59
# 	Epoch 58, Batch 10: Loss: 0.0353
# 	Epoch 58, Batch 20: Loss: 0.0860
# 	Epoch 58, Batch 30: Loss: 0.0887
# 	Epoch 58, Batch 40: Loss: 0.1132
# 	Epoch 58, Batch 50: Loss: 0.1623
# 	Epoch 58, Batch 60: Loss: 0.1641
# 	Epoch 58, Batch 70: Loss: 0.1644
# 	Epoch 58, Batch 80: Loss: 0.1686
# 	Epoch 58, Batch 90: Loss: 0.1559
# 	Epoch 58, Batch 100: Loss: 0.1394
# 	Epoch 58, Batch 110: Loss: 0.1177
# 	Epoch 58, Batch 120: Loss: 0.0862
# 	Epoch 58, Batch 130: Loss: 0.0529
# 	Epoch 58, Batch 140: Loss: 0.0131
# Epoch: 58, val_loss: 0.05, train_loss: 0.04 val_acc: 98.30, train_acc: 98.59
# 	Epoch 59, Batch 10: Loss: 0.0156
# 	Epoch 59, Batch 20: Loss: 0.0491
# 	Epoch 59, Batch 30: Loss: 0.0803
# 	Epoch 59, Batch 40: Loss: 0.1201
# 	Epoch 59, Batch 50: Loss: 0.1437
# 	Epoch 59, Batch 60: Loss: 0.1527
# 	Epoch 59, Batch 70: Loss: 0.1565
# 	Epoch 59, Batch 80: Loss: 0.1475
# 	Epoch 59, Batch 90: Loss: 0.1441
# 	Epoch 59, Batch 100: Loss: 0.1311
# 	Epoch 59, Batch 110: Loss: 0.1089
# 	Epoch 59, Batch 120: Loss: 0.0816
# 	Epoch 59, Batch 130: Loss: 0.0498
# 	Epoch 59, Batch 140: Loss: 0.0120
# Epoch: 59, val_loss: 0.04, train_loss: 0.04 val_acc: 98.46, train_acc: 98.81
# 	Epoch 60, Batch 10: Loss: 0.0279
# 	Epoch 60, Batch 20: Loss: 0.0596
# 	Epoch 60, Batch 30: Loss: 0.0768
# 	Epoch 60, Batch 40: Loss: 0.0979
# 	Epoch 60, Batch 50: Loss: 0.1191
# 	Epoch 60, Batch 60: Loss: 0.1155
# 	Epoch 60, Batch 70: Loss: 0.1239
# 	Epoch 60, Batch 80: Loss: 0.1153
# 	Epoch 60, Batch 90: Loss: 0.1217
# 	Epoch 60, Batch 100: Loss: 0.1058
# 	Epoch 60, Batch 110: Loss: 0.0894
# 	Epoch 60, Batch 120: Loss: 0.0672
# 	Epoch 60, Batch 130: Loss: 0.0446
# 	Epoch 60, Batch 140: Loss: 0.0115
# Epoch 00060: reducing learning rate of group 0 to 4.0000e-05.
# Epoch: 60, val_loss: 0.04, train_loss: 0.04 val_acc: 98.38, train_acc: 98.99
# 	Epoch 61, Batch 10: Loss: 0.0594
# 	Epoch 61, Batch 20: Loss: 0.0839
# 	Epoch 61, Batch 30: Loss: 0.0948
# 	Epoch 61, Batch 40: Loss: 0.1072
# 	Epoch 61, Batch 50: Loss: 0.1059
# 	Epoch 61, Batch 60: Loss: 0.1319
# 	Epoch 61, Batch 70: Loss: 0.1298
# 	Epoch 61, Batch 80: Loss: 0.1291
# 	Epoch 61, Batch 90: Loss: 0.1184
# 	Epoch 61, Batch 100: Loss: 0.1155
# 	Epoch 61, Batch 110: Loss: 0.0956
# 	Epoch 61, Batch 120: Loss: 0.0778
# 	Epoch 61, Batch 130: Loss: 0.0458
# 	Epoch 61, Batch 140: Loss: 0.0115
# Epoch: 61, val_loss: 0.04, train_loss: 0.04 val_acc: 98.54, train_acc: 98.96
# 	Epoch 62, Batch 10: Loss: 0.0379
# 	Epoch 62, Batch 20: Loss: 0.0920
# 	Epoch 62, Batch 30: Loss: 0.1003
# 	Epoch 62, Batch 40: Loss: 0.1039
# 	Epoch 62, Batch 50: Loss: 0.1168
# 	Epoch 62, Batch 60: Loss: 0.1352
# 	Epoch 62, Batch 70: Loss: 0.1304
# 	Epoch 62, Batch 80: Loss: 0.1258
# 	Epoch 62, Batch 90: Loss: 0.1110
# 	Epoch 62, Batch 100: Loss: 0.1007
# 	Epoch 62, Batch 110: Loss: 0.0862
# 	Epoch 62, Batch 120: Loss: 0.0662
# 	Epoch 62, Batch 130: Loss: 0.0404
# 	Epoch 62, Batch 140: Loss: 0.0103
# Epoch: 62, val_loss: 0.04, train_loss: 0.03 val_acc: 98.84, train_acc: 99.03
# 	Epoch 63, Batch 10: Loss: 0.0183
# 	Epoch 63, Batch 20: Loss: 0.0390
# 	Epoch 63, Batch 30: Loss: 0.0563
# 	Epoch 63, Batch 40: Loss: 0.0648
# 	Epoch 63, Batch 50: Loss: 0.0853
# 	Epoch 63, Batch 60: Loss: 0.0926
# 	Epoch 63, Batch 70: Loss: 0.0983
# 	Epoch 63, Batch 80: Loss: 0.0915
# 	Epoch 63, Batch 90: Loss: 0.0957
# 	Epoch 63, Batch 100: Loss: 0.0985
# 	Epoch 63, Batch 110: Loss: 0.0836
# 	Epoch 63, Batch 120: Loss: 0.0598
# 	Epoch 63, Batch 130: Loss: 0.0384
# 	Epoch 63, Batch 140: Loss: 0.0093
# Epoch: 63, val_loss: 0.04, train_loss: 0.03 val_acc: 98.92, train_acc: 98.99
# 	Epoch 64, Batch 10: Loss: 0.0274
# 	Epoch 64, Batch 20: Loss: 0.0627
# 	Epoch 64, Batch 30: Loss: 0.0858
# 	Epoch 64, Batch 40: Loss: 0.1030
# 	Epoch 64, Batch 50: Loss: 0.1101
# 	Epoch 64, Batch 60: Loss: 0.1087
# 	Epoch 64, Batch 70: Loss: 0.1056
# 	Epoch 64, Batch 80: Loss: 0.1128
# 	Epoch 64, Batch 90: Loss: 0.1119
# 	Epoch 64, Batch 100: Loss: 0.1022
# 	Epoch 64, Batch 110: Loss: 0.0808
# 	Epoch 64, Batch 120: Loss: 0.0652
# 	Epoch 64, Batch 130: Loss: 0.0398
# 	Epoch 64, Batch 140: Loss: 0.0097
# Epoch: 64, val_loss: 0.04, train_loss: 0.03 val_acc: 98.69, train_acc: 98.96
# 	Epoch 65, Batch 10: Loss: 0.0547
# 	Epoch 65, Batch 20: Loss: 0.0720
# 	Epoch 65, Batch 30: Loss: 0.0852
# 	Epoch 65, Batch 40: Loss: 0.0993
# 	Epoch 65, Batch 50: Loss: 0.1051
# 	Epoch 65, Batch 60: Loss: 0.1018
# 	Epoch 65, Batch 70: Loss: 0.1032
# 	Epoch 65, Batch 80: Loss: 0.1064
# 	Epoch 65, Batch 90: Loss: 0.0996
# 	Epoch 65, Batch 100: Loss: 0.0848
# 	Epoch 65, Batch 110: Loss: 0.0753
# 	Epoch 65, Batch 120: Loss: 0.0580
# 	Epoch 65, Batch 130: Loss: 0.0371
# 	Epoch 65, Batch 140: Loss: 0.0095
# Epoch: 65, val_loss: 0.04, train_loss: 0.03 val_acc: 98.69, train_acc: 98.88
# 	Epoch 66, Batch 10: Loss: 0.0322
# 	Epoch 66, Batch 20: Loss: 0.0515
# 	Epoch 66, Batch 30: Loss: 0.0650
# 	Epoch 66, Batch 40: Loss: 0.0953
# 	Epoch 66, Batch 50: Loss: 0.1255
# 	Epoch 66, Batch 60: Loss: 0.1246
# 	Epoch 66, Batch 70: Loss: 0.1206
# 	Epoch 66, Batch 80: Loss: 0.1091
# 	Epoch 66, Batch 90: Loss: 0.1035
# 	Epoch 66, Batch 100: Loss: 0.0934
# 	Epoch 66, Batch 110: Loss: 0.0761
# 	Epoch 66, Batch 120: Loss: 0.0613
# 	Epoch 66, Batch 130: Loss: 0.0422
# 	Epoch 66, Batch 140: Loss: 0.0102
# Epoch: 66, val_loss: 0.04, train_loss: 0.03 val_acc: 98.92, train_acc: 98.88
# 	Epoch 67, Batch 10: Loss: 0.0478
# 	Epoch 67, Batch 20: Loss: 0.0664
# 	Epoch 67, Batch 30: Loss: 0.0818
# 	Epoch 67, Batch 40: Loss: 0.0902
# 	Epoch 67, Batch 50: Loss: 0.1071
# 	Epoch 67, Batch 60: Loss: 0.1074
# 	Epoch 67, Batch 70: Loss: 0.1102
# 	Epoch 67, Batch 80: Loss: 0.1097
# 	Epoch 67, Batch 90: Loss: 0.1035
# 	Epoch 67, Batch 100: Loss: 0.0974
# 	Epoch 67, Batch 110: Loss: 0.0803
# 	Epoch 67, Batch 120: Loss: 0.0639
# 	Epoch 67, Batch 130: Loss: 0.0384
# 	Epoch 67, Batch 140: Loss: 0.0095
# Epoch: 67, val_loss: 0.04, train_loss: 0.03 val_acc: 98.77, train_acc: 99.03
# 	Epoch 68, Batch 10: Loss: 0.0338
# 	Epoch 68, Batch 20: Loss: 0.0616
# 	Epoch 68, Batch 30: Loss: 0.0907
# 	Epoch 68, Batch 40: Loss: 0.0880
# 	Epoch 68, Batch 50: Loss: 0.0960
# 	Epoch 68, Batch 60: Loss: 0.0986
# 	Epoch 68, Batch 70: Loss: 0.1006
# 	Epoch 68, Batch 80: Loss: 0.0955
# 	Epoch 68, Batch 90: Loss: 0.0869
# 	Epoch 68, Batch 100: Loss: 0.0899
# 	Epoch 68, Batch 110: Loss: 0.0751
# 	Epoch 68, Batch 120: Loss: 0.0560
# 	Epoch 68, Batch 130: Loss: 0.0352
# 	Epoch 68, Batch 140: Loss: 0.0089
# Epoch: 68, val_loss: 0.04, train_loss: 0.03 val_acc: 98.69, train_acc: 99.10
# 	Epoch 69, Batch 10: Loss: 0.0178
# 	Epoch 69, Batch 20: Loss: 0.0521
# 	Epoch 69, Batch 30: Loss: 0.0929
# 	Epoch 69, Batch 40: Loss: 0.1023
# 	Epoch 69, Batch 50: Loss: 0.1134
# 	Epoch 69, Batch 60: Loss: 0.1244
# 	Epoch 69, Batch 70: Loss: 0.1301
# 	Epoch 69, Batch 80: Loss: 0.1303
# 	Epoch 69, Batch 90: Loss: 0.1172
# 	Epoch 69, Batch 100: Loss: 0.1069
# 	Epoch 69, Batch 110: Loss: 0.0871
# 	Epoch 69, Batch 120: Loss: 0.0625
# 	Epoch 69, Batch 130: Loss: 0.0396
# 	Epoch 69, Batch 140: Loss: 0.0098
# Epoch: 69, val_loss: 0.04, train_loss: 0.03 val_acc: 98.77, train_acc: 98.94
# 	Epoch 70, Batch 10: Loss: 0.0413
# 	Epoch 70, Batch 20: Loss: 0.0624
# 	Epoch 70, Batch 30: Loss: 0.0736
# 	Epoch 70, Batch 40: Loss: 0.0857
# 	Epoch 70, Batch 50: Loss: 0.1114
# 	Epoch 70, Batch 60: Loss: 0.1103
# 	Epoch 70, Batch 70: Loss: 0.1161
# 	Epoch 70, Batch 80: Loss: 0.1102
# 	Epoch 70, Batch 90: Loss: 0.1060
# 	Epoch 70, Batch 100: Loss: 0.0934
# 	Epoch 70, Batch 110: Loss: 0.0818
# 	Epoch 70, Batch 120: Loss: 0.0660
# 	Epoch 70, Batch 130: Loss: 0.0410
# 	Epoch 70, Batch 140: Loss: 0.0103
# Epoch: 70, val_loss: 0.04, train_loss: 0.03 val_acc: 98.77, train_acc: 98.94
# 	Epoch 71, Batch 10: Loss: 0.0353
# 	Epoch 71, Batch 20: Loss: 0.0739
# 	Epoch 71, Batch 30: Loss: 0.0892
# 	Epoch 71, Batch 40: Loss: 0.0962
# 	Epoch 71, Batch 50: Loss: 0.1012
# 	Epoch 71, Batch 60: Loss: 0.1002
# 	Epoch 71, Batch 70: Loss: 0.1047
# 	Epoch 71, Batch 80: Loss: 0.0992
# 	Epoch 71, Batch 90: Loss: 0.0987
# 	Epoch 71, Batch 100: Loss: 0.0842
# 	Epoch 71, Batch 110: Loss: 0.0709
# 	Epoch 71, Batch 120: Loss: 0.0542
# 	Epoch 71, Batch 130: Loss: 0.0336
# 	Epoch 71, Batch 140: Loss: 0.0086
# Epoch: 71, val_loss: 0.04, train_loss: 0.03 val_acc: 98.69, train_acc: 99.25
# 	Epoch 72, Batch 10: Loss: 0.0406
# 	Epoch 72, Batch 20: Loss: 0.0690
# 	Epoch 72, Batch 30: Loss: 0.0946
# 	Epoch 72, Batch 40: Loss: 0.1093
# 	Epoch 72, Batch 50: Loss: 0.1226
# 	Epoch 72, Batch 60: Loss: 0.1339
# 	Epoch 72, Batch 70: Loss: 0.1432
# 	Epoch 72, Batch 80: Loss: 0.1406
# 	Epoch 72, Batch 90: Loss: 0.1270
# 	Epoch 72, Batch 100: Loss: 0.1096
# 	Epoch 72, Batch 110: Loss: 0.0929
# 	Epoch 72, Batch 120: Loss: 0.0675
# 	Epoch 72, Batch 130: Loss: 0.0395
# 	Epoch 72, Batch 140: Loss: 0.0099
# Epoch: 72, val_loss: 0.04, train_loss: 0.03 val_acc: 98.69, train_acc: 98.92
# > Early stopping <

# %% [markdown]
# # Analisis de resultados <a name="analisis"></a>
#
# Se generan graficas claves para comprender el desarollo del entrenamiento además de las matrices de confusión y los valores de presicion, y F1. Los cuales seran útiles para saber si el entrenamiento ha sido un éxito.

# %%
model.load_state_dict(early_stopper.best_model)
model.eval()

cm = metrics.confusion_matrix(targets, preds)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Gráfico de la precisión de entrenamiento y validación
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_acc_h, label='Train Accuracy')
plt.plot(val_acc_h, label='Validation Accuracy')
plt.title('Train vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Gráfico de la pérdida de entrenamiento y validación
plt.subplot(1, 2, 2)
plt.plot(train_loss_h, label='Train Loss')
plt.plot(val_loss_h, label='Validation Loss')
plt.title('Train vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# cjto train
train_preds, train_reals, train_loss, train_acc = eval(model, train_loader, device=device, criterion=criterion)
print("Train Dataset ----------------------------------------------------------------")
print(f"train_loss: {train_loss} - train_acc: {train_acc}")
print(metrics.classification_report(train_reals, train_preds, zero_division=0))


# cjto val
val_preds, val_reals, val_loss, val_acc = eval(model, val_loader, device=device, criterion=criterion)
print("Val Dataset ----------------------------------------------------------------")
print(f"val_loss: {val_loss} - val_acc: {val_acc}")
print(metrics.classification_report(val_reals, val_preds, zero_division=0))

# cjto tests
test_preds, test_reals, test_loss, test_acc = eval(model, test_loader, device=device, criterion=criterion)
cm = metrics.confusion_matrix(test_reals, test_preds)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Tests Dataset")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print("Tests Dataset ----------------------------------------------------------------")
print(f"test_loss: {test_loss} - test_acc: {test_acc}")
print(metrics.classification_report(test_reals, test_preds, zero_division=0))
# Out:
# Train Dataset ----------------------------------------------------------------
# train_loss: 0.015840423287467993 - train_acc: 0.99669457910974
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1135
#            1       1.00      1.00      1.00      1134
#            2       0.99      0.99      0.99      1134
#            3       1.00      1.00      1.00      1135
#
#     accuracy                           1.00      4538
#    macro avg       1.00      1.00      1.00      4538
# weighted avg       1.00      1.00      1.00      4538
#
# Val Dataset ----------------------------------------------------------------
# val_loss: 0.037582517275018844 - val_acc: 0.9868928296067849
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       324
#            1       0.98      0.98      0.98       324
#            2       0.98      0.98      0.98       325
#            3       0.98      1.00      0.99       324
#
#     accuracy                           0.99      1297
#    macro avg       0.99      0.99      0.99      1297
# weighted avg       0.99      0.99      0.99      1297
# Tests Dataset ----------------------------------------------------------------
# test_loss: 0.07336527015043733 - test_acc: 0.9845916795069337
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       162
#            1       0.99      0.98      0.99       163
#            2       0.95      0.99      0.97       162
#            3       0.99      0.98      0.99       162
#
#     accuracy                           0.98       649
#    macro avg       0.99      0.98      0.98       649
# weighted avg       0.99      0.98      0.98       649

# %% [markdown]
# # Guardado del modelo <a name="guardado"></a>

# %%
def save_model(model, path, complete=False):
    try:
        torch.save(model if complete else model.state_dict(), path)
    except Exception as e:
        print("Error al guardar el model:", e)

# %%
#save_model(model, "./kaggle/working/model_98.pth", complete=True)
