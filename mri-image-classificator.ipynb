# %% [markdown]
# # CLASIFICADOR DE IMAGENES MRI

# %% [markdown]
# # Indice
# * [Constantes e hiperparametros](#constantes)
# * [Creación  dataset](#dataset)
#     * [Balanceamiento del dataset](#balanceamiento)
#     * [Separación y comprobación de conjuntos](#separacion)
# * [Dataset de pytorch](#pytorch)
#     * [Calculo media y desviación](#media)
#     * [Data Augmentation y Datasets de Conjuntos](#data)
#     * [DataLoaders](#dataloaders)
# * [Entrenamiento](#entrenamiento)
#     * [Early Stopping](#earlyStopping)
#     * [Modelo CNN](#modelo)
#     * [Funcion de evaluacion](#evaluacion)
#     * [Funcion de entrenamiento](#entrenamiento)
#     * [ Configuración y Entrenamiento del Modelo CNN](#configuracion)
# * [Guardado del modelo ](#guardado)

# %%
# %matplotlib inline

# imports
import pandas as pd
from torchvision.io import read_image, ImageReadMode
import os
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns
from torch import optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print(torch.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo configurado para usar: {device}")

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.0.0
# Dispositivo configurado para usar: cuda
# True
# Tesla P100-PCIE-16GB

# %% [markdown]
# # Constantes e hiperparametros <a name="constantes"></a>

# %%
# const

DIR_PATH = "/kaggle/input/brain-tumor-mri-dataset"

LABELS = ["notumor", "glioma", "meningioma", "pituitary"]

TRAIN_PERCENT = .7
VAL_PERCENT = .2
TEST_PERCENT = .1

IMAGE_SIZE = 220

RANDOM_STATE = None

BATCH_SIZE = 20
LEARNING_RATE = 0.001
MOMENTUM = 0.9
NUM_EPOCH = 100
EARLY_PATIENCE = 10
SCHEDULER_PATIENCE = 6

# %% [markdown]
# # Creación dataset <a name="dataset"></a>
#
#
# Se crea un conjunto de datos a partir de imágenes almacenadas en el directorio. Cada imagen se registra junto con su categoria(label).

# %%
dataset = pd.DataFrame(columns = ["path", "label"])

for dir in os.listdir(DIR_PATH):
    for label in os.listdir(os.path.join(DIR_PATH, dir)):
        for img in os.listdir(os.path.join(DIR_PATH, dir, label)):
            dataset.loc[len(dataset)] = {"path": os.path.join(DIR_PATH, dir, label, img),
                                   "label": LABELS.index(label) }

print("num elementos:", dataset.count(axis=1).size)
print(dataset.head())
# Out:
# num elementos: 7023
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 2  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 3  /kaggle/input/brain-tumor-mri-dataset/Training...      3
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      3

# %% [markdown]
# ## Balanceamiento del dataset  <a name="balanceamiento"></a>
#
#
# Para evitar el desbalanceo se calcula el numero de imagenes de la categoria con menos imagenes

# %%
min_cat_size = dataset.label.value_counts().min()

print("> Cantidad de imagenes de la categoria que menos tiene:", min_cat_size)
# Out:
# > Cantidad de imagenes de la categoria que menos tiene: 1621

# %% [markdown]
# Se equilibra el conjunto de datos para que todos tengan 1621 imagenes, dependiendo del valor de RANDOM_STATE, la elección será aleatoria o no.

# %%
# Hacemos que todos tengan los mismos elementos
dataset = pd.DataFrame(dataset.groupby("label").apply(lambda label: label.sample(min_cat_size, random_state=RANDOM_STATE)).reset_index(drop=True))

print("> Cantidad de elementos: ", dataset.count(axis=1).size)
print(dataset.label.value_counts())
print(dataset.head())
# Out:
# > Cantidad de elementos:  6484
# label
# 0    1621
# 1    1621
# 2    1621
# 3    1621
# Name: count, dtype: int64
#                                                 path  label
# 0  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 1  /kaggle/input/brain-tumor-mri-dataset/Training...      0
# 2  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 3  /kaggle/input/brain-tumor-mri-dataset/Testing/...      0
# 4  /kaggle/input/brain-tumor-mri-dataset/Training...      0

# %% [markdown]
# ## Separación y comprobación de conjuntos <a name="separacion" ></a>
#
# Se separan las imagenes del dataset balanceado en 3 conjuntos: entrenamiento,validación y test

# %%
train_dataset, tmp = train_test_split(dataset, train_size=TRAIN_PERCENT, stratify=dataset["label"], shuffle=True, random_state=RANDOM_STATE)
val_dataset, test_dataset = train_test_split(tmp, test_size=TEST_PERCENT/(TEST_PERCENT+VAL_PERCENT), stratify=tmp["label"], shuffle=True, random_state=RANDOM_STATE)

print("> train", train_dataset.count(axis=1).size, train_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(train_dataset.label.value_counts())
print()

print("> val", val_dataset.count(axis=1).size, val_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(val_dataset.label.value_counts())
print()

print("> test", test_dataset.count(axis=1).size, test_dataset.count(axis=1).size/dataset.count(axis=1).size)
print(test_dataset.label.value_counts())
print()
# Out:
# > train 4538 0.6998766193707588
# label
# 0    1135
# 2    1135
# 3    1134
# 1    1134
# Name: count, dtype: int64
#
# > val 1297 0.2000308451573103
# label
# 1    325
# 3    324
# 0    324
# 2    324
# Name: count, dtype: int64
#
# > test 649 0.10009253547193091
# label
# 3    163
# 0    162
# 2    162
# 1    162
# Name: count, dtype: int64

# %% [markdown]
# Se comprueba que son disjuntos para garantizar la integridad y la evaluación imparcial del modelo

# %%
print((train_dataset[ "path" ].isin(test_dataset["path"] ) == True).value_counts())
print((train_dataset[ "path" ].isin(val_dataset["path"] ) == True).value_counts())
print((val_dataset[ "path" ].isin(test_dataset["path"]) == True).value_counts())
# Out:
# path
# False    4538
# Name: count, dtype: int64
# path
# False    4538
# Name: count, dtype: int64
# path
# False    1297
# Name: count, dtype: int64

# %% [markdown]
# # Dataset de pytorch <a name="pytorch"></a>
#
# La clase CustomDataset esta diseñada para cargar y preparar datos para su uso en el aprendizaje automático utilizando la biblioteca PyTorch.

# %%
class CustomDataset(Dataset):
    
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
    
    def __len__(self):
        return self.dataframe.count(axis=1).size
    
    def __getitem__(self, idx) -> (str, int):
        
        row = self.dataframe.iloc[idx]
        img, label = row.path, row.label

        img = read_image(img, mode=ImageReadMode.GRAY)
        if self.transform: img = self.transform(img)

        return img, label

# %% [markdown]
# ## Calculo media y desviación <a name="media"></a>
#
# Se calcula la media y desviación  de un dataset sin Data Augmentation para poder normalizar las imagenes antes de usarlas en el modelo.

# %%
unnormalized_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.ToTensor()
])

unnormalized_dataset = CustomDataset(dataset, transform=unnormalized_transforms)
loader = DataLoader(unnormalized_dataset, batch_size=1, shuffle=False)

sum_intensity = 0.0
sum_squared_intensity = 0.0
n_samples = 0

for imgs, _ in loader:
    
    sum_intensity += imgs.sum()
    sum_squared_intensity += (imgs ** 2).sum()
    n_samples += imgs.numel()

mean = sum_intensity / n_samples
std = torch.sqrt(sum_squared_intensity / n_samples - mean ** 2)

print(mean)
print(std)
# Out:
# tensor(0.1839)
# tensor(0.1991)

# %% [markdown]
# ## Data Augmentation y Datasets de Conjuntos <a name="data" ></a>

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
    transforms.RandomRotation(180),            
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

test_valid_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE),antialias=True),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])


train_dataset = CustomDataset(train_dataset, transform=train_transform)
val_dataset = CustomDataset(val_dataset, transform=test_valid_transforms)
test_dataset = CustomDataset(test_dataset, transform=test_valid_transforms)

# Acceder e imprimir las primeras 5 muestras del dataset
for i in range(5):
    image, label = train_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = val_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")
    image, label = test_dataset[i]
    print(f"Muestra {i}: Imagen - {type(image)}, Dimensiones - {image.size()}, Etiqueta - {label}")

# Imprimir los valores de la media y la desviación estándar
print(f"Media: {mean}, Desviación Estándar: {std}")
# Out:
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 1
# Muestra 0: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 1: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 2: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 3
# Muestra 3: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 1
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 2
# Muestra 4: Imagen - <class 'torch.Tensor'>, Dimensiones - torch.Size([1, 220, 220]), Etiqueta - 0
# Media: 0.18389853835105896, Desviación Estándar: 0.19905473291873932

# %% [markdown]
# ## Dataloaders <a name="dataloaders"></a>
#
# Se crean los dataLoaders ya que se encargan de cargar y organizar los datos de un conjunto de datos para que puedan ser procesados por un modelo de manera eficiente durante el entrenamiento y la evaluación.

# %%
def show_img(img, label):
    print('Label: ', dataset.label[label], "(" + str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

# Verificar DataLoader
for images, labels in train_loader:
    print(f"Batch de imágenes: {images.shape}, Batch de etiquetas: {labels.shape}")
    break

# Carga una imagen de prueba
img, label = test_dataset[45]
show_img(img, label)
# Out:
# Batch de imágenes: torch.Size([20, 1, 220, 220]), Batch de etiquetas: torch.Size([20])
# Label:  0 (2)

# %% [markdown]
# # Entrenamiento <a name="entrenamiento"></a>

# %% [markdown]
# ## Early Stopping <a name="earlyStopping"></a>
#
# Se establece el mecanismo de parada temprana (Early Stopping) para el entrenamiento del modelo. Esta técnica ayuda a evitar el sobreajuste y ahorrar tiempo de entrenamiento.
#
# Si la pérdida de validación no mejora durante un número específico de épocas (determinado por la paciencia), el entrenamiento se detiene.

# %%
class EarlyStopper:
    
    def __init__(self, patience=5, min_delta=0, callback=lambda **_: None):
        self.patience = patience
        self.min_delta = min_delta
        self.callback = callback

        self.counter = 1

        self.best_model = None
        self.best_loss = float("inf")

    def __call__(self, val_loss, model):

        if val_loss < (self.best_loss - self.min_delta):
            self.best_loss = val_loss
            self.counter = 0

            self.best_model = model.state_dict()
            return False


        self.counter += 1
        if self.counter >= self.patience:
            self.callback(counter=self.counter, best_loss=self.best_loss, best_model=self.best_model)
            return True

    def reset(self):
        self.early_stop = False
        self.counter = 1

# %% [markdown]
# ## Modelo CNN <a name="modelo"></a>
#
# Este modelo tiene:
#
# **6 Capas Convolucionales (Conv2d)**:
#
# Su objetivo es extraer características de las imágene mediante la Aplicación de un conjunto de filtros (kernels) a la imagen para crear mapas de características. Cada filtro detecta características específicas (bordes, texturas, etc.).
#
# La primera capa toma una imagen con un solo canal, ya que se trabaja con imagenes en escala de grises.
#
# **6 Normalización por Lotes (BatchNorm2d)**
#
# Su objetivo es estabilizar y acelerar el aprendizaje mediante la Normalización de la salida de la capa anterior, reduciendo el cambio de distribución interna (Internal Covariate Shift).
#
# **Función de Activación ReLU**
#
# Su objetivo es introducir no linealidades en el model Convirtiendo todos los valores negativos a cero y mantiene los positivos tal cual están, lo que ayuda a activar solo ciertas neuronas, aumentando la eficiencia y efectividad del aprendizaje.
#
# **Pooling (Max Pooling)**
#
# Su objetivo es reducir la dimensionalidad espacial, conservando las características más importantes. Esto se consigue seleccionando el valor máximo de una ventana de tamaño especificado y lo usa para representar la región.
#
# **3 Capas Completamente Conectadas (Linear)**
#
# Su objetivo es realizar la clasificación en base a las características extraídas.
# Cada neurona en estas capas está conectada a todas las activaciones de la capa anterior, y se utilizan para derivar la salida final.
#
# **Dropout**
#
# Su objetivo es prevenir el sobreajuste. Durante el entrenamiento, se "desactivan" aleatoriamente algunas neuronas, lo que hace que el modelo sea menos sensible a las características específicas de los datos de entrenamiento.

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        padding_size = 3
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 64, kernel_size=7, padding=padding_size)
        self.bn1 = nn.BatchNorm2d(64)

        self.conv2 = nn.Conv2d(64, 128, kernel_size=7, padding=padding_size)
        self.bn2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128, 128, kernel_size=7, padding=padding_size)
        self.bn3 = nn.BatchNorm2d(128)

        self.conv4 = nn.Conv2d(128, 256, kernel_size=7, padding=padding_size)
        self.bn4 = nn.BatchNorm2d(256)

        self.conv5 = nn.Conv2d(256, 256, kernel_size=7, padding=padding_size)
        self.bn5 = nn.BatchNorm2d(256)

        self.conv6 = nn.Conv2d(256, 512, kernel_size=7, padding=padding_size)
        self.bn6 = nn.BatchNorm2d(512)

        # Fully connected layers
        self.fc1 = nn.Linear(512*3*3, 1024) 
        self.dropout1 = nn.Dropout(0.25)
        self.fc2 = nn.Linear(1024, 512)
        self.dropout2 = nn.Dropout(0.25)
        self.fc3 = nn.Linear(512, 4)

    def forward(self, x):
        # Convolutional layers with ReLU activations and batch normalization
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn3(self.conv3(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn4(self.conv4(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn5(self.conv5(x)))
        x = F.max_pool2d(x, kernel_size=2)

        x = F.relu(self.bn6(self.conv6(x)))
        x = F.max_pool2d(x, kernel_size=2)

        # Flatten the output for the fully connected layers
        x = x.view(x.size(0), -1)

        # Fully connected layers with ReLU activations and dropout
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)  

        return x

# %% [markdown]
# ## Función de evaluación <a name="evaluacion"></a>

# %%
def eval(model, loader, *, device = None, criterion = None):
    """returns pred, real, accuracy, val_loss"""
    if not (device and criterion): raise Exception("Params needed")

    model.eval()

    corrects = 0

    pred = []
    real = []
    loss = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in loader:
            
            imgs, labels = imgs.to(device), labels.to(device)

            outs = model(imgs)
            loss += criterion(outs.data, labels).item()

            _, predicted = torch.max(outs.data, 1)
            
            total += labels.size(0)
            pred.extend(predicted.tolist())
            real.extend(labels.tolist())

            corrects += (predicted == labels).sum().item()
    
    return  pred, real, loss/len(loader), corrects/total

# %% [markdown]
# ## Función de entrenamiento <a name="entrenamiento"></a>

# %%
def train_loop(model, loader, *, optimizer, criterion, num_epoch=100, device=torch.device("cuda" if torch.cuda.is_available() else "cpu"), train_loss_h=[], train_acc_h=[], val_loss_h=[] ,val_acc_h=[], callback=lambda **_: None, early_callback=lambda **_: None, scheduler, val_loader):
    if not (optimizer and criterion and early_stopper and scheduler): raise Exception("Params needed")
    
    val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
    callback(epoch=0, val_acc=val_acc, val_loss=val_loss, train_loss=float("inf"), train_acc=0)

    for epoch in range(num_epoch):

        running_loss = 0.0
        corrects = 0
        total = 0

        model.train()

        for i, (imgs, labels) in enumerate(loader, 1):

            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()

            outs = model(imgs)
            loss = criterion(outs, labels)
            
            running_loss += loss.item()
            
            loss.backward()
            optimizer.step()

            # extra for analytics
            _, predicted = torch.max(outs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()
            # ==================

            if not i % 10:
                print(f"\tEpoch {epoch+1}, Batch {i}: Loss: {running_loss*(len(loader)-i+1)/(10*len(loader)):.4f}")
            
        val_preds, val_labels, val_loss, val_acc  = eval(model, val_loader, device=device, criterion=criterion)
        scheduler.step(val_loss)
        
        # extra for analytics
        train_loss = running_loss/len(loader)
        train_loss_h.append(train_loss)
        train_acc = 100*corrects/total
        train_acc_h.append(train_acc)

        val_loss_h.append(val_loss)
        val_acc_h.append(val_acc*100)
        # ===================

        callback(epoch=epoch+1, val_acc=val_acc, val_loss=val_loss, train_loss=train_loss, train_acc=train_acc)

        if(early_stopper(val_loss, model)): break

    return train_acc_h, val_acc_h, train_loss_h, val_loss_h, val_preds, val_labels

# %% [markdown]
# ## Configuración y Entrenamiento del Modelo CNN <a name="configuracion"></a>
#
# **Optimizador**: descenso de gradiente estocástico (SGD. El gradiente se calcula de manera aproximada a partir de un subconjunto de datos en lugar de utilizar todo el conjunto de datos. Esto hace que el proceso de entrenamiento sea más eficiente y escalable.
#
# **Función de pérdida:** CrossEntropyLoss. Ampliamente utilizada para problemas de clasificación multiclase en aprendizaje profundo. Ayuda a medir la discrepancia entre las predicciones del modelo y las etiquetas reales.
#
# **Scheduler:** ReduceLROnPlateau. Reduce la tasa de aprendizaje cuando el modelo deja de mejorar en la perdida de validación. Esto puede ayudar a que el modelo converja de manera más efectiva hacia una solución óptima y evite oscilaciones en el entrenamiento

# %%
def early_callback(**kwargs): print("> Early stopping <")

early_stopper = EarlyStopper(patience=EARLY_PATIENCE, min_delta=.001, callback=early_callback)

# %%
model = CNN()
if torch.cuda.device_count() > 1: model = nn.DataParallel(model)
model.to(device)

optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
criterion = nn.CrossEntropyLoss().to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, patience=SCHEDULER_PATIENCE, verbose=True)

def callback(**kwargs):
    print(f"Epoch: {kwargs['epoch']}, val_loss: {(kwargs['val_loss']):.2f}, train_loss: {(kwargs['train_loss']):.2f} val_acc: {(kwargs['val_acc']*100):.2f}, train_acc: {(kwargs['train_acc']):.2f}")

train_acc_h, val_acc_h, train_loss_h, val_loss_h, preds, targets = train_loop(model, train_loader,
           val_loader=val_loader,                                                             
           optimizer=optimizer,
           criterion=criterion,
           num_epoch=NUM_EPOCH,
           device=device,
           callback=callback,
           scheduler=scheduler
           )
# Out:
# Epoch: 0, val_loss: 1.39, train_loss: inf val_acc: 24.98, train_acc: 0.00
# 	Epoch 1, Batch 10: Loss: 1.2753
# 	Epoch 1, Batch 20: Loss: 2.2887
# 	Epoch 1, Batch 30: Loss: 3.1164
# 	Epoch 1, Batch 40: Loss: 3.8441
# 	Epoch 1, Batch 50: Loss: 4.4141
# 	Epoch 1, Batch 60: Loss: 4.8586
# 	Epoch 1, Batch 70: Loss: 5.2155
# 	Epoch 1, Batch 80: Loss: 5.4515
# 	Epoch 1, Batch 90: Loss: 5.6467
# 	Epoch 1, Batch 100: Loss: 5.6835
# 	Epoch 1, Batch 110: Loss: 5.7257
# 	Epoch 1, Batch 120: Loss: 5.6452
# 	Epoch 1, Batch 130: Loss: 5.4449
# 	Epoch 1, Batch 140: Loss: 5.1942
# 	Epoch 1, Batch 150: Loss: 4.8537
# 	Epoch 1, Batch 160: Loss: 4.4719
# 	Epoch 1, Batch 170: Loss: 4.0162
# 	Epoch 1, Batch 180: Loss: 3.4927
# 	Epoch 1, Batch 190: Loss: 2.8805
# 	Epoch 1, Batch 200: Loss: 2.2133
# 	Epoch 1, Batch 210: Loss: 1.4792
# 	Epoch 1, Batch 220: Loss: 0.6818
# Epoch: 1, val_loss: 0.60, train_loss: 0.88 val_acc: 78.26, train_acc: 64.63
# 	Epoch 2, Batch 10: Loss: 0.6188
# 	Epoch 2, Batch 20: Loss: 1.2467
# 	Epoch 2, Batch 30: Loss: 1.8589
# 	Epoch 2, Batch 40: Loss: 2.3407
# 	Epoch 2, Batch 50: Loss: 2.7542
# 	Epoch 2, Batch 60: Loss: 3.1297
# 	Epoch 2, Batch 70: Loss: 3.3843
# 	Epoch 2, Batch 80: Loss: 3.6010
# 	Epoch 2, Batch 90: Loss: 3.6920
# 	Epoch 2, Batch 100: Loss: 3.7692
# 	Epoch 2, Batch 110: Loss: 3.8130
# 	Epoch 2, Batch 120: Loss: 3.8118
# 	Epoch 2, Batch 130: Loss: 3.7495
# 	Epoch 2, Batch 140: Loss: 3.6171
# 	Epoch 2, Batch 150: Loss: 3.4006
# 	Epoch 2, Batch 160: Loss: 3.1719
# 	Epoch 2, Batch 170: Loss: 2.8366
# 	Epoch 2, Batch 180: Loss: 2.4721
# 	Epoch 2, Batch 190: Loss: 2.0696
# 	Epoch 2, Batch 200: Loss: 1.6150
# 	Epoch 2, Batch 210: Loss: 1.0820
# 	Epoch 2, Batch 220: Loss: 0.5007
# Epoch: 2, val_loss: 0.54, train_loss: 0.65 val_acc: 78.87, train_acc: 73.29
# 	Epoch 3, Batch 10: Loss: 0.6519
# 	Epoch 3, Batch 20: Loss: 1.1545
# 	Epoch 3, Batch 30: Loss: 1.5773
# 	Epoch 3, Batch 40: Loss: 1.9785
# 	Epoch 3, Batch 50: Loss: 2.2677
# 	Epoch 3, Batch 60: Loss: 2.4801
# 	Epoch 3, Batch 70: Loss: 2.7472
# 	Epoch 3, Batch 80: Loss: 2.9450
# 	Epoch 3, Batch 90: Loss: 3.0799
# 	Epoch 3, Batch 100: Loss: 3.1999
# 	Epoch 3, Batch 110: Loss: 3.2166
# 	Epoch 3, Batch 120: Loss: 3.2354
# 	Epoch 3, Batch 130: Loss: 3.1883
# 	Epoch 3, Batch 140: Loss: 3.1048
# 	Epoch 3, Batch 150: Loss: 2.9309
# 	Epoch 3, Batch 160: Loss: 2.7454
# 	Epoch 3, Batch 170: Loss: 2.4719
# 	Epoch 3, Batch 180: Loss: 2.1484
# 	Epoch 3, Batch 190: Loss: 1.7787
# 	Epoch 3, Batch 200: Loss: 1.3751
# 	Epoch 3, Batch 210: Loss: 0.9298
# 	Epoch 3, Batch 220: Loss: 0.4339
# Epoch: 3, val_loss: 0.64, train_loss: 0.56 val_acc: 74.94, train_acc: 77.17
# 	Epoch 4, Batch 10: Loss: 0.4922
# 	Epoch 4, Batch 20: Loss: 0.9023
# 	Epoch 4, Batch 30: Loss: 1.3318
# 	Epoch 4, Batch 40: Loss: 1.7014
# 	Epoch 4, Batch 50: Loss: 1.9763
# 	Epoch 4, Batch 60: Loss: 2.3066
# 	Epoch 4, Batch 70: Loss: 2.6099
# 	Epoch 4, Batch 80: Loss: 2.7616
# 	Epoch 4, Batch 90: Loss: 2.8809
# 	Epoch 4, Batch 100: Loss: 2.8979
# 	Epoch 4, Batch 110: Loss: 2.9110
# 	Epoch 4, Batch 120: Loss: 2.8368
# 	Epoch 4, Batch 130: Loss: 2.7769
# 	Epoch 4, Batch 140: Loss: 2.6770
# 	Epoch 4, Batch 150: Loss: 2.5215
# 	Epoch 4, Batch 160: Loss: 2.3450
# 	Epoch 4, Batch 170: Loss: 2.1263
# 	Epoch 4, Batch 180: Loss: 1.8592
# 	Epoch 4, Batch 190: Loss: 1.5520
# 	Epoch 4, Batch 200: Loss: 1.1946
# 	Epoch 4, Batch 210: Loss: 0.8054
# 	Epoch 4, Batch 220: Loss: 0.3735
# Epoch: 4, val_loss: 0.62, train_loss: 0.48 val_acc: 74.79, train_acc: 81.47
# 	Epoch 5, Batch 10: Loss: 0.3541
# 	Epoch 5, Batch 20: Loss: 0.6996
# 	Epoch 5, Batch 30: Loss: 1.0431
# 	Epoch 5, Batch 40: Loss: 1.4388
# 	Epoch 5, Batch 50: Loss: 1.6664
# 	Epoch 5, Batch 60: Loss: 1.8711
# 	Epoch 5, Batch 70: Loss: 2.0692
# 	Epoch 5, Batch 80: Loss: 2.2454
# 	Epoch 5, Batch 90: Loss: 2.3813
# 	Epoch 5, Batch 100: Loss: 2.4611
# 	Epoch 5, Batch 110: Loss: 2.4477
# 	Epoch 5, Batch 120: Loss: 2.4337
# 	Epoch 5, Batch 130: Loss: 2.3631
# 	Epoch 5, Batch 140: Loss: 2.2527
# 	Epoch 5, Batch 150: Loss: 2.1266
# 	Epoch 5, Batch 160: Loss: 1.9735
# 	Epoch 5, Batch 170: Loss: 1.7695
# 	Epoch 5, Batch 180: Loss: 1.5427
# 	Epoch 5, Batch 190: Loss: 1.2953
# 	Epoch 5, Batch 200: Loss: 1.0080
# 	Epoch 5, Batch 210: Loss: 0.6877
# 	Epoch 5, Batch 220: Loss: 0.3205
# Epoch: 5, val_loss: 0.54, train_loss: 0.41 val_acc: 77.41, train_acc: 83.72
# 	Epoch 6, Batch 10: Loss: 0.3951
# 	Epoch 6, Batch 20: Loss: 0.6794
# 	Epoch 6, Batch 30: Loss: 1.0202
# 	Epoch 6, Batch 40: Loss: 1.2772
# 	Epoch 6, Batch 50: Loss: 1.4474
# 	Epoch 6, Batch 60: Loss: 1.6182
# 	Epoch 6, Batch 70: Loss: 1.7477
# 	Epoch 6, Batch 80: Loss: 1.9231
# 	Epoch 6, Batch 90: Loss: 1.9879
# 	Epoch 6, Batch 100: Loss: 1.9988
# 	Epoch 6, Batch 110: Loss: 2.0529
# 	Epoch 6, Batch 120: Loss: 2.0479
# 	Epoch 6, Batch 130: Loss: 2.0290
# 	Epoch 6, Batch 140: Loss: 1.9440
# 	Epoch 6, Batch 150: Loss: 1.8468
# 	Epoch 6, Batch 160: Loss: 1.7306
# 	Epoch 6, Batch 170: Loss: 1.5517
# 	Epoch 6, Batch 180: Loss: 1.3453
# 	Epoch 6, Batch 190: Loss: 1.1211
# 	Epoch 6, Batch 200: Loss: 0.8700
# 	Epoch 6, Batch 210: Loss: 0.5934
# 	Epoch 6, Batch 220: Loss: 0.2785
# Epoch: 6, val_loss: 0.32, train_loss: 0.36 val_acc: 89.44, train_acc: 86.58
# 	Epoch 7, Batch 10: Loss: 0.3450
# 	Epoch 7, Batch 20: Loss: 0.5751
# 	Epoch 7, Batch 30: Loss: 0.8225
# 	Epoch 7, Batch 40: Loss: 1.1236
# 	Epoch 7, Batch 50: Loss: 1.3530
# 	Epoch 7, Batch 60: Loss: 1.4797
# 	Epoch 7, Batch 70: Loss: 1.5465
# 	Epoch 7, Batch 80: Loss: 1.6245
# 	Epoch 7, Batch 90: Loss: 1.7063
# 	Epoch 7, Batch 100: Loss: 1.8203
# 	Epoch 7, Batch 110: Loss: 1.9007
# 	Epoch 7, Batch 120: Loss: 1.8827
# 	Epoch 7, Batch 130: Loss: 1.8334
# 	Epoch 7, Batch 140: Loss: 1.7758
# 	Epoch 7, Batch 150: Loss: 1.7088
# 	Epoch 7, Batch 160: Loss: 1.5734
# 	Epoch 7, Batch 170: Loss: 1.4083
# 	Epoch 7, Batch 180: Loss: 1.2355
# 	Epoch 7, Batch 190: Loss: 1.0420
# 	Epoch 7, Batch 200: Loss: 0.8108
# 	Epoch 7, Batch 210: Loss: 0.5481
# 	Epoch 7, Batch 220: Loss: 0.2547
# Epoch: 7, val_loss: 0.25, train_loss: 0.33 val_acc: 91.29, train_acc: 88.06
# 	Epoch 8, Batch 10: Loss: 0.2690
# 	Epoch 8, Batch 20: Loss: 0.4560
# 	Epoch 8, Batch 30: Loss: 0.6632
# 	Epoch 8, Batch 40: Loss: 0.8741
# 	Epoch 8, Batch 50: Loss: 1.0582
# 	Epoch 8, Batch 60: Loss: 1.1547
# 	Epoch 8, Batch 70: Loss: 1.2586
# 	Epoch 8, Batch 80: Loss: 1.3686
# 	Epoch 8, Batch 90: Loss: 1.4798
# 	Epoch 8, Batch 100: Loss: 1.5278
# 	Epoch 8, Batch 110: Loss: 1.5413
# 	Epoch 8, Batch 120: Loss: 1.5299
# 	Epoch 8, Batch 130: Loss: 1.5096
# 	Epoch 8, Batch 140: Loss: 1.4267
# 	Epoch 8, Batch 150: Loss: 1.3599
# 	Epoch 8, Batch 160: Loss: 1.2645
# 	Epoch 8, Batch 170: Loss: 1.1407
# 	Epoch 8, Batch 180: Loss: 1.0161
# 	Epoch 8, Batch 190: Loss: 0.8550
# 	Epoch 8, Batch 200: Loss: 0.6822
# 	Epoch 8, Batch 210: Loss: 0.4669
# 	Epoch 8, Batch 220: Loss: 0.2197
# Epoch: 8, val_loss: 0.25, train_loss: 0.28 val_acc: 90.29, train_acc: 89.51
# 	Epoch 9, Batch 10: Loss: 0.2648
# 	Epoch 9, Batch 20: Loss: 0.5436
# 	Epoch 9, Batch 30: Loss: 0.7267
# 	Epoch 9, Batch 40: Loss: 0.8686
# 	Epoch 9, Batch 50: Loss: 1.0415
# 	Epoch 9, Batch 60: Loss: 1.1994
# 	Epoch 9, Batch 70: Loss: 1.2341
# 	Epoch 9, Batch 80: Loss: 1.2742
# 	Epoch 9, Batch 90: Loss: 1.3539
# 	Epoch 9, Batch 100: Loss: 1.4120
# 	Epoch 9, Batch 110: Loss: 1.4948
# 	Epoch 9, Batch 120: Loss: 1.5484
# 	Epoch 9, Batch 130: Loss: 1.5318
# 	Epoch 9, Batch 140: Loss: 1.4820
# 	Epoch 9, Batch 150: Loss: 1.4042
# 	Epoch 9, Batch 160: Loss: 1.3253
# 	Epoch 9, Batch 170: Loss: 1.2099
# 	Epoch 9, Batch 180: Loss: 1.0494
# 	Epoch 9, Batch 190: Loss: 0.8682
# 	Epoch 9, Batch 200: Loss: 0.6844
# 	Epoch 9, Batch 210: Loss: 0.4692
# 	Epoch 9, Batch 220: Loss: 0.2193
# Epoch: 9, val_loss: 0.19, train_loss: 0.28 val_acc: 93.14, train_acc: 89.07
# 	Epoch 10, Batch 10: Loss: 0.2244
# 	Epoch 10, Batch 20: Loss: 0.4618
# 	Epoch 10, Batch 30: Loss: 0.6707
# 	Epoch 10, Batch 40: Loss: 0.8722
# 	Epoch 10, Batch 50: Loss: 1.0594
# 	Epoch 10, Batch 60: Loss: 1.2771
# 	Epoch 10, Batch 70: Loss: 1.4177
# 	Epoch 10, Batch 80: Loss: 1.4861
# 	Epoch 10, Batch 90: Loss: 1.4906
# 	Epoch 10, Batch 100: Loss: 1.5469
# 	Epoch 10, Batch 110: Loss: 1.5181
# 	Epoch 10, Batch 120: Loss: 1.4930
# 	Epoch 10, Batch 130: Loss: 1.5115
# 	Epoch 10, Batch 140: Loss: 1.4444
# 	Epoch 10, Batch 150: Loss: 1.3440
# 	Epoch 10, Batch 160: Loss: 1.2741
# 	Epoch 10, Batch 170: Loss: 1.1396
# 	Epoch 10, Batch 180: Loss: 1.0085
# 	Epoch 10, Batch 190: Loss: 0.8300
# 	Epoch 10, Batch 200: Loss: 0.6422
# 	Epoch 10, Batch 210: Loss: 0.4361
# 	Epoch 10, Batch 220: Loss: 0.2014
# Epoch: 10, val_loss: 0.19, train_loss: 0.26 val_acc: 92.06, train_acc: 90.39
# 	Epoch 11, Batch 10: Loss: 0.2453
# 	Epoch 11, Batch 20: Loss: 0.4148
# 	Epoch 11, Batch 30: Loss: 0.5636
# 	Epoch 11, Batch 40: Loss: 0.6396
# 	Epoch 11, Batch 50: Loss: 0.8210
# 	Epoch 11, Batch 60: Loss: 0.9944
# 	Epoch 11, Batch 70: Loss: 1.0732
# 	Epoch 11, Batch 80: Loss: 1.1421
# 	Epoch 11, Batch 90: Loss: 1.2254
# 	Epoch 11, Batch 100: Loss: 1.3023
# 	Epoch 11, Batch 110: Loss: 1.3173
# 	Epoch 11, Batch 120: Loss: 1.3197
# 	Epoch 11, Batch 130: Loss: 1.2813
# 	Epoch 11, Batch 140: Loss: 1.2155
# 	Epoch 11, Batch 150: Loss: 1.1779
# 	Epoch 11, Batch 160: Loss: 1.0867
# 	Epoch 11, Batch 170: Loss: 0.9886
# 	Epoch 11, Batch 180: Loss: 0.8562
# 	Epoch 11, Batch 190: Loss: 0.7015
# 	Epoch 11, Batch 200: Loss: 0.5634
# 	Epoch 11, Batch 210: Loss: 0.3821
# 	Epoch 11, Batch 220: Loss: 0.1802
# Epoch: 11, val_loss: 0.18, train_loss: 0.23 val_acc: 93.60, train_acc: 91.21
# 	Epoch 12, Batch 10: Loss: 0.2535
# 	Epoch 12, Batch 20: Loss: 0.4341
# 	Epoch 12, Batch 30: Loss: 0.6234
# 	Epoch 12, Batch 40: Loss: 0.7070
# 	Epoch 12, Batch 50: Loss: 0.7896
# 	Epoch 12, Batch 60: Loss: 0.8762
# 	Epoch 12, Batch 70: Loss: 0.9750
# 	Epoch 12, Batch 80: Loss: 1.0877
# 	Epoch 12, Batch 90: Loss: 1.1225
# 	Epoch 12, Batch 100: Loss: 1.1669
# 	Epoch 12, Batch 110: Loss: 1.1691
# 	Epoch 12, Batch 120: Loss: 1.1954
# 	Epoch 12, Batch 130: Loss: 1.1734
# 	Epoch 12, Batch 140: Loss: 1.1362
# 	Epoch 12, Batch 150: Loss: 1.0824
# 	Epoch 12, Batch 160: Loss: 1.0191
# 	Epoch 12, Batch 170: Loss: 0.9352
# 	Epoch 12, Batch 180: Loss: 0.8212
# 	Epoch 12, Batch 190: Loss: 0.6907
# 	Epoch 12, Batch 200: Loss: 0.5428
# 	Epoch 12, Batch 210: Loss: 0.3715
# 	Epoch 12, Batch 220: Loss: 0.1735
# Epoch: 12, val_loss: 0.25, train_loss: 0.22 val_acc: 89.98, train_acc: 91.87
# 	Epoch 13, Batch 10: Loss: 0.2495
# 	Epoch 13, Batch 20: Loss: 0.4213
# 	Epoch 13, Batch 30: Loss: 0.5894
# 	Epoch 13, Batch 40: Loss: 0.7222
# 	Epoch 13, Batch 50: Loss: 0.8448
# 	Epoch 13, Batch 60: Loss: 0.8862
# 	Epoch 13, Batch 70: Loss: 0.9156
# 	Epoch 13, Batch 80: Loss: 0.9270
# 	Epoch 13, Batch 90: Loss: 0.9986
# 	Epoch 13, Batch 100: Loss: 1.0496
# 	Epoch 13, Batch 110: Loss: 1.1483
# 	Epoch 13, Batch 120: Loss: 1.1631
# 	Epoch 13, Batch 130: Loss: 1.1348
# 	Epoch 13, Batch 140: Loss: 1.1283
# 	Epoch 13, Batch 150: Loss: 1.0836
# 	Epoch 13, Batch 160: Loss: 1.0102
# 	Epoch 13, Batch 170: Loss: 0.9270
# 	Epoch 13, Batch 180: Loss: 0.8065
# 	Epoch 13, Batch 190: Loss: 0.6724
# 	Epoch 13, Batch 200: Loss: 0.5212
# 	Epoch 13, Batch 210: Loss: 0.3476
# 	Epoch 13, Batch 220: Loss: 0.1623
# Epoch: 13, val_loss: 0.23, train_loss: 0.21 val_acc: 91.90, train_acc: 92.13
# 	Epoch 14, Batch 10: Loss: 0.2090
# 	Epoch 14, Batch 20: Loss: 0.3662
# 	Epoch 14, Batch 30: Loss: 0.4957
# 	Epoch 14, Batch 40: Loss: 0.6193
# 	Epoch 14, Batch 50: Loss: 0.7583
# 	Epoch 14, Batch 60: Loss: 0.8357
# 	Epoch 14, Batch 70: Loss: 0.9432
# 	Epoch 14, Batch 80: Loss: 1.0136
# 	Epoch 14, Batch 90: Loss: 1.0481
# 	Epoch 14, Batch 100: Loss: 1.0812
# 	Epoch 14, Batch 110: Loss: 1.1092
# 	Epoch 14, Batch 120: Loss: 1.1038
# 	Epoch 14, Batch 130: Loss: 1.0885
# 	Epoch 14, Batch 140: Loss: 1.0858
# 	Epoch 14, Batch 150: Loss: 1.0410
# 	Epoch 14, Batch 160: Loss: 0.9688
# 	Epoch 14, Batch 170: Loss: 0.8776
# 	Epoch 14, Batch 180: Loss: 0.7782
# 	Epoch 14, Batch 190: Loss: 0.6510
# 	Epoch 14, Batch 200: Loss: 0.5044
# 	Epoch 14, Batch 210: Loss: 0.3387
# 	Epoch 14, Batch 220: Loss: 0.1577
# Epoch: 14, val_loss: 0.17, train_loss: 0.21 val_acc: 94.14, train_acc: 92.22
# 	Epoch 15, Batch 10: Loss: 0.2253
# 	Epoch 15, Batch 20: Loss: 0.4133
# 	Epoch 15, Batch 30: Loss: 0.5153
# 	Epoch 15, Batch 40: Loss: 0.6762
# 	Epoch 15, Batch 50: Loss: 0.8613
# 	Epoch 15, Batch 60: Loss: 0.9021
# 	Epoch 15, Batch 70: Loss: 0.9511
# 	Epoch 15, Batch 80: Loss: 1.0365
# 	Epoch 15, Batch 90: Loss: 1.0768
# 	Epoch 15, Batch 100: Loss: 1.0982
# 	Epoch 15, Batch 110: Loss: 1.0982
# 	Epoch 15, Batch 120: Loss: 1.0914
# 	Epoch 15, Batch 130: Loss: 1.0534
# 	Epoch 15, Batch 140: Loss: 0.9806
# 	Epoch 15, Batch 150: Loss: 0.9306
# 	Epoch 15, Batch 160: Loss: 0.8717
# 	Epoch 15, Batch 170: Loss: 0.7974
# 	Epoch 15, Batch 180: Loss: 0.6999
# 	Epoch 15, Batch 190: Loss: 0.5873
# 	Epoch 15, Batch 200: Loss: 0.4507
# 	Epoch 15, Batch 210: Loss: 0.3037
# 	Epoch 15, Batch 220: Loss: 0.1445
# Epoch: 15, val_loss: 0.21, train_loss: 0.19 val_acc: 93.14, train_acc: 92.84
# 	Epoch 16, Batch 10: Loss: 0.2286
# 	Epoch 16, Batch 20: Loss: 0.4219
# 	Epoch 16, Batch 30: Loss: 0.5158
# 	Epoch 16, Batch 40: Loss: 0.6480
# 	Epoch 16, Batch 50: Loss: 0.7472
# 	Epoch 16, Batch 60: Loss: 0.8412
# 	Epoch 16, Batch 70: Loss: 0.9008
# 	Epoch 16, Batch 80: Loss: 0.9166
# 	Epoch 16, Batch 90: Loss: 0.9747
# 	Epoch 16, Batch 100: Loss: 1.0231
# 	Epoch 16, Batch 110: Loss: 1.0065
# 	Epoch 16, Batch 120: Loss: 1.0262
# 	Epoch 16, Batch 130: Loss: 0.9865
# 	Epoch 16, Batch 140: Loss: 0.9432
# 	Epoch 16, Batch 150: Loss: 0.8792
# 	Epoch 16, Batch 160: Loss: 0.8229
# 	Epoch 16, Batch 170: Loss: 0.7684
# 	Epoch 16, Batch 180: Loss: 0.6641
# 	Epoch 16, Batch 190: Loss: 0.5606
# 	Epoch 16, Batch 200: Loss: 0.4269
# 	Epoch 16, Batch 210: Loss: 0.2861
# 	Epoch 16, Batch 220: Loss: 0.1311
# Epoch: 16, val_loss: 0.12, train_loss: 0.17 val_acc: 96.14, train_acc: 93.52
# 	Epoch 17, Batch 10: Loss: 0.1216
# 	Epoch 17, Batch 20: Loss: 0.2362
# 	Epoch 17, Batch 30: Loss: 0.3726
# 	Epoch 17, Batch 40: Loss: 0.4564
# 	Epoch 17, Batch 50: Loss: 0.5740
# 	Epoch 17, Batch 60: Loss: 0.6339
# 	Epoch 17, Batch 70: Loss: 0.6976
# 	Epoch 17, Batch 80: Loss: 0.7240
# 	Epoch 17, Batch 90: Loss: 0.7556
# 	Epoch 17, Batch 100: Loss: 0.7734
# 	Epoch 17, Batch 110: Loss: 0.8249
# 	Epoch 17, Batch 120: Loss: 0.8368
# 	Epoch 17, Batch 130: Loss: 0.8241
# 	Epoch 17, Batch 140: Loss: 0.7963
# 	Epoch 17, Batch 150: Loss: 0.7758
# 	Epoch 17, Batch 160: Loss: 0.7258
# 	Epoch 17, Batch 170: Loss: 0.6586
# 	Epoch 17, Batch 180: Loss: 0.5979
# 	Epoch 17, Batch 190: Loss: 0.5007
# 	Epoch 17, Batch 200: Loss: 0.3873
# 	Epoch 17, Batch 210: Loss: 0.2681
# 	Epoch 17, Batch 220: Loss: 0.1250
# Epoch: 17, val_loss: 0.27, train_loss: 0.16 val_acc: 90.13, train_acc: 93.90
# 	Epoch 18, Batch 10: Loss: 0.1579
# 	Epoch 18, Batch 20: Loss: 0.2573
# 	Epoch 18, Batch 30: Loss: 0.3612
# 	Epoch 18, Batch 40: Loss: 0.5322
# 	Epoch 18, Batch 50: Loss: 0.5994
# 	Epoch 18, Batch 60: Loss: 0.6533
# 	Epoch 18, Batch 70: Loss: 0.7087
# 	Epoch 18, Batch 80: Loss: 0.7663
# 	Epoch 18, Batch 90: Loss: 0.7664
# 	Epoch 18, Batch 100: Loss: 0.7960
# 	Epoch 18, Batch 110: Loss: 0.8124
# 	Epoch 18, Batch 120: Loss: 0.7985
# 	Epoch 18, Batch 130: Loss: 0.7744
# 	Epoch 18, Batch 140: Loss: 0.7671
# 	Epoch 18, Batch 150: Loss: 0.7271
# 	Epoch 18, Batch 160: Loss: 0.6886
# 	Epoch 18, Batch 170: Loss: 0.6251
# 	Epoch 18, Batch 180: Loss: 0.5483
# 	Epoch 18, Batch 190: Loss: 0.4581
# 	Epoch 18, Batch 200: Loss: 0.3666
# 	Epoch 18, Batch 210: Loss: 0.2471
# 	Epoch 18, Batch 220: Loss: 0.1172
# Epoch: 18, val_loss: 0.14, train_loss: 0.15 val_acc: 94.99, train_acc: 94.01
# 	Epoch 19, Batch 10: Loss: 0.1609
# 	Epoch 19, Batch 20: Loss: 0.2600
# 	Epoch 19, Batch 30: Loss: 0.3580
# 	Epoch 19, Batch 40: Loss: 0.3810
# 	Epoch 19, Batch 50: Loss: 0.4458
# 	Epoch 19, Batch 60: Loss: 0.4910
# 	Epoch 19, Batch 70: Loss: 0.5683
# 	Epoch 19, Batch 80: Loss: 0.6145
# 	Epoch 19, Batch 90: Loss: 0.6430
# 	Epoch 19, Batch 100: Loss: 0.6884
# 	Epoch 19, Batch 110: Loss: 0.7072
# 	Epoch 19, Batch 120: Loss: 0.7100
# 	Epoch 19, Batch 130: Loss: 0.7743
# 	Epoch 19, Batch 140: Loss: 0.7401
# 	Epoch 19, Batch 150: Loss: 0.7200
# 	Epoch 19, Batch 160: Loss: 0.6756
# 	Epoch 19, Batch 170: Loss: 0.6230
# 	Epoch 19, Batch 180: Loss: 0.5465
# 	Epoch 19, Batch 190: Loss: 0.4538
# 	Epoch 19, Batch 200: Loss: 0.3631
# 	Epoch 19, Batch 210: Loss: 0.2467
# 	Epoch 19, Batch 220: Loss: 0.1154
# Epoch: 19, val_loss: 0.12, train_loss: 0.15 val_acc: 96.07, train_acc: 94.67
# 	Epoch 20, Batch 10: Loss: 0.1115
# 	Epoch 20, Batch 20: Loss: 0.2193
# 	Epoch 20, Batch 30: Loss: 0.2926
# 	Epoch 20, Batch 40: Loss: 0.3412
# 	Epoch 20, Batch 50: Loss: 0.4344
# 	Epoch 20, Batch 60: Loss: 0.5543
# 	Epoch 20, Batch 70: Loss: 0.6279
# 	Epoch 20, Batch 80: Loss: 0.6638
# 	Epoch 20, Batch 90: Loss: 0.7120
# 	Epoch 20, Batch 100: Loss: 0.7218
# 	Epoch 20, Batch 110: Loss: 0.7205
# 	Epoch 20, Batch 120: Loss: 0.7384
# 	Epoch 20, Batch 130: Loss: 0.7167
# 	Epoch 20, Batch 140: Loss: 0.6911
# 	Epoch 20, Batch 150: Loss: 0.6541
# 	Epoch 20, Batch 160: Loss: 0.6124
# 	Epoch 20, Batch 170: Loss: 0.5582
# 	Epoch 20, Batch 180: Loss: 0.4845
# 	Epoch 20, Batch 190: Loss: 0.4013
# 	Epoch 20, Batch 200: Loss: 0.3164
# 	Epoch 20, Batch 210: Loss: 0.2125
# 	Epoch 20, Batch 220: Loss: 0.0983
# Epoch: 20, val_loss: 0.20, train_loss: 0.13 val_acc: 93.45, train_acc: 95.13
# 	Epoch 21, Batch 10: Loss: 0.1558
# 	Epoch 21, Batch 20: Loss: 0.2881
# 	Epoch 21, Batch 30: Loss: 0.3541
# 	Epoch 21, Batch 40: Loss: 0.4778
# 	Epoch 21, Batch 50: Loss: 0.5527
# 	Epoch 21, Batch 60: Loss: 0.6033
# 	Epoch 21, Batch 70: Loss: 0.6609
# 	Epoch 21, Batch 80: Loss: 0.7527
# 	Epoch 21, Batch 90: Loss: 0.7825
# 	Epoch 21, Batch 100: Loss: 0.7847
# 	Epoch 21, Batch 110: Loss: 0.7936
# 	Epoch 21, Batch 120: Loss: 0.8087
# 	Epoch 21, Batch 130: Loss: 0.7855
# 	Epoch 21, Batch 140: Loss: 0.7365
# 	Epoch 21, Batch 150: Loss: 0.7150
# 	Epoch 21, Batch 160: Loss: 0.6654
# 	Epoch 21, Batch 170: Loss: 0.5965
# 	Epoch 21, Batch 180: Loss: 0.5224
# 	Epoch 21, Batch 190: Loss: 0.4393
# 	Epoch 21, Batch 200: Loss: 0.3461
# 	Epoch 21, Batch 210: Loss: 0.2381
# 	Epoch 21, Batch 220: Loss: 0.1110
# Epoch: 21, val_loss: 0.15, train_loss: 0.14 val_acc: 95.14, train_acc: 94.95
# 	Epoch 22, Batch 10: Loss: 0.0847
# 	Epoch 22, Batch 20: Loss: 0.1589
# 	Epoch 22, Batch 30: Loss: 0.3389
# 	Epoch 22, Batch 40: Loss: 0.4798
# 	Epoch 22, Batch 50: Loss: 0.5399
# 	Epoch 22, Batch 60: Loss: 0.6027
# 	Epoch 22, Batch 70: Loss: 0.6555
# 	Epoch 22, Batch 80: Loss: 0.6994
# 	Epoch 22, Batch 90: Loss: 0.7228
# 	Epoch 22, Batch 100: Loss: 0.7301
# 	Epoch 22, Batch 110: Loss: 0.7371
# 	Epoch 22, Batch 120: Loss: 0.7287
# 	Epoch 22, Batch 130: Loss: 0.7054
# 	Epoch 22, Batch 140: Loss: 0.6966
# 	Epoch 22, Batch 150: Loss: 0.6721
# 	Epoch 22, Batch 160: Loss: 0.6273
# 	Epoch 22, Batch 170: Loss: 0.5873
# 	Epoch 22, Batch 180: Loss: 0.5025
# 	Epoch 22, Batch 190: Loss: 0.4125
# 	Epoch 22, Batch 200: Loss: 0.3173
# 	Epoch 22, Batch 210: Loss: 0.2119
# 	Epoch 22, Batch 220: Loss: 0.0977
# Epoch: 22, val_loss: 0.09, train_loss: 0.13 val_acc: 96.76, train_acc: 95.50
# 	Epoch 23, Batch 10: Loss: 0.1153
# 	Epoch 23, Batch 20: Loss: 0.2909
# 	Epoch 23, Batch 30: Loss: 0.3755
# 	Epoch 23, Batch 40: Loss: 0.4219
# 	Epoch 23, Batch 50: Loss: 0.4791
# 	Epoch 23, Batch 60: Loss: 0.5212
# 	Epoch 23, Batch 70: Loss: 0.6109
# 	Epoch 23, Batch 80: Loss: 0.6736
# 	Epoch 23, Batch 90: Loss: 0.6968
# 	Epoch 23, Batch 100: Loss: 0.6786
# 	Epoch 23, Batch 110: Loss: 0.6924
# 	Epoch 23, Batch 120: Loss: 0.6684
# 	Epoch 23, Batch 130: Loss: 0.6797
# 	Epoch 23, Batch 140: Loss: 0.6766
# 	Epoch 23, Batch 150: Loss: 0.6485
# 	Epoch 23, Batch 160: Loss: 0.6013
# 	Epoch 23, Batch 170: Loss: 0.5344
# 	Epoch 23, Batch 180: Loss: 0.4666
# 	Epoch 23, Batch 190: Loss: 0.3826
# 	Epoch 23, Batch 200: Loss: 0.2971
# 	Epoch 23, Batch 210: Loss: 0.2001
# 	Epoch 23, Batch 220: Loss: 0.0964
# Epoch: 23, val_loss: 0.12, train_loss: 0.12 val_acc: 96.07, train_acc: 95.61
# 	Epoch 24, Batch 10: Loss: 0.1328
# 	Epoch 24, Batch 20: Loss: 0.2160
# 	Epoch 24, Batch 30: Loss: 0.3121
# 	Epoch 24, Batch 40: Loss: 0.3569
# 	Epoch 24, Batch 50: Loss: 0.4146
# 	Epoch 24, Batch 60: Loss: 0.4870
# 	Epoch 24, Batch 70: Loss: 0.5439
# 	Epoch 24, Batch 80: Loss: 0.6190
# 	Epoch 24, Batch 90: Loss: 0.6383
# 	Epoch 24, Batch 100: Loss: 0.6677
# 	Epoch 24, Batch 110: Loss: 0.6611
# 	Epoch 24, Batch 120: Loss: 0.6804
# 	Epoch 24, Batch 130: Loss: 0.6684
# 	Epoch 24, Batch 140: Loss: 0.6278
# 	Epoch 24, Batch 150: Loss: 0.6019
# 	Epoch 24, Batch 160: Loss: 0.5592
# 	Epoch 24, Batch 170: Loss: 0.5064
# 	Epoch 24, Batch 180: Loss: 0.4394
# 	Epoch 24, Batch 190: Loss: 0.3597
# 	Epoch 24, Batch 200: Loss: 0.2776
# 	Epoch 24, Batch 210: Loss: 0.1858
# 	Epoch 24, Batch 220: Loss: 0.0870
# Epoch: 24, val_loss: 0.47, train_loss: 0.11 val_acc: 87.05, train_acc: 95.95
# 	Epoch 25, Batch 10: Loss: 0.1426
# 	Epoch 25, Batch 20: Loss: 0.2586
# 	Epoch 25, Batch 30: Loss: 0.3379
# 	Epoch 25, Batch 40: Loss: 0.4385
# 	Epoch 25, Batch 50: Loss: 0.4770
# 	Epoch 25, Batch 60: Loss: 0.5638
# 	Epoch 25, Batch 70: Loss: 0.6993
# 	Epoch 25, Batch 80: Loss: 0.7126
# 	Epoch 25, Batch 90: Loss: 0.7491
# 	Epoch 25, Batch 100: Loss: 0.7591
# 	Epoch 25, Batch 110: Loss: 0.7547
# 	Epoch 25, Batch 120: Loss: 0.7292
# 	Epoch 25, Batch 130: Loss: 0.7318
# 	Epoch 25, Batch 140: Loss: 0.7002
# 	Epoch 25, Batch 150: Loss: 0.6533
# 	Epoch 25, Batch 160: Loss: 0.5963
# 	Epoch 25, Batch 170: Loss: 0.5421
# 	Epoch 25, Batch 180: Loss: 0.4729
# 	Epoch 25, Batch 190: Loss: 0.4067
# 	Epoch 25, Batch 200: Loss: 0.3219
# 	Epoch 25, Batch 210: Loss: 0.2182
# 	Epoch 25, Batch 220: Loss: 0.1019
# Epoch: 25, val_loss: 0.21, train_loss: 0.13 val_acc: 92.14, train_acc: 95.13
# 	Epoch 26, Batch 10: Loss: 0.1362
# 	Epoch 26, Batch 20: Loss: 0.1896
# 	Epoch 26, Batch 30: Loss: 0.2251
# 	Epoch 26, Batch 40: Loss: 0.2737
# 	Epoch 26, Batch 50: Loss: 0.3178
# 	Epoch 26, Batch 60: Loss: 0.4025
# 	Epoch 26, Batch 70: Loss: 0.4475
# 	Epoch 26, Batch 80: Loss: 0.4958
# 	Epoch 26, Batch 90: Loss: 0.5381
# 	Epoch 26, Batch 100: Loss: 0.5590
# 	Epoch 26, Batch 110: Loss: 0.5606
# 	Epoch 26, Batch 120: Loss: 0.5350
# 	Epoch 26, Batch 130: Loss: 0.5776
# 	Epoch 26, Batch 140: Loss: 0.5544
# 	Epoch 26, Batch 150: Loss: 0.5381
# 	Epoch 26, Batch 160: Loss: 0.4923
# 	Epoch 26, Batch 170: Loss: 0.4605
# 	Epoch 26, Batch 180: Loss: 0.4061
# 	Epoch 26, Batch 190: Loss: 0.3549
# 	Epoch 26, Batch 200: Loss: 0.2790
# 	Epoch 26, Batch 210: Loss: 0.1877
# 	Epoch 26, Batch 220: Loss: 0.0891
# Epoch: 26, val_loss: 1.21, train_loss: 0.12 val_acc: 64.92, train_acc: 95.53
# 	Epoch 27, Batch 10: Loss: 0.1660
# 	Epoch 27, Batch 20: Loss: 0.3864
# 	Epoch 27, Batch 30: Loss: 0.4999
# 	Epoch 27, Batch 40: Loss: 0.5457
# 	Epoch 27, Batch 50: Loss: 0.5821
# 	Epoch 27, Batch 60: Loss: 0.6143
# 	Epoch 27, Batch 70: Loss: 0.6454
# 	Epoch 27, Batch 80: Loss: 0.6315
# 	Epoch 27, Batch 90: Loss: 0.6724
# 	Epoch 27, Batch 100: Loss: 0.6838
# 	Epoch 27, Batch 110: Loss: 0.6848
# 	Epoch 27, Batch 120: Loss: 0.6682
# 	Epoch 27, Batch 130: Loss: 0.6605
# 	Epoch 27, Batch 140: Loss: 0.6401
# 	Epoch 27, Batch 150: Loss: 0.6004
# 	Epoch 27, Batch 160: Loss: 0.5648
# 	Epoch 27, Batch 170: Loss: 0.5088
# 	Epoch 27, Batch 180: Loss: 0.4610
# 	Epoch 27, Batch 190: Loss: 0.3846
# 	Epoch 27, Batch 200: Loss: 0.2971
# 	Epoch 27, Batch 210: Loss: 0.1960
# 	Epoch 27, Batch 220: Loss: 0.0908
# Epoch: 27, val_loss: 0.15, train_loss: 0.12 val_acc: 94.53, train_acc: 95.44
# 	Epoch 28, Batch 10: Loss: 0.1014
# 	Epoch 28, Batch 20: Loss: 0.1848
# 	Epoch 28, Batch 30: Loss: 0.3167
# 	Epoch 28, Batch 40: Loss: 0.3708
# 	Epoch 28, Batch 50: Loss: 0.4269
# 	Epoch 28, Batch 60: Loss: 0.4360
# 	Epoch 28, Batch 70: Loss: 0.5059
# 	Epoch 28, Batch 80: Loss: 0.5303
# 	Epoch 28, Batch 90: Loss: 0.5391
# 	Epoch 28, Batch 100: Loss: 0.5237
# 	Epoch 28, Batch 110: Loss: 0.5436
# 	Epoch 28, Batch 120: Loss: 0.5278
# 	Epoch 28, Batch 130: Loss: 0.5143
# 	Epoch 28, Batch 140: Loss: 0.5178
# 	Epoch 28, Batch 150: Loss: 0.4894
# 	Epoch 28, Batch 160: Loss: 0.4750
# 	Epoch 28, Batch 170: Loss: 0.4370
# 	Epoch 28, Batch 180: Loss: 0.3944
# 	Epoch 28, Batch 190: Loss: 0.3273
# 	Epoch 28, Batch 200: Loss: 0.2582
# 	Epoch 28, Batch 210: Loss: 0.1714
# 	Epoch 28, Batch 220: Loss: 0.0794
# Epoch: 28, val_loss: 0.15, train_loss: 0.10 val_acc: 95.14, train_acc: 96.45
# 	Epoch 29, Batch 10: Loss: 0.0714
# 	Epoch 29, Batch 20: Loss: 0.1468
# 	Epoch 29, Batch 30: Loss: 0.2158
# 	Epoch 29, Batch 40: Loss: 0.2918
# 	Epoch 29, Batch 50: Loss: 0.3529
# 	Epoch 29, Batch 60: Loss: 0.4248
# 	Epoch 29, Batch 70: Loss: 0.4798
# 	Epoch 29, Batch 80: Loss: 0.5003
# 	Epoch 29, Batch 90: Loss: 0.4913
# 	Epoch 29, Batch 100: Loss: 0.4938
# 	Epoch 29, Batch 110: Loss: 0.4996
# 	Epoch 29, Batch 120: Loss: 0.5262
# 	Epoch 29, Batch 130: Loss: 0.5699
# 	Epoch 29, Batch 140: Loss: 0.5506
# 	Epoch 29, Batch 150: Loss: 0.5219
# 	Epoch 29, Batch 160: Loss: 0.4807
# 	Epoch 29, Batch 170: Loss: 0.4502
# 	Epoch 29, Batch 180: Loss: 0.3828
# 	Epoch 29, Batch 190: Loss: 0.3315
# 	Epoch 29, Batch 200: Loss: 0.2538
# 	Epoch 29, Batch 210: Loss: 0.1663
# 	Epoch 29, Batch 220: Loss: 0.0762
# Epoch: 29, val_loss: 0.09, train_loss: 0.10 val_acc: 96.92, train_acc: 96.47
# 	Epoch 30, Batch 10: Loss: 0.0785
# 	Epoch 30, Batch 20: Loss: 0.1605
# 	Epoch 30, Batch 30: Loss: 0.2318
# 	Epoch 30, Batch 40: Loss: 0.3165
# 	Epoch 30, Batch 50: Loss: 0.3487
# 	Epoch 30, Batch 60: Loss: 0.4112
# 	Epoch 30, Batch 70: Loss: 0.4364
# 	Epoch 30, Batch 80: Loss: 0.4597
# 	Epoch 30, Batch 90: Loss: 0.5636
# 	Epoch 30, Batch 100: Loss: 0.5896
# 	Epoch 30, Batch 110: Loss: 0.6205
# 	Epoch 30, Batch 120: Loss: 0.6184
# 	Epoch 30, Batch 130: Loss: 0.6053
# 	Epoch 30, Batch 140: Loss: 0.5764
# 	Epoch 30, Batch 150: Loss: 0.5680
# 	Epoch 30, Batch 160: Loss: 0.5300
# 	Epoch 30, Batch 170: Loss: 0.4865
# 	Epoch 30, Batch 180: Loss: 0.4151
# 	Epoch 30, Batch 190: Loss: 0.3370
# 	Epoch 30, Batch 200: Loss: 0.2540
# 	Epoch 30, Batch 210: Loss: 0.1744
# 	Epoch 30, Batch 220: Loss: 0.0796
# Epoch: 30, val_loss: 0.12, train_loss: 0.10 val_acc: 95.91, train_acc: 96.76
# 	Epoch 31, Batch 10: Loss: 0.0430
# 	Epoch 31, Batch 20: Loss: 0.1170
# 	Epoch 31, Batch 30: Loss: 0.2057
# 	Epoch 31, Batch 40: Loss: 0.2582
# 	Epoch 31, Batch 50: Loss: 0.3221
# 	Epoch 31, Batch 60: Loss: 0.3683
# 	Epoch 31, Batch 70: Loss: 0.3950
# 	Epoch 31, Batch 80: Loss: 0.4440
# 	Epoch 31, Batch 90: Loss: 0.5113
# 	Epoch 31, Batch 100: Loss: 0.5631
# 	Epoch 31, Batch 110: Loss: 0.5954
# 	Epoch 31, Batch 120: Loss: 0.6074
# 	Epoch 31, Batch 130: Loss: 0.5970
# 	Epoch 31, Batch 140: Loss: 0.5739
# 	Epoch 31, Batch 150: Loss: 0.5454
# 	Epoch 31, Batch 160: Loss: 0.5035
# 	Epoch 31, Batch 170: Loss: 0.4546
# 	Epoch 31, Batch 180: Loss: 0.3994
# 	Epoch 31, Batch 190: Loss: 0.3265
# 	Epoch 31, Batch 200: Loss: 0.2514
# 	Epoch 31, Batch 210: Loss: 0.1675
# 	Epoch 31, Batch 220: Loss: 0.0763
# Epoch: 31, val_loss: 0.10, train_loss: 0.10 val_acc: 96.76, train_acc: 96.30
# 	Epoch 32, Batch 10: Loss: 0.1331
# 	Epoch 32, Batch 20: Loss: 0.1985
# 	Epoch 32, Batch 30: Loss: 0.3011
# 	Epoch 32, Batch 40: Loss: 0.3521
# 	Epoch 32, Batch 50: Loss: 0.4058
# 	Epoch 32, Batch 60: Loss: 0.4244
# 	Epoch 32, Batch 70: Loss: 0.4485
# 	Epoch 32, Batch 80: Loss: 0.5077
# 	Epoch 32, Batch 90: Loss: 0.5265
# 	Epoch 32, Batch 100: Loss: 0.5048
# 	Epoch 32, Batch 110: Loss: 0.5175
# 	Epoch 32, Batch 120: Loss: 0.5221
# 	Epoch 32, Batch 130: Loss: 0.5080
# 	Epoch 32, Batch 140: Loss: 0.4856
# 	Epoch 32, Batch 150: Loss: 0.4429
# 	Epoch 32, Batch 160: Loss: 0.4023
# 	Epoch 32, Batch 170: Loss: 0.3678
# 	Epoch 32, Batch 180: Loss: 0.3225
# 	Epoch 32, Batch 190: Loss: 0.2814
# 	Epoch 32, Batch 200: Loss: 0.2204
# 	Epoch 32, Batch 210: Loss: 0.1484
# 	Epoch 32, Batch 220: Loss: 0.0690
# Epoch: 32, val_loss: 0.10, train_loss: 0.09 val_acc: 96.76, train_acc: 96.85
# 	Epoch 33, Batch 10: Loss: 0.0292
# 	Epoch 33, Batch 20: Loss: 0.0994
# 	Epoch 33, Batch 30: Loss: 0.1728
# 	Epoch 33, Batch 40: Loss: 0.2234
# 	Epoch 33, Batch 50: Loss: 0.2567
# 	Epoch 33, Batch 60: Loss: 0.2963
# 	Epoch 33, Batch 70: Loss: 0.3761
# 	Epoch 33, Batch 80: Loss: 0.3969
# 	Epoch 33, Batch 90: Loss: 0.4135
# 	Epoch 33, Batch 100: Loss: 0.4500
# 	Epoch 33, Batch 110: Loss: 0.4499
# 	Epoch 33, Batch 120: Loss: 0.4505
# 	Epoch 33, Batch 130: Loss: 0.4395
# 	Epoch 33, Batch 140: Loss: 0.4315
# 	Epoch 33, Batch 150: Loss: 0.4048
# 	Epoch 33, Batch 160: Loss: 0.3865
# 	Epoch 33, Batch 170: Loss: 0.3477
# 	Epoch 33, Batch 180: Loss: 0.3169
# 	Epoch 33, Batch 190: Loss: 0.2688
# 	Epoch 33, Batch 200: Loss: 0.2084
# 	Epoch 33, Batch 210: Loss: 0.1442
# 	Epoch 33, Batch 220: Loss: 0.0699
# Epoch: 33, val_loss: 0.09, train_loss: 0.09 val_acc: 97.07, train_acc: 96.61
# 	Epoch 34, Batch 10: Loss: 0.0744
# 	Epoch 34, Batch 20: Loss: 0.1559
# 	Epoch 34, Batch 30: Loss: 0.1845
# 	Epoch 34, Batch 40: Loss: 0.1956
# 	Epoch 34, Batch 50: Loss: 0.2552
# 	Epoch 34, Batch 60: Loss: 0.2867
# 	Epoch 34, Batch 70: Loss: 0.3239
# 	Epoch 34, Batch 80: Loss: 0.3296
# 	Epoch 34, Batch 90: Loss: 0.3641
# 	Epoch 34, Batch 100: Loss: 0.3682
# 	Epoch 34, Batch 110: Loss: 0.3703
# 	Epoch 34, Batch 120: Loss: 0.3696
# 	Epoch 34, Batch 130: Loss: 0.4087
# 	Epoch 34, Batch 140: Loss: 0.4208
# 	Epoch 34, Batch 150: Loss: 0.4457
# 	Epoch 34, Batch 160: Loss: 0.4201
# 	Epoch 34, Batch 170: Loss: 0.3925
# 	Epoch 34, Batch 180: Loss: 0.3441
# 	Epoch 34, Batch 190: Loss: 0.2800
# 	Epoch 34, Batch 200: Loss: 0.2195
# 	Epoch 34, Batch 210: Loss: 0.1480
# 	Epoch 34, Batch 220: Loss: 0.0713
# Epoch: 34, val_loss: 0.09, train_loss: 0.09 val_acc: 97.30, train_acc: 96.91
# 	Epoch 35, Batch 10: Loss: 0.0583
# 	Epoch 35, Batch 20: Loss: 0.1305
# 	Epoch 35, Batch 30: Loss: 0.1708
# 	Epoch 35, Batch 40: Loss: 0.2158
# 	Epoch 35, Batch 50: Loss: 0.2800
# 	Epoch 35, Batch 60: Loss: 0.3246
# 	Epoch 35, Batch 70: Loss: 0.3750
# 	Epoch 35, Batch 80: Loss: 0.4006
# 	Epoch 35, Batch 90: Loss: 0.3952
# 	Epoch 35, Batch 100: Loss: 0.3975
# 	Epoch 35, Batch 110: Loss: 0.3914
# 	Epoch 35, Batch 120: Loss: 0.3882
# 	Epoch 35, Batch 130: Loss: 0.3892
# 	Epoch 35, Batch 140: Loss: 0.3675
# 	Epoch 35, Batch 150: Loss: 0.3595
# 	Epoch 35, Batch 160: Loss: 0.3398
# 	Epoch 35, Batch 170: Loss: 0.3204
# 	Epoch 35, Batch 180: Loss: 0.2814
# 	Epoch 35, Batch 190: Loss: 0.2381
# 	Epoch 35, Batch 200: Loss: 0.1960
# 	Epoch 35, Batch 210: Loss: 0.1381
# 	Epoch 35, Batch 220: Loss: 0.0643
# Epoch: 35, val_loss: 0.12, train_loss: 0.08 val_acc: 95.91, train_acc: 97.05
# 	Epoch 36, Batch 10: Loss: 0.0308
# 	Epoch 36, Batch 20: Loss: 0.1018
# 	Epoch 36, Batch 30: Loss: 0.1298
# 	Epoch 36, Batch 40: Loss: 0.2041
# 	Epoch 36, Batch 50: Loss: 0.2279
# 	Epoch 36, Batch 60: Loss: 0.3172
# 	Epoch 36, Batch 70: Loss: 0.3487
# 	Epoch 36, Batch 80: Loss: 0.3640
# 	Epoch 36, Batch 90: Loss: 0.4123
# 	Epoch 36, Batch 100: Loss: 0.4258
# 	Epoch 36, Batch 110: Loss: 0.4417
# 	Epoch 36, Batch 120: Loss: 0.4332
# 	Epoch 36, Batch 130: Loss: 0.4363
# 	Epoch 36, Batch 140: Loss: 0.4100
# 	Epoch 36, Batch 150: Loss: 0.3846
# 	Epoch 36, Batch 160: Loss: 0.3553
# 	Epoch 36, Batch 170: Loss: 0.3135
# 	Epoch 36, Batch 180: Loss: 0.2773
# 	Epoch 36, Batch 190: Loss: 0.2344
# 	Epoch 36, Batch 200: Loss: 0.1812
# 	Epoch 36, Batch 210: Loss: 0.1225
# 	Epoch 36, Batch 220: Loss: 0.0586
# Epoch: 36, val_loss: 0.08, train_loss: 0.08 val_acc: 97.46, train_acc: 97.44
# 	Epoch 37, Batch 10: Loss: 0.0901
# 	Epoch 37, Batch 20: Loss: 0.1468
# 	Epoch 37, Batch 30: Loss: 0.2177
# 	Epoch 37, Batch 40: Loss: 0.2477
# 	Epoch 37, Batch 50: Loss: 0.2664
# 	Epoch 37, Batch 60: Loss: 0.3478
# 	Epoch 37, Batch 70: Loss: 0.3657
# 	Epoch 37, Batch 80: Loss: 0.3837
# 	Epoch 37, Batch 90: Loss: 0.3894
# 	Epoch 37, Batch 100: Loss: 0.3990
# 	Epoch 37, Batch 110: Loss: 0.4131
# 	Epoch 37, Batch 120: Loss: 0.4627
# 	Epoch 37, Batch 130: Loss: 0.4582
# 	Epoch 37, Batch 140: Loss: 0.4526
# 	Epoch 37, Batch 150: Loss: 0.4264
# 	Epoch 37, Batch 160: Loss: 0.4139
# 	Epoch 37, Batch 170: Loss: 0.3669
# 	Epoch 37, Batch 180: Loss: 0.3186
# 	Epoch 37, Batch 190: Loss: 0.2612
# 	Epoch 37, Batch 200: Loss: 0.1978
# 	Epoch 37, Batch 210: Loss: 0.1347
# 	Epoch 37, Batch 220: Loss: 0.0641
# Epoch: 37, val_loss: 0.16, train_loss: 0.08 val_acc: 94.53, train_acc: 97.18
# 	Epoch 38, Batch 10: Loss: 0.0606
# 	Epoch 38, Batch 20: Loss: 0.0940
# 	Epoch 38, Batch 30: Loss: 0.1549
# 	Epoch 38, Batch 40: Loss: 0.1923
# 	Epoch 38, Batch 50: Loss: 0.2108
# 	Epoch 38, Batch 60: Loss: 0.2384
# 	Epoch 38, Batch 70: Loss: 0.2747
# 	Epoch 38, Batch 80: Loss: 0.3215
# 	Epoch 38, Batch 90: Loss: 0.3332
# 	Epoch 38, Batch 100: Loss: 0.3612
# 	Epoch 38, Batch 110: Loss: 0.3765
# 	Epoch 38, Batch 120: Loss: 0.3859
# 	Epoch 38, Batch 130: Loss: 0.3735
# 	Epoch 38, Batch 140: Loss: 0.3621
# 	Epoch 38, Batch 150: Loss: 0.3778
# 	Epoch 38, Batch 160: Loss: 0.3625
# 	Epoch 38, Batch 170: Loss: 0.3249
# 	Epoch 38, Batch 180: Loss: 0.2922
# 	Epoch 38, Batch 190: Loss: 0.2546
# 	Epoch 38, Batch 200: Loss: 0.1940
# 	Epoch 38, Batch 210: Loss: 0.1319
# 	Epoch 38, Batch 220: Loss: 0.0601
# Epoch: 38, val_loss: 0.13, train_loss: 0.08 val_acc: 96.14, train_acc: 97.22
# 	Epoch 39, Batch 10: Loss: 0.0850
# 	Epoch 39, Batch 20: Loss: 0.1805
# 	Epoch 39, Batch 30: Loss: 0.2352
# 	Epoch 39, Batch 40: Loss: 0.2867
# 	Epoch 39, Batch 50: Loss: 0.3184
# 	Epoch 39, Batch 60: Loss: 0.3344
# 	Epoch 39, Batch 70: Loss: 0.3647
# 	Epoch 39, Batch 80: Loss: 0.3851
# 	Epoch 39, Batch 90: Loss: 0.4022
# 	Epoch 39, Batch 100: Loss: 0.4218
# 	Epoch 39, Batch 110: Loss: 0.4179
# 	Epoch 39, Batch 120: Loss: 0.4028
# 	Epoch 39, Batch 130: Loss: 0.4006
# 	Epoch 39, Batch 140: Loss: 0.3855
# 	Epoch 39, Batch 150: Loss: 0.3737
# 	Epoch 39, Batch 160: Loss: 0.3478
# 	Epoch 39, Batch 170: Loss: 0.3190
# 	Epoch 39, Batch 180: Loss: 0.2793
# 	Epoch 39, Batch 190: Loss: 0.2342
# 	Epoch 39, Batch 200: Loss: 0.1871
# 	Epoch 39, Batch 210: Loss: 0.1262
# 	Epoch 39, Batch 220: Loss: 0.0582
# Epoch: 39, val_loss: 0.16, train_loss: 0.08 val_acc: 94.60, train_acc: 97.42
# 	Epoch 40, Batch 10: Loss: 0.0806
# 	Epoch 40, Batch 20: Loss: 0.1331
# 	Epoch 40, Batch 30: Loss: 0.2325
# 	Epoch 40, Batch 40: Loss: 0.2565
# 	Epoch 40, Batch 50: Loss: 0.2624
# 	Epoch 40, Batch 60: Loss: 0.2741
# 	Epoch 40, Batch 70: Loss: 0.2710
# 	Epoch 40, Batch 80: Loss: 0.2697
# 	Epoch 40, Batch 90: Loss: 0.2973
# 	Epoch 40, Batch 100: Loss: 0.3073
# 	Epoch 40, Batch 110: Loss: 0.3330
# 	Epoch 40, Batch 120: Loss: 0.3240
# 	Epoch 40, Batch 130: Loss: 0.3133
# 	Epoch 40, Batch 140: Loss: 0.3134
# 	Epoch 40, Batch 150: Loss: 0.2960
# 	Epoch 40, Batch 160: Loss: 0.2647
# 	Epoch 40, Batch 170: Loss: 0.2453
# 	Epoch 40, Batch 180: Loss: 0.2235
# 	Epoch 40, Batch 190: Loss: 0.1921
# 	Epoch 40, Batch 200: Loss: 0.1463
# 	Epoch 40, Batch 210: Loss: 0.1072
# 	Epoch 40, Batch 220: Loss: 0.0502
# Epoch: 40, val_loss: 0.17, train_loss: 0.07 val_acc: 94.29, train_acc: 97.60
# 	Epoch 41, Batch 10: Loss: 0.0514
# 	Epoch 41, Batch 20: Loss: 0.1538
# 	Epoch 41, Batch 30: Loss: 0.2206
# 	Epoch 41, Batch 40: Loss: 0.2826
# 	Epoch 41, Batch 50: Loss: 0.3084
# 	Epoch 41, Batch 60: Loss: 0.3557
# 	Epoch 41, Batch 70: Loss: 0.3775
# 	Epoch 41, Batch 80: Loss: 0.3789
# 	Epoch 41, Batch 90: Loss: 0.4340
# 	Epoch 41, Batch 100: Loss: 0.4312
# 	Epoch 41, Batch 110: Loss: 0.4385
# 	Epoch 41, Batch 120: Loss: 0.4281
# 	Epoch 41, Batch 130: Loss: 0.4216
# 	Epoch 41, Batch 140: Loss: 0.3913
# 	Epoch 41, Batch 150: Loss: 0.3870
# 	Epoch 41, Batch 160: Loss: 0.3496
# 	Epoch 41, Batch 170: Loss: 0.3189
# 	Epoch 41, Batch 180: Loss: 0.2839
# 	Epoch 41, Batch 190: Loss: 0.2370
# 	Epoch 41, Batch 200: Loss: 0.1798
# 	Epoch 41, Batch 210: Loss: 0.1208
# 	Epoch 41, Batch 220: Loss: 0.0556
# Epoch: 41, val_loss: 0.07, train_loss: 0.07 val_acc: 97.30, train_acc: 97.38
# 	Epoch 42, Batch 10: Loss: 0.0503
# 	Epoch 42, Batch 20: Loss: 0.1141
# 	Epoch 42, Batch 30: Loss: 0.1541
# 	Epoch 42, Batch 40: Loss: 0.1814
# 	Epoch 42, Batch 50: Loss: 0.2312
# 	Epoch 42, Batch 60: Loss: 0.2490
# 	Epoch 42, Batch 70: Loss: 0.2767
# 	Epoch 42, Batch 80: Loss: 0.3143
# 	Epoch 42, Batch 90: Loss: 0.3254
# 	Epoch 42, Batch 100: Loss: 0.3316
# 	Epoch 42, Batch 110: Loss: 0.3437
# 	Epoch 42, Batch 120: Loss: 0.3586
# 	Epoch 42, Batch 130: Loss: 0.3393
# 	Epoch 42, Batch 140: Loss: 0.3342
# 	Epoch 42, Batch 150: Loss: 0.3223
# 	Epoch 42, Batch 160: Loss: 0.2977
# 	Epoch 42, Batch 170: Loss: 0.2621
# 	Epoch 42, Batch 180: Loss: 0.2293
# 	Epoch 42, Batch 190: Loss: 0.1895
# 	Epoch 42, Batch 200: Loss: 0.1444
# 	Epoch 42, Batch 210: Loss: 0.1009
# 	Epoch 42, Batch 220: Loss: 0.0465
# Epoch: 42, val_loss: 0.32, train_loss: 0.06 val_acc: 90.44, train_acc: 97.86
# 	Epoch 43, Batch 10: Loss: 0.0889
# 	Epoch 43, Batch 20: Loss: 0.1276
# 	Epoch 43, Batch 30: Loss: 0.1914
# 	Epoch 43, Batch 40: Loss: 0.2280
# 	Epoch 43, Batch 50: Loss: 0.2746
# 	Epoch 43, Batch 60: Loss: 0.2975
# 	Epoch 43, Batch 70: Loss: 0.3347
# 	Epoch 43, Batch 80: Loss: 0.3559
# 	Epoch 43, Batch 90: Loss: 0.3661
# 	Epoch 43, Batch 100: Loss: 0.3730
# 	Epoch 43, Batch 110: Loss: 0.3759
# 	Epoch 43, Batch 120: Loss: 0.3672
# 	Epoch 43, Batch 130: Loss: 0.3624
# 	Epoch 43, Batch 140: Loss: 0.3646
# 	Epoch 43, Batch 150: Loss: 0.3335
# 	Epoch 43, Batch 160: Loss: 0.3038
# 	Epoch 43, Batch 170: Loss: 0.2743
# 	Epoch 43, Batch 180: Loss: 0.2334
# 	Epoch 43, Batch 190: Loss: 0.1948
# 	Epoch 43, Batch 200: Loss: 0.1487
# 	Epoch 43, Batch 210: Loss: 0.1009
# 	Epoch 43, Batch 220: Loss: 0.0458
# Epoch: 43, val_loss: 0.08, train_loss: 0.06 val_acc: 97.76, train_acc: 97.91
# 	Epoch 44, Batch 10: Loss: 0.0191
# 	Epoch 44, Batch 20: Loss: 0.0473
# 	Epoch 44, Batch 30: Loss: 0.0899
# 	Epoch 44, Batch 40: Loss: 0.1292
# 	Epoch 44, Batch 50: Loss: 0.1515
# 	Epoch 44, Batch 60: Loss: 0.1768
# 	Epoch 44, Batch 70: Loss: 0.1747
# 	Epoch 44, Batch 80: Loss: 0.1918
# 	Epoch 44, Batch 90: Loss: 0.2162
# 	Epoch 44, Batch 100: Loss: 0.2623
# 	Epoch 44, Batch 110: Loss: 0.2619
# 	Epoch 44, Batch 120: Loss: 0.2806
# 	Epoch 44, Batch 130: Loss: 0.3030
# 	Epoch 44, Batch 140: Loss: 0.2922
# 	Epoch 44, Batch 150: Loss: 0.2764
# 	Epoch 44, Batch 160: Loss: 0.2552
# 	Epoch 44, Batch 170: Loss: 0.2239
# 	Epoch 44, Batch 180: Loss: 0.1940
# 	Epoch 44, Batch 190: Loss: 0.1603
# 	Epoch 44, Batch 200: Loss: 0.1242
# 	Epoch 44, Batch 210: Loss: 0.0850
# 	Epoch 44, Batch 220: Loss: 0.0407
# Epoch: 44, val_loss: 0.13, train_loss: 0.05 val_acc: 95.91, train_acc: 98.10
# 	Epoch 45, Batch 10: Loss: 0.0309
# 	Epoch 45, Batch 20: Loss: 0.0671
# 	Epoch 45, Batch 30: Loss: 0.0731
# 	Epoch 45, Batch 40: Loss: 0.1002
# 	Epoch 45, Batch 50: Loss: 0.1097
# 	Epoch 45, Batch 60: Loss: 0.1406
# 	Epoch 45, Batch 70: Loss: 0.1588
# 	Epoch 45, Batch 80: Loss: 0.1949
# 	Epoch 45, Batch 90: Loss: 0.2166
# 	Epoch 45, Batch 100: Loss: 0.2338
# 	Epoch 45, Batch 110: Loss: 0.2702
# 	Epoch 45, Batch 120: Loss: 0.3187
# 	Epoch 45, Batch 130: Loss: 0.3435
# 	Epoch 45, Batch 140: Loss: 0.3250
# 	Epoch 45, Batch 150: Loss: 0.3195
# 	Epoch 45, Batch 160: Loss: 0.2895
# 	Epoch 45, Batch 170: Loss: 0.2617
# 	Epoch 45, Batch 180: Loss: 0.2361
# 	Epoch 45, Batch 190: Loss: 0.2057
# 	Epoch 45, Batch 200: Loss: 0.1618
# 	Epoch 45, Batch 210: Loss: 0.1084
# 	Epoch 45, Batch 220: Loss: 0.0498
# Epoch: 45, val_loss: 0.08, train_loss: 0.06 val_acc: 97.38, train_acc: 97.71
# 	Epoch 46, Batch 10: Loss: 0.0374
# 	Epoch 46, Batch 20: Loss: 0.0799
# 	Epoch 46, Batch 30: Loss: 0.1274
# 	Epoch 46, Batch 40: Loss: 0.1917
# 	Epoch 46, Batch 50: Loss: 0.2433
# 	Epoch 46, Batch 60: Loss: 0.3011
# 	Epoch 46, Batch 70: Loss: 0.3043
# 	Epoch 46, Batch 80: Loss: 0.3721
# 	Epoch 46, Batch 90: Loss: 0.3870
# 	Epoch 46, Batch 100: Loss: 0.3910
# 	Epoch 46, Batch 110: Loss: 0.4144
# 	Epoch 46, Batch 120: Loss: 0.4163
# 	Epoch 46, Batch 130: Loss: 0.4167
# 	Epoch 46, Batch 140: Loss: 0.3945
# 	Epoch 46, Batch 150: Loss: 0.3736
# 	Epoch 46, Batch 160: Loss: 0.3459
# 	Epoch 46, Batch 170: Loss: 0.3053
# 	Epoch 46, Batch 180: Loss: 0.2574
# 	Epoch 46, Batch 190: Loss: 0.2175
# 	Epoch 46, Batch 200: Loss: 0.1682
# 	Epoch 46, Batch 210: Loss: 0.1115
# 	Epoch 46, Batch 220: Loss: 0.0527
# Epoch: 46, val_loss: 0.09, train_loss: 0.07 val_acc: 97.61, train_acc: 97.44
# 	Epoch 47, Batch 10: Loss: 0.1382
# 	Epoch 47, Batch 20: Loss: 0.1860
# 	Epoch 47, Batch 30: Loss: 0.2041
# 	Epoch 47, Batch 40: Loss: 0.2308
# 	Epoch 47, Batch 50: Loss: 0.2734
# 	Epoch 47, Batch 60: Loss: 0.3050
# 	Epoch 47, Batch 70: Loss: 0.3276
# 	Epoch 47, Batch 80: Loss: 0.3481
# 	Epoch 47, Batch 90: Loss: 0.3600
# 	Epoch 47, Batch 100: Loss: 0.3608
# 	Epoch 47, Batch 110: Loss: 0.3675
# 	Epoch 47, Batch 120: Loss: 0.3806
# 	Epoch 47, Batch 130: Loss: 0.3772
# 	Epoch 47, Batch 140: Loss: 0.3712
# 	Epoch 47, Batch 150: Loss: 0.3434
# 	Epoch 47, Batch 160: Loss: 0.3194
# 	Epoch 47, Batch 170: Loss: 0.2887
# 	Epoch 47, Batch 180: Loss: 0.2487
# 	Epoch 47, Batch 190: Loss: 0.2107
# 	Epoch 47, Batch 200: Loss: 0.1653
# 	Epoch 47, Batch 210: Loss: 0.1126
# 	Epoch 47, Batch 220: Loss: 0.0524
# Epoch: 47, val_loss: 0.09, train_loss: 0.07 val_acc: 97.61, train_acc: 97.55
# 	Epoch 48, Batch 10: Loss: 0.0363
# 	Epoch 48, Batch 20: Loss: 0.0845
# 	Epoch 48, Batch 30: Loss: 0.1618
# 	Epoch 48, Batch 40: Loss: 0.2094
# 	Epoch 48, Batch 50: Loss: 0.2320
# 	Epoch 48, Batch 60: Loss: 0.2499
# 	Epoch 48, Batch 70: Loss: 0.2537
# 	Epoch 48, Batch 80: Loss: 0.2867
# 	Epoch 48, Batch 90: Loss: 0.2733
# 	Epoch 48, Batch 100: Loss: 0.2868
# 	Epoch 48, Batch 110: Loss: 0.2959
# 	Epoch 48, Batch 120: Loss: 0.3078
# 	Epoch 48, Batch 130: Loss: 0.3116
# 	Epoch 48, Batch 140: Loss: 0.3036
# 	Epoch 48, Batch 150: Loss: 0.2896
# 	Epoch 48, Batch 160: Loss: 0.2612
# 	Epoch 48, Batch 170: Loss: 0.2401
# 	Epoch 48, Batch 180: Loss: 0.2089
# 	Epoch 48, Batch 190: Loss: 0.1760
# 	Epoch 48, Batch 200: Loss: 0.1383
# 	Epoch 48, Batch 210: Loss: 0.0950
# 	Epoch 48, Batch 220: Loss: 0.0448
# Epoch 00048: reducing learning rate of group 0 to 2.0000e-04.
# Epoch: 48, val_loss: 0.08, train_loss: 0.06 val_acc: 97.22, train_acc: 97.95
# 	Epoch 49, Batch 10: Loss: 0.0933
# 	Epoch 49, Batch 20: Loss: 0.1459
# 	Epoch 49, Batch 30: Loss: 0.1673
# 	Epoch 49, Batch 40: Loss: 0.1836
# 	Epoch 49, Batch 50: Loss: 0.2300
# 	Epoch 49, Batch 60: Loss: 0.2484
# 	Epoch 49, Batch 70: Loss: 0.2480
# 	Epoch 49, Batch 80: Loss: 0.2511
# 	Epoch 49, Batch 90: Loss: 0.2434
# 	Epoch 49, Batch 100: Loss: 0.2325
# 	Epoch 49, Batch 110: Loss: 0.2353
# 	Epoch 49, Batch 120: Loss: 0.2288
# 	Epoch 49, Batch 130: Loss: 0.2158
# 	Epoch 49, Batch 140: Loss: 0.2054
# 	Epoch 49, Batch 150: Loss: 0.1979
# 	Epoch 49, Batch 160: Loss: 0.1829
# 	Epoch 49, Batch 170: Loss: 0.1626
# 	Epoch 49, Batch 180: Loss: 0.1422
# 	Epoch 49, Batch 190: Loss: 0.1177
# 	Epoch 49, Batch 200: Loss: 0.0951
# 	Epoch 49, Batch 210: Loss: 0.0637
# 	Epoch 49, Batch 220: Loss: 0.0293
# Epoch: 49, val_loss: 0.06, train_loss: 0.04 val_acc: 98.54, train_acc: 98.83
# 	Epoch 50, Batch 10: Loss: 0.0407
# 	Epoch 50, Batch 20: Loss: 0.0473
# 	Epoch 50, Batch 30: Loss: 0.0696
# 	Epoch 50, Batch 40: Loss: 0.0806
# 	Epoch 50, Batch 50: Loss: 0.0975
# 	Epoch 50, Batch 60: Loss: 0.1080
# 	Epoch 50, Batch 70: Loss: 0.1264
# 	Epoch 50, Batch 80: Loss: 0.1340
# 	Epoch 50, Batch 90: Loss: 0.1322
# 	Epoch 50, Batch 100: Loss: 0.1419
# 	Epoch 50, Batch 110: Loss: 0.1431
# 	Epoch 50, Batch 120: Loss: 0.1418
# 	Epoch 50, Batch 130: Loss: 0.1536
# 	Epoch 50, Batch 140: Loss: 0.1498
# 	Epoch 50, Batch 150: Loss: 0.1491
# 	Epoch 50, Batch 160: Loss: 0.1485
# 	Epoch 50, Batch 170: Loss: 0.1316
# 	Epoch 50, Batch 180: Loss: 0.1166
# 	Epoch 50, Batch 190: Loss: 0.0967
# 	Epoch 50, Batch 200: Loss: 0.0727
# 	Epoch 50, Batch 210: Loss: 0.0477
# 	Epoch 50, Batch 220: Loss: 0.0221
# Epoch: 50, val_loss: 0.06, train_loss: 0.03 val_acc: 98.54, train_acc: 99.03
# 	Epoch 51, Batch 10: Loss: 0.0093
# 	Epoch 51, Batch 20: Loss: 0.0387
# 	Epoch 51, Batch 30: Loss: 0.0740
# 	Epoch 51, Batch 40: Loss: 0.1116
# 	Epoch 51, Batch 50: Loss: 0.1330
# 	Epoch 51, Batch 60: Loss: 0.1451
# 	Epoch 51, Batch 70: Loss: 0.1540
# 	Epoch 51, Batch 80: Loss: 0.1616
# 	Epoch 51, Batch 90: Loss: 0.1597
# 	Epoch 51, Batch 100: Loss: 0.1639
# 	Epoch 51, Batch 110: Loss: 0.1621
# 	Epoch 51, Batch 120: Loss: 0.1612
# 	Epoch 51, Batch 130: Loss: 0.1581
# 	Epoch 51, Batch 140: Loss: 0.1473
# 	Epoch 51, Batch 150: Loss: 0.1485
# 	Epoch 51, Batch 160: Loss: 0.1395
# 	Epoch 51, Batch 170: Loss: 0.1224
# 	Epoch 51, Batch 180: Loss: 0.1036
# 	Epoch 51, Batch 190: Loss: 0.0876
# 	Epoch 51, Batch 200: Loss: 0.0673
# 	Epoch 51, Batch 210: Loss: 0.0468
# 	Epoch 51, Batch 220: Loss: 0.0212
# Epoch: 51, val_loss: 0.06, train_loss: 0.03 val_acc: 98.38, train_acc: 99.01
# 	Epoch 52, Batch 10: Loss: 0.0164
# 	Epoch 52, Batch 20: Loss: 0.0533
# 	Epoch 52, Batch 30: Loss: 0.0969
# 	Epoch 52, Batch 40: Loss: 0.1120
# 	Epoch 52, Batch 50: Loss: 0.1400
# 	Epoch 52, Batch 60: Loss: 0.1727
# 	Epoch 52, Batch 70: Loss: 0.1757
# 	Epoch 52, Batch 80: Loss: 0.1961
# 	Epoch 52, Batch 90: Loss: 0.2166
# 	Epoch 52, Batch 100: Loss: 0.2188
# 	Epoch 52, Batch 110: Loss: 0.2126
# 	Epoch 52, Batch 120: Loss: 0.2016
# 	Epoch 52, Batch 130: Loss: 0.1999
# 	Epoch 52, Batch 140: Loss: 0.1886
# 	Epoch 52, Batch 150: Loss: 0.1733
# 	Epoch 52, Batch 160: Loss: 0.1552
# 	Epoch 52, Batch 170: Loss: 0.1337
# 	Epoch 52, Batch 180: Loss: 0.1146
# 	Epoch 52, Batch 190: Loss: 0.0966
# 	Epoch 52, Batch 200: Loss: 0.0731
# 	Epoch 52, Batch 210: Loss: 0.0485
# 	Epoch 52, Batch 220: Loss: 0.0228
# Epoch: 52, val_loss: 0.06, train_loss: 0.03 val_acc: 98.23, train_acc: 99.10
# 	Epoch 53, Batch 10: Loss: 0.0257
# 	Epoch 53, Batch 20: Loss: 0.0390
# 	Epoch 53, Batch 30: Loss: 0.0512
# 	Epoch 53, Batch 40: Loss: 0.0743
# 	Epoch 53, Batch 50: Loss: 0.0822
# 	Epoch 53, Batch 60: Loss: 0.0854
# 	Epoch 53, Batch 70: Loss: 0.1198
# 	Epoch 53, Batch 80: Loss: 0.1153
# 	Epoch 53, Batch 90: Loss: 0.1155
# 	Epoch 53, Batch 100: Loss: 0.1177
# 	Epoch 53, Batch 110: Loss: 0.1118
# 	Epoch 53, Batch 120: Loss: 0.1118
# 	Epoch 53, Batch 130: Loss: 0.1080
# 	Epoch 53, Batch 140: Loss: 0.1065
# 	Epoch 53, Batch 150: Loss: 0.1036
# 	Epoch 53, Batch 160: Loss: 0.1013
# 	Epoch 53, Batch 170: Loss: 0.0890
# 	Epoch 53, Batch 180: Loss: 0.0785
# 	Epoch 53, Batch 190: Loss: 0.0704
# 	Epoch 53, Batch 200: Loss: 0.0538
# 	Epoch 53, Batch 210: Loss: 0.0353
# 	Epoch 53, Batch 220: Loss: 0.0163
# Epoch: 53, val_loss: 0.06, train_loss: 0.02 val_acc: 98.30, train_acc: 99.32
# 	Epoch 54, Batch 10: Loss: 0.0074
# 	Epoch 54, Batch 20: Loss: 0.0286
# 	Epoch 54, Batch 30: Loss: 0.0595
# 	Epoch 54, Batch 40: Loss: 0.0647
# 	Epoch 54, Batch 50: Loss: 0.0822
# 	Epoch 54, Batch 60: Loss: 0.1000
# 	Epoch 54, Batch 70: Loss: 0.0987
# 	Epoch 54, Batch 80: Loss: 0.1017
# 	Epoch 54, Batch 90: Loss: 0.1218
# 	Epoch 54, Batch 100: Loss: 0.1243
# 	Epoch 54, Batch 110: Loss: 0.1286
# 	Epoch 54, Batch 120: Loss: 0.1220
# 	Epoch 54, Batch 130: Loss: 0.1173
# 	Epoch 54, Batch 140: Loss: 0.1129
# 	Epoch 54, Batch 150: Loss: 0.1028
# 	Epoch 54, Batch 160: Loss: 0.0964
# 	Epoch 54, Batch 170: Loss: 0.0850
# 	Epoch 54, Batch 180: Loss: 0.0737
# 	Epoch 54, Batch 190: Loss: 0.0608
# 	Epoch 54, Batch 200: Loss: 0.0465
# 	Epoch 54, Batch 210: Loss: 0.0310
# 	Epoch 54, Batch 220: Loss: 0.0144
# Epoch: 54, val_loss: 0.07, train_loss: 0.02 val_acc: 98.23, train_acc: 99.38
# 	Epoch 55, Batch 10: Loss: 0.0182
# 	Epoch 55, Batch 20: Loss: 0.0503
# 	Epoch 55, Batch 30: Loss: 0.0576
# 	Epoch 55, Batch 40: Loss: 0.0697
# 	Epoch 55, Batch 50: Loss: 0.0758
# 	Epoch 55, Batch 60: Loss: 0.0850
# 	Epoch 55, Batch 70: Loss: 0.0827
# 	Epoch 55, Batch 80: Loss: 0.0811
# 	Epoch 55, Batch 90: Loss: 0.0829
# 	Epoch 55, Batch 100: Loss: 0.0809
# 	Epoch 55, Batch 110: Loss: 0.0813
# 	Epoch 55, Batch 120: Loss: 0.0836
# 	Epoch 55, Batch 130: Loss: 0.0795
# 	Epoch 55, Batch 140: Loss: 0.0811
# 	Epoch 55, Batch 150: Loss: 0.0767
# 	Epoch 55, Batch 160: Loss: 0.0751
# 	Epoch 55, Batch 170: Loss: 0.0701
# 	Epoch 55, Batch 180: Loss: 0.0599
# 	Epoch 55, Batch 190: Loss: 0.0577
# 	Epoch 55, Batch 200: Loss: 0.0477
# 	Epoch 55, Batch 210: Loss: 0.0344
# 	Epoch 55, Batch 220: Loss: 0.0169
# Epoch: 55, val_loss: 0.06, train_loss: 0.02 val_acc: 98.61, train_acc: 99.43
# 	Epoch 56, Batch 10: Loss: 0.0042
# 	Epoch 56, Batch 20: Loss: 0.0394
# 	Epoch 56, Batch 30: Loss: 0.0525
# 	Epoch 56, Batch 40: Loss: 0.0550
# 	Epoch 56, Batch 50: Loss: 0.0885
# 	Epoch 56, Batch 60: Loss: 0.1123
# 	Epoch 56, Batch 70: Loss: 0.1361
# 	Epoch 56, Batch 80: Loss: 0.1485
# 	Epoch 56, Batch 90: Loss: 0.1463
# 	Epoch 56, Batch 100: Loss: 0.1475
# 	Epoch 56, Batch 110: Loss: 0.1419
# 	Epoch 56, Batch 120: Loss: 0.1466
# 	Epoch 56, Batch 130: Loss: 0.1452
# 	Epoch 56, Batch 140: Loss: 0.1372
# 	Epoch 56, Batch 150: Loss: 0.1233
# 	Epoch 56, Batch 160: Loss: 0.1170
# 	Epoch 56, Batch 170: Loss: 0.1020
# 	Epoch 56, Batch 180: Loss: 0.0946
# 	Epoch 56, Batch 190: Loss: 0.0795
# 	Epoch 56, Batch 200: Loss: 0.0625
# 	Epoch 56, Batch 210: Loss: 0.0415
# 	Epoch 56, Batch 220: Loss: 0.0199
# Epoch 00056: reducing learning rate of group 0 to 4.0000e-05.
# Epoch: 56, val_loss: 0.06, train_loss: 0.03 val_acc: 98.23, train_acc: 99.10
# 	Epoch 57, Batch 10: Loss: 0.0286
# 	Epoch 57, Batch 20: Loss: 0.0323
# 	Epoch 57, Batch 30: Loss: 0.0505
# 	Epoch 57, Batch 40: Loss: 0.0585
# 	Epoch 57, Batch 50: Loss: 0.0641
# 	Epoch 57, Batch 60: Loss: 0.0700
# 	Epoch 57, Batch 70: Loss: 0.0833
# 	Epoch 57, Batch 80: Loss: 0.0893
# 	Epoch 57, Batch 90: Loss: 0.0973
# 	Epoch 57, Batch 100: Loss: 0.0936
# 	Epoch 57, Batch 110: Loss: 0.1082
# 	Epoch 57, Batch 120: Loss: 0.1090
# 	Epoch 57, Batch 130: Loss: 0.1053
# 	Epoch 57, Batch 140: Loss: 0.0976
# 	Epoch 57, Batch 150: Loss: 0.1088
# 	Epoch 57, Batch 160: Loss: 0.0993
# 	Epoch 57, Batch 170: Loss: 0.0926
# 	Epoch 57, Batch 180: Loss: 0.0772
# 	Epoch 57, Batch 190: Loss: 0.0622
# 	Epoch 57, Batch 200: Loss: 0.0518
# 	Epoch 57, Batch 210: Loss: 0.0343
# 	Epoch 57, Batch 220: Loss: 0.0156
# Epoch: 57, val_loss: 0.06, train_loss: 0.02 val_acc: 98.61, train_acc: 99.38
# 	Epoch 58, Batch 10: Loss: 0.0113
# 	Epoch 58, Batch 20: Loss: 0.0308
# 	Epoch 58, Batch 30: Loss: 0.0443
# 	Epoch 58, Batch 40: Loss: 0.0657
# 	Epoch 58, Batch 50: Loss: 0.0689
# 	Epoch 58, Batch 60: Loss: 0.0734
# 	Epoch 58, Batch 70: Loss: 0.0844
# 	Epoch 58, Batch 80: Loss: 0.0831
# 	Epoch 58, Batch 90: Loss: 0.0884
# 	Epoch 58, Batch 100: Loss: 0.0995
# 	Epoch 58, Batch 110: Loss: 0.1038
# 	Epoch 58, Batch 120: Loss: 0.1175
# 	Epoch 58, Batch 130: Loss: 0.1130
# 	Epoch 58, Batch 140: Loss: 0.1068
# 	Epoch 58, Batch 150: Loss: 0.0969
# 	Epoch 58, Batch 160: Loss: 0.0868
# 	Epoch 58, Batch 170: Loss: 0.0769
# 	Epoch 58, Batch 180: Loss: 0.0655
# 	Epoch 58, Batch 190: Loss: 0.0571
# 	Epoch 58, Batch 200: Loss: 0.0443
# 	Epoch 58, Batch 210: Loss: 0.0304
# 	Epoch 58, Batch 220: Loss: 0.0141
# Epoch: 58, val_loss: 0.06, train_loss: 0.02 val_acc: 98.54, train_acc: 99.45
# 	Epoch 59, Batch 10: Loss: 0.0078
# 	Epoch 59, Batch 20: Loss: 0.0130
# 	Epoch 59, Batch 30: Loss: 0.0200
# 	Epoch 59, Batch 40: Loss: 0.0534
# 	Epoch 59, Batch 50: Loss: 0.0697
# 	Epoch 59, Batch 60: Loss: 0.0715
# 	Epoch 59, Batch 70: Loss: 0.0897
# 	Epoch 59, Batch 80: Loss: 0.0912
# 	Epoch 59, Batch 90: Loss: 0.1008
# 	Epoch 59, Batch 100: Loss: 0.1026
# 	Epoch 59, Batch 110: Loss: 0.1101
# 	Epoch 59, Batch 120: Loss: 0.1055
# 	Epoch 59, Batch 130: Loss: 0.0992
# 	Epoch 59, Batch 140: Loss: 0.0931
# 	Epoch 59, Batch 150: Loss: 0.0983
# 	Epoch 59, Batch 160: Loss: 0.0876
# 	Epoch 59, Batch 170: Loss: 0.0812
# 	Epoch 59, Batch 180: Loss: 0.0718
# 	Epoch 59, Batch 190: Loss: 0.0575
# 	Epoch 59, Batch 200: Loss: 0.0437
# 	Epoch 59, Batch 210: Loss: 0.0295
# 	Epoch 59, Batch 220: Loss: 0.0135
# Epoch: 59, val_loss: 0.06, train_loss: 0.02 val_acc: 98.54, train_acc: 99.54
# > Early stopping <

# %% [markdown]
# # Analisis de resultados <a name="analisis"></a>

# %%
model.load_state_dict(early_stopper.best_model)
model.eval()

cm = metrics.confusion_matrix(targets, preds)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Gráfico de la precisión de entrenamiento y validación
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_acc_h, label='Train Accuracy')
plt.plot(val_acc_h, label='Validation Accuracy')
plt.title('Train vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Gráfico de la pérdida de entrenamiento y validación
plt.subplot(1, 2, 2)
plt.plot(train_loss_h, label='Train Loss')
plt.plot(val_loss_h, label='Validation Loss')
plt.title('Train vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# cjto train
train_preds, train_reals, train_loss, train_acc = eval(model, train_loader, device=device, criterion=criterion)
print("Train Dataset ----------------------------------------------------------------")
print(f"train_loss: {train_loss} - train_acc: {train_acc}")
print(metrics.classification_report(train_reals, train_preds, zero_division=0))


# cjto val
val_preds, val_reals, val_loss, val_acc = eval(model, val_loader, device=device, criterion=criterion)
print("Val Dataset ----------------------------------------------------------------")
print(f"val_loss: {val_loss} - val_acc: {val_acc}")
print(metrics.classification_report(val_reals, val_preds, zero_division=0))

# cjto tests
test_preds, test_reals, test_loss, test_acc = eval(model, test_loader, device=device, criterion=criterion)
cm = metrics.confusion_matrix(test_reals, test_preds)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Tests Dataset")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print("Tests Dataset ----------------------------------------------------------------")
print(f"test_loss: {test_loss} - test_acc: {test_acc}")
print(metrics.classification_report(test_reals, test_preds, zero_division=0))
# Out:
# Train Dataset ----------------------------------------------------------------
# train_loss: 0.011917975219505089 - train_acc: 0.99669457910974
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1135
#            1       1.00      0.99      0.99      1134
#            2       0.99      1.00      0.99      1135
#            3       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      4538
#    macro avg       1.00      1.00      1.00      4538
# weighted avg       1.00      1.00      1.00      4538
#
# Val Dataset ----------------------------------------------------------------
# val_loss: 0.059043334251327906 - val_acc: 0.9853508095605242
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       324
#            1       0.99      0.98      0.98       325
#            2       0.97      0.98      0.97       324
#            3       0.99      0.99      0.99       324
#
#     accuracy                           0.99      1297
#    macro avg       0.99      0.99      0.99      1297
# weighted avg       0.99      0.99      0.99      1297
# Tests Dataset ----------------------------------------------------------------
# test_loss: 0.08575232133686465 - test_acc: 0.9830508474576272
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       162
#            1       0.98      0.98      0.98       162
#            2       0.96      0.97      0.97       162
#            3       0.99      1.00      1.00       163
#
#     accuracy                           0.98       649
#    macro avg       0.98      0.98      0.98       649
# weighted avg       0.98      0.98      0.98       649

# %% [markdown]
# # Guardado del modelo <a name="guardado"></a>

# %%
def save_model(model, path, complete=False):
    try:
        torch.save(model if complete else model.state_dict(), path)
    except Exception as e:
        print("Error al guardar el model:", e)

# %%
#save_model(model, "./kaggle/working/model_98.pth", complete=True)
